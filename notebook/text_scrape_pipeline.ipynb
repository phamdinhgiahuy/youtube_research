# %% [markdown]
# # Setting and suporting functions

# %%
import os
from dotenv import load_dotenv
from googleapiclient.discovery import build
from youtube_transcript_api import YouTubeTranscriptApi
import pandas as pd
import time
import json
from typing import List, Dict, Optional
from yt_dlp import YoutubeDL
# Load environment variables
load_dotenv()

# Get YouTube API key
API_KEY = os.getenv("J_YOUTUBE_API_KEY")
if not API_KEY:
    raise ValueError("API key not found. Please ensure the '.env' file is set up correctly.")
youtube = build("youtube", "v3", developerKey=API_KEY)

# Constants
MAX_RESULTS_PER_PAGE = 50
CACHE_DIR = "cache"
os.makedirs(CACHE_DIR, exist_ok=True)

def get_video_stats(video_id: str) -> Optional[Dict]:
    """
    Fetch statistics for a given video ID.
    """
    try:
        response = youtube.videos().list(
            part="snippet,statistics,contentDetails,liveStreamingDetails,paidProductPlacementDetails,status,topicDetails",
            id=video_id
        ).execute()
    except Exception as e:
        print(f"Error fetching video data: {e}")
        return None

    if not response.get("items"):
        print(f"No video found with ID: {video_id}")
        return None

    video_data = response["items"][0]
    return {
        "title": video_data.get("snippet", {}).get("title", ""),
        "description": video_data.get("snippet", {}).get("description", ""),
        "channelTitle": video_data.get("snippet", {}).get("channelTitle", ""),
        "publishTime": video_data.get("snippet", {}).get("publishedAt", ""),
        "channelId": video_data.get("snippet", {}).get("channelId", ""),
        "thumbnail": video_data.get("snippet", {}).get("thumbnails", {}).get("standard", {}).get("url", ""),
        "tags": video_data.get("snippet", {}).get("tags", []),
        "topicCategories": video_data.get("topicDetails", {}).get("topicCategories", []),
        "categoryId": video_data.get("snippet", {}).get("categoryId", None),
        "liveBroadcastContent": video_data.get("snippet", {}).get("liveBroadcastContent", None),
        "duration": video_data.get("contentDetails", {}).get("duration", None),
        "has_caption": video_data.get("contentDetails", {}).get("caption", None),
        "licensedContent": video_data.get("contentDetails", {}).get("licensedContent", None),
        "definition": video_data.get("contentDetails", {}).get("definition", None),
        "contentRating": video_data.get("contentDetails", {}).get("contentRating", None),
        "madeForKids": video_data.get("status", {}).get("madeForKids", None),
        "privacyStatus": video_data.get("status", {}).get("privacyStatus", None),
        "viewCount": video_data.get("statistics", {}).get("viewCount", None),
        "likeCount": video_data.get("statistics", {}).get("likeCount", None),
        "commentCount": video_data.get("statistics", {}).get("commentCount", None),
        "dislikeCount": video_data.get("statistics", {}).get("dislikeCount", None),
        "favoriteCount": video_data.get("statistics", {}).get("favoriteCount", None),
        "paidProductPlacement": video_data.get("paidProductPlacementDetails", {}).get("hasPaidProductPlacement", None)
    }

def get_channel_stats(channel_id: str) -> Optional[Dict]:
    """
    Fetch statistics for a given channel ID.
    """
    try:
        response = youtube.channels().list(
            part="snippet,statistics,contentDetails,topicDetails",
            id=channel_id
        ).execute()
    except Exception as e:
        print(f"Error fetching channel data: {e}")
        return None

    if not response.get("items"):
        print(f"No channel found with ID: {channel_id}")
        return None

    channel_data = response["items"][0]
    return {
        "channel_title": channel_data["snippet"]["title"],
        "channel_description": channel_data["snippet"]["description"],
        "channel_custom_url": channel_data["snippet"]["customUrl"],
        "channel_thumbnail": channel_data["snippet"]["thumbnails"]["default"]["url"],
        "channel_published_at": channel_data["snippet"]["publishedAt"],
        "channel_view_count": channel_data["statistics"].get("viewCount", None),
        "channel_subscriber_count": channel_data["statistics"].get("subscriberCount", None),
        "channel_video_count": channel_data["statistics"].get("videoCount", None),
        "channel_playlist_count": channel_data["statistics"].get("playlistCount", None),
        "channel_comment_count": channel_data["statistics"].get("commentCount", None),
        "channel_live_count": channel_data["statistics"].get("liveCount", None),
        "channel_topic_categories": channel_data["topicDetails"].get("topicCategories", []),
        "channel_topic_ids": channel_data["topicDetails"].get("topicIds", []),
        "channel_country": channel_data["snippet"].get("country", None),
    }

def get_comments(video_id: str, cmt_count: int = 200, max_results: int = 100) -> Dict:
    """
    Fetch comments for a given video ID.
    """
    all_comments = []
    next_page_token = None
    search_pages = (cmt_count // max_results) + (1 if cmt_count % max_results else 0)

    for i in range(search_pages):
        try:
            comment_request = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                pageToken=next_page_token,
                textFormat="plainText",
                maxResults=max_results,
                order="relevance"
            )
            comment_response = comment_request.execute()

            for item in comment_response['items']:
                top_comment = item['snippet']['topLevelComment']['snippet']
                all_comments.append({
                    'Timestamp': top_comment['publishedAt'],
                    'Username': top_comment['authorDisplayName'],
                    'VideoID': video_id,
                    'Comment': top_comment['textDisplay'],
                    'Date': top_comment.get('updatedAt', top_comment['publishedAt']),
                    "likeCount": top_comment["likeCount"],
                    "totalReplyCount": item["snippet"]["totalReplyCount"],
                })
            print(f"Page {i + 1} of comments fetched for video {video_id}")
            next_page_token = comment_response.get('nextPageToken')
            if not next_page_token:
                break
        except Exception as e:
            print(f"Error fetching comments for video {video_id}: {e}")
            break

    return {"top_comments": all_comments}

def get_transcript(video_id: str) -> Dict:
    """
    Fetch transcript for a given video ID.
    """
    try:
        transcript_list = YouTubeTranscriptApi.list_transcripts(video_id)
        transcript = transcript_list.find_transcript(['en'])
        transcript_src = transcript.fetch()
        transcript_txt = " ".join([line['text'] for line in transcript_src])
        return {"transcript": transcript_txt, "transcript_is_generated": transcript.is_generated}
    except Exception as e:
        print(f"Error fetching transcript for video {video_id}: {e}")
        return {"transcript": None, "transcript_is_generated": None}

def fetch_video_page(youtube, keyword: str, order: str, region: str, language: str, video_duration: str, 
                     published_start: str, published_end: str, video_quality: str, token: Optional[str] = None) -> Dict:
    """
    Fetch a single page of video search results from the YouTube API.
    """
    try:
        request = youtube.search().list(
            part="snippet",
            maxResults=MAX_RESULTS_PER_PAGE,
            q=keyword,
            order=order,
            type="video",
            regionCode=region,
            relevanceLanguage=language,
            videoDuration=video_duration,
            publishedAfter=published_start,
            publishedBefore=published_end,
            pageToken=token,
            videoDefinition=video_quality
        )
        return request.execute()
    except Exception as e:
        print(f"Error fetching video page: {e}")
        return {}

def extract_video_data(item: Dict, product_type: str, product_name: str) -> Dict:
    """
    Extract relevant video data from a single API response item.
    """
    return {
        "product_type": product_type,
        "product_name": product_name,
        "video_id": item["id"]["videoId"],
        "video_url": f"https://www.youtube.com/watch?v={item['id']['videoId']}",
        "video_title": item["snippet"]["title"],
        "video_description": item["snippet"]["description"],
        "video_channel": item["snippet"]["channelTitle"],
        "video_channel_id": item["snippet"]["channelId"],
        "video_published": item["snippet"]["publishedAt"],
        "video_thumbnail": item["snippet"]["thumbnails"]["default"]["url"]
    }

def save_to_cache(cache_file: str, keyword: str, response_list: List[Dict]) -> None:
    """
    Save the API response to a cache file.
    """
    cache_json = {'keyword': keyword, 'response_list': response_list}
    with open(cache_file, 'w') as f:
        json.dump(cache_json, f, indent=4, ensure_ascii=False)

def search_videos_by_keyword(youtube, product_type: str, product_name: str, region: str = 'US', language: str = "en", 
                            video_quality: str = "any", video_duration: str = "any", videos_count: int = 100, 
                            order: str = "viewCount", published_start: str = '2023-01-01T00:00:00Z', 
                            published_end: str = '2024-12-31T23:59:59Z', token: Optional[str] = None) -> List[Dict]:
    """
    Search for videos by keyword and return a list of video data.
    """
    keyword = f"{product_type} review"
    cache_file = os.path.join(CACHE_DIR, f'ytb_search_cache_{product_type}.json')
    response_list = []
    pages = (videos_count // MAX_RESULTS_PER_PAGE) + (1 if videos_count % MAX_RESULTS_PER_PAGE else 0)

    for i in range(pages):
        response = fetch_video_page(youtube, keyword, order, region, language, video_duration, 
                                   published_start, published_end, video_quality, token)
        if not response:
            break

        response_list.append(response)
        print(f"Page {i+1}: {response['pageInfo']['totalResults']} videos found. Next page token: {response.get('nextPageToken')}")

        token = response.get("nextPageToken")
        if not token:
            break
        # time.sleep(1)  # Avoid hitting API rate limits

    save_to_cache(cache_file, keyword, response_list)

    ytb_search_data = []
    for response in response_list:
        for item in response.get("items", []):
            video_data = extract_video_data(item, product_type, product_name)
            ytb_search_data.append(video_data)

    return ytb_search_data

def process_video_results(all_search_results: List[Dict], cache_file: str) -> List[Dict]:
    """
    Process video results, fetch stats, and update cache.
    """
    video_stats_cache = load_cache(cache_file)
    testing_search = []

    for result in all_search_results:
        video_id = result["video_id"]
        if video_id in video_stats_cache:
            print(f"Using cached data for video ID: {video_id}")
            video_stats = video_stats_cache[video_id]
        else:
            video_stats = get_video_stats(video_id)
            if video_stats:
                update_cache(video_stats_cache, video_id, video_stats, cache_file)
                print(f"Fetched and cached data for video ID: {video_id}")
            else:
                print(f"Failed to fetch data for video ID: {video_id}")
                continue

        result.update(video_stats)
        testing_search.append(result)

    return testing_search

def fetch_and_process_videos(product_type: str, product_name: str = "", videos_count: int = 1000) -> pd.DataFrame:
    """
    Fetch videos, process stats, fetch transcripts, and save results to a CSV file.
    """
    # Define cache file paths
    product_type_file = product_type.replace(" ", "_").lower()
    cache_file = os.path.join(CACHE_DIR, f"video_stats_cache_{product_type_file}.json")
    output_file = os.path.join(CACHE_DIR, f"ytb_search_results_{product_type_file}.csv")

    # Load cache if it exists, or initialize an empty cache
    if os.path.exists(cache_file):
        with open(cache_file, "r") as f:
            video_stats_cache = json.load(f)
    else:
        video_stats_cache = {}

    # Fetch videos by keyword
    print(f"Searching for videos related to '{product_type}'...")
    search_results = search_videos_by_keyword(
        youtube=youtube,
        product_type=product_type,
        product_name=product_name,
        videos_count=videos_count,
        order="relevance",
        region="US",
        language="en",
        video_duration="medium",
        published_start='2023-01-01T00:00:00Z',
        published_end='2024-12-31T23:59:59Z'
    )
    print(f"Found {len(search_results)} videos for {product_type}.")

    # Process each video
    all_search_results = []
    for result in search_results:
        video_id = result["video_id"]

        # Fetch video stats (from cache or API)
        if video_id in video_stats_cache:
            print(f"Using cached data for video ID: {video_id}")
            video_stats = video_stats_cache[video_id]
        else:
            video_stats = get_video_stats(video_id)
            if video_stats:
                # Fetch transcript
                transcript_data = get_transcript(video_id)
                video_stats.update(transcript_data)  # Add transcript to video stats

                # Update cache
                video_stats_cache[video_id] = video_stats
                with open(cache_file, "w") as f:
                    json.dump(video_stats_cache, f)
                print(f"Fetched and cached data for video ID: {video_id}")
            else:
                print(f"Failed to fetch data for video ID: {video_id}")
                continue  # Skip to the next result if API call fails

        # Update result with video stats and add to the list
        result.update(video_stats)
        all_search_results.append(result)

    print(f"Total videos processed: {len(all_search_results)}")

    # Convert to DataFrame and save
    ytb_search_df = pd.DataFrame(all_search_results)
    ytb_search_df.to_csv(output_file, index=False)
    print(f"Data saved to {output_file}")

    return ytb_search_df

def load_cache(cache_file: str) -> Dict:
    """
    Load cache from a file.
    """
    if os.path.exists(cache_file):
        with open(cache_file, "r") as f:
            return json.load(f)
    return {}

def update_cache(video_stats_cache: Dict, video_id: str, video_stats: Dict, cache_file: str) -> None:
    """
    Update cache with new video stats.
    """
    video_stats_cache[video_id] = video_stats
    with open(cache_file, "w") as f:
        json.dump(video_stats_cache, f)

def save_results_to_csv(testing_search: List[Dict], keyword: str) -> None:
    """
    Save results to a CSV file.
    """
    keyword_file = keyword.replace(" ", "_").lower()
    ytb_search_df = pd.DataFrame(testing_search)
    output_file = os.path.join(CACHE_DIR, f"ytb_search_results_{keyword_file}.csv")
    ytb_search_df.to_csv(output_file, index=False)
    print(f"Data saved to {output_file}")


def fetch_video_metadata(video_id: str, ydl: YoutubeDL, cache_file: str, video_info_cache: Dict) -> Optional[Dict]:
    """
    Fetch metadata for a video using yt-dlp and update the cache.
    """
    if video_id in video_info_cache:
        print(f"Skipping {video_id}: Already in cache.")
        return video_info_cache[video_id]

    url = f"https://www.youtube.com/watch?v={video_id}"
    try:
        print(f"Fetching info for {video_id}...")
        info = ydl.extract_info(url, download=False)
        video_info_cache[video_id] = info
        return info
    except Exception as e:
        print(f"Error fetching info for {video_id}: {e}")
        return None

# %%
products = [
    "COSRX Snail Mucin Serum",
    "Tesla Model Y",
    "Samsung OLED TV",
    "Liquid Death",
    "Stanley tumbler",
    "Apple AirTag",
    "Meta quest 3",
    "Samsung Galaxy Watch 7",
    "Macbook Pro M4",
    "Lululemon Align Pants",
]

# %%
for keyword in products[8:]:
    ytb_search_df = fetch_and_process_videos(product_type=keyword, videos_count=500)
    print(ytb_search_df.head())
    print(f"Finished processing {keyword} videos. Total videos: {len(ytb_search_df)}")
# Out:
# Searching for videos related to 'Macbook Pro M4'...
# Page 1: 378396 videos found. Next page token: CDIQAA
# Page 2: 378397 videos found. Next page token: CGQQAA
# Page 3: 378396 videos found. Next page token: CJYBEAA
# Page 4: 378395 videos found. Next page token: CMgBEAA
# Page 5: 378395 videos found. Next page token: CPoBEAA
# Page 6: 378395 videos found. Next page token: CKwCEAA
# Page 7: 378395 videos found. Next page token: CN4CEAA
# Page 8: 378395 videos found. Next page token: CJADEAA
# Page 9: 378395 videos found. Next page token: CMIDEAA
# Page 10: 378395 videos found. Next page token: CPQDEAA
# Found 500 videos for Macbook Pro M4.
# Error fetching transcript for video anIVewgtbFc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=anIVewgtbFc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: anIVewgtbFc
# Error fetching transcript for video b4x8boB2KdI:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=b4x8boB2KdI! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: b4x8boB2KdI
# Error fetching transcript for video iwg_K-crnv4:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=iwg_K-crnv4! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: iwg_K-crnv4
# Error fetching transcript for video 9HQx5pgUoiY:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=9HQx5pgUoiY! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: 9HQx5pgUoiY
# Error fetching transcript for video etP2Th9g2hM:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=etP2Th9g2hM! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: etP2Th9g2hM
# Error fetching transcript for video hwRuj5ANres:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=hwRuj5ANres! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: hwRuj5ANres
# Error fetching transcript for video n3den_F-oZk:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=n3den_F-oZk! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: n3den_F-oZk
# Error fetching transcript for video 9PCtfKr5Uw8:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=9PCtfKr5Uw8! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: 9PCtfKr5Uw8
# Error fetching transcript for video -StTTWAw214:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=-StTTWAw214! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: -StTTWAw214
# Error fetching transcript for video 0PpF_2oJ1c8:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=0PpF_2oJ1c8! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: 0PpF_2oJ1c8
# Error fetching transcript for video Q5HAMzDaUF8:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Q5HAMzDaUF8! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: Q5HAMzDaUF8
# Error fetching transcript for video zslf3n2V3uQ:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=zslf3n2V3uQ! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: zslf3n2V3uQ
# Error fetching transcript for video TfvIgdzImt4:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=TfvIgdzImt4! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: TfvIgdzImt4
# Error fetching transcript for video oOgLihYVI9U:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=oOgLihYVI9U! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: oOgLihYVI9U
# Error fetching transcript for video Lw0SQ-xhqek:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Lw0SQ-xhqek! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: Lw0SQ-xhqek
# Error fetching transcript for video bkvsY1pQbwc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=bkvsY1pQbwc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: bkvsY1pQbwc
# Error fetching transcript for video hJZ63aCXFFc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=hJZ63aCXFFc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: hJZ63aCXFFc
# Error fetching transcript for video I8hPTEfcZjM:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=I8hPTEfcZjM! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: I8hPTEfcZjM
# Fetched and cached data for video ID: Sc9WByMKTG4
# Error fetching transcript for video VcAxjw3akMU:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=VcAxjw3akMU! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: VcAxjw3akMU
# Error fetching transcript for video 1X9Vo43qx_c:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=1X9Vo43qx_c! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: 1X9Vo43qx_c
# Fetched and cached data for video ID: 0Y-hSdqnh_c
# Error fetching transcript for video 0vn9T3x4dGg:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=0vn9T3x4dGg! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: 0vn9T3x4dGg
# Error fetching transcript for video FDsHCALztjg:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=FDsHCALztjg! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: FDsHCALztjg
# Error fetching transcript for video n63sByo2edM:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=n63sByo2edM! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: n63sByo2edM
# Error fetching transcript for video -zxJBLNEj7w:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=-zxJBLNEj7w! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: -zxJBLNEj7w
# Error fetching transcript for video oacRsO3ZuuQ:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=oacRsO3ZuuQ! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: oacRsO3ZuuQ
# Error fetching transcript for video LRRpyTlsZ-s:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=LRRpyTlsZ-s! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: LRRpyTlsZ-s
# Error fetching transcript for video 1dwZz0uQ24o:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=1dwZz0uQ24o! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: 1dwZz0uQ24o
# Error fetching transcript for video 1xwEGW3z21U:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=1xwEGW3z21U! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: 1xwEGW3z21U
# Error fetching transcript for video 5ee2cMal4oI:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=5ee2cMal4oI! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: 5ee2cMal4oI
# Error fetching transcript for video r-wuQT5vvys:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=r-wuQT5vvys! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: r-wuQT5vvys
# Fetched and cached data for video ID: EQI1ib597yA
# Error fetching transcript for video rSoqE5gbNvM:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=rSoqE5gbNvM! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: rSoqE5gbNvM
# Error fetching transcript for video GuE6MuKPbGw:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=GuE6MuKPbGw! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: GuE6MuKPbGw
# Error fetching transcript for video S6HJS2Hcl0w:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=S6HJS2Hcl0w! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: S6HJS2Hcl0w
# Fetched and cached data for video ID: Iiev3DJGJpw
# Fetched and cached data for video ID: l5H9xCYNQEk
# Error fetching transcript for video KVG5R7QxbFM:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=KVG5R7QxbFM! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: KVG5R7QxbFM
# Fetched and cached data for video ID: SdJvoHrvqlA
# Error fetching transcript for video uH3m8-k44E8:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=uH3m8-k44E8! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: uH3m8-k44E8
# Error fetching transcript for video 65dHdBMTu9U:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=65dHdBMTu9U! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: 65dHdBMTu9U
# Error fetching transcript for video ehjpS8Bnd20:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=ehjpS8Bnd20! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: ehjpS8Bnd20
# Fetched and cached data for video ID: UehsG0iKE14
# Error fetching transcript for video OQADGqA83LU:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=OQADGqA83LU! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: OQADGqA83LU
# Error fetching transcript for video Cwi_GBO0VpE:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Cwi_GBO0VpE! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: Cwi_GBO0VpE
# Error fetching transcript for video D2ezDpeq8_Q:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=D2ezDpeq8_Q! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: D2ezDpeq8_Q
# Error fetching transcript for video ryejRyd3fY8:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=ryejRyd3fY8! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: ryejRyd3fY8
# Fetched and cached data for video ID: kdTJGR3FTV0
# Fetched and cached data for video ID: HN-WH7C4K0Q
# Error fetching transcript for video Kr28OQ4ony8:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Kr28OQ4ony8! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: Kr28OQ4ony8
# Error fetching transcript for video d2kSQiYrOeQ:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=d2kSQiYrOeQ! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: d2kSQiYrOeQ
# Error fetching transcript for video 4d2cgDTC2u0:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=4d2cgDTC2u0! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: 4d2cgDTC2u0
# Error fetching transcript for video cMc8lpsQcdE:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=cMc8lpsQcdE! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: cMc8lpsQcdE
# Fetched and cached data for video ID: z19HM7ANZlo
# Error fetching transcript for video Jj4wbjBoz9I:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Jj4wbjBoz9I! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: Jj4wbjBoz9I
# Error fetching transcript for video PHcDrXeyguM:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=PHcDrXeyguM! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: PHcDrXeyguM
# Error fetching transcript for video EA5NRyU3p10:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=EA5NRyU3p10! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: EA5NRyU3p10
# Error fetching transcript for video 6cz_81pA7Oc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=6cz_81pA7Oc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: 6cz_81pA7Oc
# Fetched and cached data for video ID: qExcc92zHfo
# Error fetching transcript for video KFL9YG3jg20:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=KFL9YG3jg20! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: KFL9YG3jg20
# Error fetching transcript for video Q451suhTHp8:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Q451suhTHp8! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: Q451suhTHp8
# Error fetching transcript for video xuJNGDwpDIM:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=xuJNGDwpDIM! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: xuJNGDwpDIM
# Error fetching transcript for video Bl9tQ6ZgdLc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Bl9tQ6ZgdLc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: Bl9tQ6ZgdLc
# Error fetching transcript for video gBoXmtDCZMM:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=gBoXmtDCZMM! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: gBoXmtDCZMM
# Error fetching transcript for video ZhmBG67nSDM:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=ZhmBG67nSDM! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: ZhmBG67nSDM
# Error fetching transcript for video -EY5kCH66Cc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=-EY5kCH66Cc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: -EY5kCH66Cc
# Fetched and cached data for video ID: nr5SroBm74c
# Error fetching transcript for video fEapHEKqNA8:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=fEapHEKqNA8! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: fEapHEKqNA8
# Fetched and cached data for video ID: OuOcF7hHvIg
# Error fetching transcript for video Nf0aIX8niV4:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Nf0aIX8niV4! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: Nf0aIX8niV4
# Error fetching transcript for video p1XONA3sHWA:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=p1XONA3sHWA! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: p1XONA3sHWA
# Error fetching transcript for video ijTNBZszvJ0:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=ijTNBZszvJ0! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: ijTNBZszvJ0
# Fetched and cached data for video ID: eJK4Jb53Sys
# Error fetching transcript for video KTq57j9Jmf8:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=KTq57j9Jmf8! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: KTq57j9Jmf8
# Error fetching transcript for video ZWgr7qP6yhY:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=ZWgr7qP6yhY! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: ZWgr7qP6yhY
# Error fetching transcript for video cuX7e-JaFMI:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=cuX7e-JaFMI! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: cuX7e-JaFMI
# Error fetching transcript for video julah2zp4dY:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=julah2zp4dY! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: julah2zp4dY
# Error fetching transcript for video 6vIigQyVHjQ:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=6vIigQyVHjQ! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: 6vIigQyVHjQ
# Error fetching transcript for video ThkvX6f8ZKk:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=ThkvX6f8ZKk! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: ThkvX6f8ZKk
# Error fetching transcript for video B0v2toApP9M:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=B0v2toApP9M! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: B0v2toApP9M
# Error fetching transcript for video MCPvVYQyygI:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=MCPvVYQyygI! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: MCPvVYQyygI
# Error fetching transcript for video F2XbE3kg5Yg:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=F2XbE3kg5Yg! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: F2XbE3kg5Yg
# Error fetching transcript for video mQN8gQRAVMU:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=mQN8gQRAVMU! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# ...
# Fetched and cached data for video ID: L77TjgoTOH0
# Fetched and cached data for video ID: SzRSjTnZVyE
# Fetched and cached data for video ID: Zr74rrPxLYw
# Fetched and cached data for video ID: m6ls4U_WJyU
# Fetched and cached data for video ID: KZm3K6m-2Ko
# Fetched and cached data for video ID: FcITwqdyZL8
# Fetched and cached data for video ID: jCQv-eoocg4
# Fetched and cached data for video ID: FI5smFzf8oI
# Fetched and cached data for video ID: SJy4VcKwf0E
# Fetched and cached data for video ID: eL4eZcm2TIo
# Using cached data for video ID: FI5smFzf8oI
# Fetched and cached data for video ID: qvB6fMAMy-k
# Fetched and cached data for video ID: f3WTGcLhYI0
# Fetched and cached data for video ID: OVuXZZCKCYw
# Fetched and cached data for video ID: iUajtbS3AlQ
# Fetched and cached data for video ID: Vhu17FezflY
# Fetched and cached data for video ID: TxaE5fVl9y4
# Fetched and cached data for video ID: upk-uGr_Jh0
# Fetched and cached data for video ID: LzvOubCpYqE
# Fetched and cached data for video ID: LfzRabBfNCg
# Fetched and cached data for video ID: dJblS-ss_Xg
# Fetched and cached data for video ID: d433xw7H-Uc
# Fetched and cached data for video ID: JsQ_TX8fd3I
# Fetched and cached data for video ID: EIp69A-Gwf4
# Fetched and cached data for video ID: eUQXtFEThGA
# Fetched and cached data for video ID: vhY58719wKk
# Fetched and cached data for video ID: enEiDVFl_Fo
# Fetched and cached data for video ID: q0RvRYI70UQ
# Fetched and cached data for video ID: mGvy_i-5hXc
# Fetched and cached data for video ID: ATJNSXNNy9g
# Fetched and cached data for video ID: iT69ywltEk0
# Fetched and cached data for video ID: V56ueIG_MoM
# Fetched and cached data for video ID: jb-SC1Yyl3o
# Fetched and cached data for video ID: bb0nQfFs8p8
# Fetched and cached data for video ID: 6Xdt7GoFn2w
# Fetched and cached data for video ID: okkOC2RVxf4
# Fetched and cached data for video ID: maGccSOoVrQ
# Fetched and cached data for video ID: BX_tk-xsurg
# Fetched and cached data for video ID: QW9QBdddRAE
# Fetched and cached data for video ID: 6dFPyzzTJYk
# Fetched and cached data for video ID: J-MvXJWYASo
# Fetched and cached data for video ID: ZOBdeoTlViA
# Fetched and cached data for video ID: FdJIUDbuQB8
# Fetched and cached data for video ID: W4FcOmnWBSE
# Fetched and cached data for video ID: RxOQNCtIhMA
# Fetched and cached data for video ID: 5WLUE4wn0D8
# Error fetching transcript for video H8cvIbUVKRk:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=H8cvIbUVKRk! This is most likely caused by:
#
# No transcripts were found for any of the requested language codes: ['en']
#
# For this video (H8cvIbUVKRk) transcripts are available in the following languages:
#
# (MANUALLY CREATED)
# None
#
# (GENERATED)
#  - ko ("Korean (auto-generated)")[TRANSLATABLE]
#
# (TRANSLATION LANGUAGES)
#  - ab ("Abkhazian")
#  - aa ("Afar")
#  - af ("Afrikaans")
#  - ak ("Akan")
#  - sq ("Albanian")
#  - am ("Amharic")
#  - ar ("Arabic")
#  - hy ("Armenian")
#  - as ("Assamese")
#  - ay ("Aymara")
#  - az ("Azerbaijani")
#  - bn ("Bangla")
#  - ba ("Bashkir")
#  - eu ("Basque")
#  - be ("Belarusian")
#  - bho ("Bhojpuri")
#  - bs ("Bosnian")
#  - br ("Breton")
#  - bg ("Bulgarian")
#  - my ("Burmese")
#  - ca ("Catalan")
#  - ceb ("Cebuano")
#  - zh-Hans ("Chinese (Simplified)")
#  - zh-Hant ("Chinese (Traditional)")
#  - co ("Corsican")
#  - hr ("Croatian")
#  - cs ("Czech")
#  - da ("Danish")
#  - dv ("Divehi")
#  - nl ("Dutch")
#  - dz ("Dzongkha")
#  - en ("English")
#  - eo ("Esperanto")
#  - et ("Estonian")
#  - ee ("Ewe")
#  - fo ("Faroese")
#  - fj ("Fijian")
#  - fil ("Filipino")
#  - fi ("Finnish")
#  - fr ("French")
#  - gaa ("Ga")
#  - gl ("Galician")
#  - lg ("Ganda")
#  - ka ("Georgian")
#  - de ("German")
#  - el ("Greek")
#  - gn ("Guarani")
#  - gu ("Gujarati")
#  - ht ("Haitian Creole")
#  - ha ("Hausa")
#  - haw ("Hawaiian")
#  - iw ("Hebrew")
#  - hi ("Hindi")
#  - hmn ("Hmong")
#  - hu ("Hungarian")
#  - is ("Icelandic")
#  - ig ("Igbo")
#  - id ("Indonesian")
#  - iu ("Inuktitut")
#  - ga ("Irish")
#  - it ("Italian")
#  - ja ("Japanese")
#  - jv ("Javanese")
#  - kl ("Kalaallisut")
#  - kn ("Kannada")
#  - kk ("Kazakh")
#  - kha ("Khasi")
#  - km ("Khmer")
#  - rw ("Kinyarwanda")
#  - ko ("Korean")
#  - kri ("Krio")
#  - ku ("Kurdish")
#  - ky ("Kyrgyz")
#  - lo ("Lao")
#  - la ("Latin")
#  - lv ("Latvian")
#  - ln ("Lingala")
#  - lt ("Lithuanian")
#  - lua ("Luba-Lulua")
#  - luo ("Luo")
#  - lb ("Luxembourgish")
#  - mk ("Macedonian")
#  - mg ("Malagasy")
#  - ms ("Malay")
#  - ml ("Malayalam")
#  - mt ("Maltese")
#  - gv ("Manx")
#  - mi ("Māori")
#  - mr ("Marathi")
#  - mn ("Mongolian")
#  - mfe ("Morisyen")
#  - ne ("Nepali")
#  - new ("Newari")
#  - nso ("Northern Sotho")
#  - no ("Norwegian")
#  - ny ("Nyanja")
#  - oc ("Occitan")
#  - or ("Odia")
#  - om ("Oromo")
#  - os ("Ossetic")
#  - pam ("Pampanga")
#  - ps ("Pashto")
#  - fa ("Persian")
#  - pl ("Polish")
#  - pt ("Portuguese")
#  - pt-PT ("Portuguese (Portugal)")
#  - pa ("Punjabi")
#  - qu ("Quechua")
#  - ro ("Romanian")
#  - rn ("Rundi")
#  - ru ("Russian")
#  - sm ("Samoan")
#  - sg ("Sango")
#  - sa ("Sanskrit")
#  - gd ("Scottish Gaelic")
#  - sr ("Serbian")
#  - crs ("Seselwa Creole French")
#  - sn ("Shona")
#  - sd ("Sindhi")
#  - si ("Sinhala")
#  - sk ("Slovak")
#  - sl ("Slovenian")
#  - so ("Somali")
#  - st ("Southern Sotho")
#  - es ("Spanish")
#  - su ("Sundanese")
#  - sw ("Swahili")
#  - ss ("Swati")
#  - sv ("Swedish")
#  - tg ("Tajik")
#  - ta ("Tamil")
#  - tt ("Tatar")
#  - te ("Telugu")
#  - th ("Thai")
#  - bo ("Tibetan")
#  - ti ("Tigrinya")
#  - to ("Tongan")
#  - ts ("Tsonga")
#  - tn ("Tswana")
#  - tum ("Tumbuka")
#  - tr ("Turkish")
#  - tk ("Turkmen")
#  - uk ("Ukrainian")
#  - ur ("Urdu")
#  - ug ("Uyghur")
#  - uz ("Uzbek")
#  - ve ("Venda")
#  - vi ("Vietnamese")
#  - war ("Waray")
#  - cy ("Welsh")
#  - fy ("Western Frisian")
#  - wo ("Wolof")
#  - xh ("Xhosa")
#  - yi ("Yiddish")
#  - yo ("Yoruba")
#  - zu ("Zulu")
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: H8cvIbUVKRk
# Fetched and cached data for video ID: a2lUJe8IkLQ
# Fetched and cached data for video ID: -4Nxbu6gKbo
# Fetched and cached data for video ID: LKMYktXv6ts
# Fetched and cached data for video ID: 4J4bJEfE1RM
# Fetched and cached data for video ID: Jjn--6-Jc88
# Fetched and cached data for video ID: viB8HLEQdic
# Fetched and cached data for video ID: j_hgtV1EYH0
# Fetched and cached data for video ID: xQ2-mXEuNhI
# Fetched and cached data for video ID: 7PoAXxTB5pw
# Fetched and cached data for video ID: o8yjzL2pI5E
# Fetched and cached data for video ID: qUl6qQLcGvo
# Fetched and cached data for video ID: otp-eG8pjNI
# Fetched and cached data for video ID: a0nrn-Kw16A
# Fetched and cached data for video ID: 8d5yRV9Yu6M
# Using cached data for video ID: otp-eG8pjNI
# Fetched and cached data for video ID: ZTCoXp-6IOg
# Fetched and cached data for video ID: cZgCk-b8DLI
# Fetched and cached data for video ID: LTGNBSkOkgE
# Fetched and cached data for video ID: -t9I8DmoWe4
# Fetched and cached data for video ID: i1IJystU1uo
# Fetched and cached data for video ID: UsNLjb-HRj8
# Fetched and cached data for video ID: t9UmXPCUN1Q
# Fetched and cached data for video ID: f_Ru1b92ECo
# Fetched and cached data for video ID: xruHcvyEcLY
# Fetched and cached data for video ID: AO4Ctm5Rz8I
# Fetched and cached data for video ID: DEW4yyDSXRU
# Fetched and cached data for video ID: S5fd2RfFrJk
# Fetched and cached data for video ID: JHIZ9NEQU4E
# Fetched and cached data for video ID: dGln2chcHl0
# Fetched and cached data for video ID: o44Hta0XT1w
# Fetched and cached data for video ID: SWutjTMILYQ
# Fetched and cached data for video ID: BNzwl6M-kO8
# Fetched and cached data for video ID: AjefLEkw6qM
# Fetched and cached data for video ID: 48LcTDSscU4
# Fetched and cached data for video ID: EDQ7ouP84ZY
# Fetched and cached data for video ID: 5WxtLfMJC2g
# Fetched and cached data for video ID: YkD0ysw-nJ8
# Fetched and cached data for video ID: Xm6IeSxVzgs
# Fetched and cached data for video ID: P5myiyazLzk
# Fetched and cached data for video ID: cdWAVVGZ2OQ
# Fetched and cached data for video ID: pcLPYNkQRFU
# Fetched and cached data for video ID: do7mwcaESdw
# Fetched and cached data for video ID: MZbWuEOwkxk
# Fetched and cached data for video ID: H-ye25g2cj4
# Fetched and cached data for video ID: BwSatBeSm8k
# Fetched and cached data for video ID: OUr_zHIP3D0
# Error fetching transcript for video UIsRPWkDTeQ:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=UIsRPWkDTeQ! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: UIsRPWkDTeQ
# Fetched and cached data for video ID: P-MqmsYcaaE
# Fetched and cached data for video ID: QpYt-93ixcc
# Fetched and cached data for video ID: bCwCnLB3j3g
# Fetched and cached data for video ID: Kx4unQUFrj8
# Fetched and cached data for video ID: pRyVuL_I_nU
# Fetched and cached data for video ID: fxr5quIBZ6w
# Fetched and cached data for video ID: 4wDmHXISP5o
# Fetched and cached data for video ID: aDBlBFR3Qq4
# Fetched and cached data for video ID: TvmaQRXebtE
# Fetched and cached data for video ID: xyIBMm8oMFc
# Fetched and cached data for video ID: Sjv9wRBjOWM
# Fetched and cached data for video ID: 4LTd6dedmvc
# Fetched and cached data for video ID: eRVt2msKNVg
# Fetched and cached data for video ID: 3jjjKrsXLvE
# Fetched and cached data for video ID: b08LN-xJf2o
# Fetched and cached data for video ID: mrqE6yMRUsU
# Fetched and cached data for video ID: MTm22n8fKcs
# Fetched and cached data for video ID: 5BDQSEl7iMM
# Fetched and cached data for video ID: 18URp4JDibE
# Fetched and cached data for video ID: YmK5GL6IxUc
# Fetched and cached data for video ID: ArKpfWJEDlI
# Fetched and cached data for video ID: Hz2B8LIvAHY
# Fetched and cached data for video ID: dXK56i7DB70
# Fetched and cached data for video ID: EjVBDtFNuKE
# Fetched and cached data for video ID: 6rgSpWvRHaQ
# Fetched and cached data for video ID: Ti002_qhP7k
# Fetched and cached data for video ID: UypTwXu5jzU
# Fetched and cached data for video ID: 7wX9KpTq6qk
# Fetched and cached data for video ID: kE6ynY8DFXU
# Fetched and cached data for video ID: aa2mpNvQfAU
# Fetched and cached data for video ID: ssjV5K4RUoE
# Fetched and cached data for video ID: En4TqrK7F9o
# Fetched and cached data for video ID: aCKKvx-1uq4
# Fetched and cached data for video ID: PXdHheN9mmU
# Fetched and cached data for video ID: MZu9mjRicPo
# Error fetching transcript for video KvkZ2bl8G3Q:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=KvkZ2bl8G3Q! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached data for video ID: KvkZ2bl8G3Q
# Fetched and cached data for video ID: umH6yTFahnk
# Fetched and cached data for video ID: 2UpnIA0xZ_Y
# Fetched and cached data for video ID: T3f1q5RnFiA
# Fetched and cached data for video ID: 9cLOY-w47H0
# Fetched and cached data for video ID: nUYy1I6qVYk
# Fetched and cached data for video ID: hUWe7koKqp0
# Fetched and cached data for video ID: cA9BmcyNXCw
# Fetched and cached data for video ID: C6y6yPcwDZE
# Fetched and cached data for video ID: ArLoX2nPvg4
# Fetched and cached data for video ID: 3rQwYeVcvu4
# Fetched and cached data for video ID: kN0vapQMFuI
# Fetched and cached data for video ID: oL0iIu3R6ws
# Fetched and cached data for video ID: IEHUoVlVGOk
# Fetched and cached data for video ID: fFNfwnkuNIU
# Fetched and cached data for video ID: kw12AtaX2Zs
# Fetched and cached data for video ID: TJy8oVN5QVo
# Fetched and cached data for video ID: 0pkJVif2htM
# Fetched and cached data for video ID: empqmvxkJNw
# Fetched and cached data for video ID: eGwQY9553HA
# Fetched and cached data for video ID: 1wlCUphcE2U
# Fetched and cached data for video ID: yVlxS6Rqtg8
# Fetched and cached data for video ID: fReJZT-6ra0
# Fetched and cached data for video ID: 9UKwYpgqX4w
# Fetched and cached data for video ID: rKrxa8wHrI0
# Fetched and cached data for video ID: giTy85RANs4
# Fetched and cached data for video ID: LJhLhfgL3Og
# Fetched and cached data for video ID: 3DIVdqFfcwY
# Total videos processed: 498
# Data saved to cache\ytb_search_results_lululemon_align_pants.csv
#             product_type product_name     video_id  \
# 0  Lululemon Align Pants               pE-jNu4i19M
# 1  Lululemon Align Pants               2Ji7P37kGzg
# 2  Lululemon Align Pants               sNZYR0gl7zo
# 3  Lululemon Align Pants               DTfjUYtZvWU
# 4  Lululemon Align Pants               iy5Saa_h9Mo
#
#                                      video_url  \
# 0  https://www.youtube.com/watch?v=pE-jNu4i19M
# 1  https://www.youtube.com/watch?v=2Ji7P37kGzg
# 2  https://www.youtube.com/watch?v=sNZYR0gl7zo
# 3  https://www.youtube.com/watch?v=DTfjUYtZvWU
# 4  https://www.youtube.com/watch?v=iy5Saa_h9Mo
#
#                                          video_title  \
# 0  What does it cost to make Lululemon Align legg...
# 1  LULULEMON LEGGINGS EXPLAINED | What You Need t...
# 2   LULULEMON ALIGN VS WUNDER TRAIN LEGGINGS UPDATED
# 3  LULULEMON *Align* vs. *Wunder Train* 23&quot; ...
# 4  NEW LULULEMON LEGGING! WUNDER UNDER EVERLUX HI...
#
#                                    video_description      video_channel  \
# 0  Instagram / Tik Tok: @Shiftfashiongroup Joe's ...  Shiftfashiongroup
# 1  LULULEMON LEGGINGS EXPLAINED | What You Need t...       Gabi LeMoine
# 2  Hi Hi Hi! Lululemon switched up their wunder t...               Maya
# 3  Get at least $30 on your 1st purchase via Raku...   Tawny Alessandra
# 4  Lululemon Wunder Under Everlux High Rise Tight...            Lindsey
#
#            video_channel_id       video_published  \
# 0  UC5Bs2BXfOU8VdQDNBIjHEew  2023-10-02T23:00:06Z
# 1  UCAlwbNvolMosuxPfanc-jLQ  2024-01-20T00:00:01Z
# 2  UCg8mp8FO35KOeJeEbcJm9hg  2023-03-17T15:00:44Z
# 3  UCNHIo8cvEL-Flfg-YdJRyrg  2023-07-05T21:06:25Z
# 4  UCrH9u6Q6SP-ZkceP4N58Seg  2024-10-03T19:00:23Z
#
#                                   video_thumbnail  ... madeForKids  \
# 0  https://i.ytimg.com/vi/pE-jNu4i19M/default.jpg  ...       False
# 1  https://i.ytimg.com/vi/2Ji7P37kGzg/default.jpg  ...       False
# 2  https://i.ytimg.com/vi/sNZYR0gl7zo/default.jpg  ...       False
# 3  https://i.ytimg.com/vi/DTfjUYtZvWU/default.jpg  ...       False
# 4  https://i.ytimg.com/vi/iy5Saa_h9Mo/default.jpg  ...       False
#
#   privacyStatus viewCount likeCount commentCount dislikeCount favoriteCount  \
# 0        public     14094       290           19         None             0
# 1        public     23835       367           44         None             0
# 2        public     37272       281           41         None             0
# 3        public     10602        73            2         None             0
# 4        public      4705        63           10         None             0
#
#   paidProductPlacement transcript transcript_is_generated
# 0                False       None                    None
# 1                False       None                    None
# 2                False       None                    None
# 3                False       None                    None
# 4                False       None                    None
#
# [5 rows x 35 columns]
# Finished processing Lululemon Align Pants videos. Total videos: 498

# %%
def fetch_metadata_for_dataframe(df: pd.DataFrame, category: str) -> pd.DataFrame:
    """
    Fetch metadata for all videos in a DataFrame and update the cache.
    """
    # Define cache file path
    metadata_cache_file = os.path.join(CACHE_DIR, f"video_info_cache_{category}.json")

    # Load cache if it exists, or initialize an empty cache
    if os.path.exists(metadata_cache_file):
        with open(metadata_cache_file, "r") as f:
            video_info_cache = json.load(f)
    else:
        video_info_cache = {}

    # Initialize yt-dlp
    ydl_opts = {"quiet": True}
    ydl = YoutubeDL(ydl_opts)

    # Fetch metadata for each video
    metadata_list = []
    for idx, video_id in enumerate(df["video_id"]):
        metadata = fetch_video_metadata(video_id, ydl, metadata_cache_file, video_info_cache)
        metadata_list.append(metadata)

        # Save cache every 10 iterations
        if idx % 10 == 0:
            with open(metadata_cache_file, "w") as f:
                json.dump(video_info_cache, f, indent=4)

        # Delay to avoid rate limiting
        # time.sleep(1)

    # Final save of metadata cache
    with open(metadata_cache_file, "w") as f:
        json.dump(video_info_cache, f, indent=4)

    # Add metadata to the DataFrame
    df["metadata"] = metadata_list
    return df

# Example usage
if __name__ == "__main__":
    product_type = "lululemon align pants"
    ytb_search_df = fetch_and_process_videos(product_type=product_type, videos_count=500)

    # Fetch metadata as a post-processing step
    ytb_search_df = fetch_metadata_for_dataframe(ytb_search_df, category="fashion_50")

    # Save the updated DataFrame
    output_file = os.path.join(CACHE_DIR, f"ytb_search_results_with_metadata_{product_type.replace(' ', '_').lower()}.csv")
    ytb_search_df.to_csv(output_file, index=False)
    print(f"Data with metadata saved to {output_file}")

# %% [markdown]
# # Clean text dataset

# %%
import pandas as pd

def add_cols(df: pd.DataFrame) -> pd.DataFrame:
    """
    Add new columns to the DataFrame and clean existing ones.
    """
    # Convert duration to seconds (e.g., PT4M20S to 260)
    try:
        df["duration_seconds"] = df["duration"].apply(lambda x: pd.to_timedelta(x).seconds)
    except Exception as e:
        print(f"Error converting duration to seconds: {e}")
        df["duration_seconds"] = None  # Fallback to None if conversion fails

    # Convert 'video_published' to datetime format
    df["video_published"] = pd.to_datetime(df["video_published"], errors="coerce")

    # Check for invalid dates
    if df["video_published"].isnull().any():
        print("Warning: Some values in 'video_published' could not be converted to datetime!")

    # Extract 'publish_month' in 'YYYY-MM' format
    df["publish_month"] = df["video_published"].dt.strftime("%Y-%m")

    # Convert numeric columns to numeric type
    numeric_cols = ["viewCount", "likeCount", "commentCount", "duration_seconds"]
    for col in numeric_cols:
        df[col] = pd.to_numeric(df[col], errors="coerce")

    # Sort the DataFrame by 'viewCount' in descending order
    df_sorted = df.sort_values(by=["viewCount"], ascending=False)
    return df_sorted

def drop_cols_rows(df: pd.DataFrame) -> pd.DataFrame:
    """
    Drop unnecessary columns and rows, and clean the DataFrame.
    """
    # Drop columns with all null values
    df = df.dropna(axis=1, how="all")

    # Drop rows with all null values
    df = df.dropna(how="all")

    # Drop duplicates, reset index, and sort by 'viewCount'
    df = df.drop_duplicates().reset_index(drop=True).sort_values(by=["viewCount"], ascending=False)
    # drop unnecessary columns
    try:
        df = df.drop(['liveBroadcastContent', 'contentRating', 'video_channel', 'title', 'video_channel_id', 'privacyStatus'], axis=1)
    except KeyError:
        pass

    # drop rows with null values in 'transcript'
    df = df.dropna(subset=["transcript"])

    
    # drop dumplicate columns
    df = df.loc[:,~df.columns.duplicated()]
    return df

# %%
# load the data
import glob
import os

csv_search_files = glob.glob(os.path.join(CACHE_DIR, "ytb_search_results*.csv"))
csv_search_files
# Out:
# ['cache\\ytb_search_results_apple_airtag.csv',
#  'cache\\ytb_search_results_cosrx_snail_mucin_serum.csv',
#  'cache\\ytb_search_results_liquid_death.csv',
#  'cache\\ytb_search_results_meta_quest_3.csv',
#  'cache\\ytb_search_results_samsung_galaxy_watch_7.csv',
#  'cache\\ytb_search_results_samsung_oled_tv.csv',
#  'cache\\ytb_search_results_stanley_tumbler.csv',
#  'cache\\ytb_search_results_tesla_model_y.csv']

# %%
csv_search_files[0]
# Out:
# 'cache\\ytb_search_results_apple_airtag.csv'

# %%
pd.read_csv(csv_search_files[1]).columns
# Out:
# Index(['product_type', 'video_id', 'video_url', 'video_title',
#        'video_description', 'video_channel', 'video_channel_id',
#        'video_published', 'video_thumbnail', 'title', 'description',
#        'channelTitle', 'publishTime', 'channelId', 'thumbnail', 'tags',
#        'topicCategories', 'categoryId', 'liveBroadcastContent', 'duration',
#        'has_caption', 'licensedContent', 'definition', 'contentRating',
#        'madeForKids', 'privacyStatus', 'viewCount', 'likeCount',
#        'commentCount', 'favoriteCount', 'paidProductPlacement', 'transcript',
#        'transcript_is_generated', 'duration_seconds', 'publish_month'],
#       dtype='object')

# %%
# clean the data and save it
for csv_search_file in csv_search_files:
    df = pd.read_csv(csv_search_file)
    df = add_cols(df)
    df = drop_cols_rows(df)
    name_f = "cleaned_" + os.path.basename(csv_search_file)
    df.to_csv(os.path.join(CACHE_DIR, name_f), index=False)
    print(f"Data cleaned and saved to {os.path.join(CACHE_DIR, name_f)}")
    # remove timezone information
    df["video_published"] = df["video_published"].dt.tz_localize(None)
    # save to excel
    df.to_excel(os.path.join(CACHE_DIR, name_f.replace(".csv", ".xlsx")), index=False)
    print(f"Data cleaned and saved to {os.path.join(CACHE_DIR, name_f.replace('.csv', '.xlsx'))}")
# Out:
# Data cleaned and saved to cache\cleaned_ytb_search_results_apple_airtag.csv
# Data cleaned and saved to cache\cleaned_ytb_search_results_apple_airtag.xlsx
# Data cleaned and saved to cache\cleaned_ytb_search_results_cosrx_snail_mucin_serum.csv
# Data cleaned and saved to cache\cleaned_ytb_search_results_cosrx_snail_mucin_serum.xlsx
# Data cleaned and saved to cache\cleaned_ytb_search_results_liquid_death.csv
# Data cleaned and saved to cache\cleaned_ytb_search_results_liquid_death.xlsx
# Data cleaned and saved to cache\cleaned_ytb_search_results_meta_quest_3.csv
# Data cleaned and saved to cache\cleaned_ytb_search_results_meta_quest_3.xlsx
# Data cleaned and saved to cache\cleaned_ytb_search_results_samsung_galaxy_watch_7.csv
# Data cleaned and saved to cache\cleaned_ytb_search_results_samsung_galaxy_watch_7.xlsx
# Data cleaned and saved to cache\cleaned_ytb_search_results_samsung_oled_tv.csv
# Data cleaned and saved to cache\cleaned_ytb_search_results_samsung_oled_tv.xlsx
# Data cleaned and saved to cache\cleaned_ytb_search_results_stanley_tumbler.csv
# Data cleaned and saved to cache\cleaned_ytb_search_results_stanley_tumbler.xlsx
# Data cleaned and saved to cache\cleaned_ytb_search_results_tesla_model_y.csv
# Data cleaned and saved to cache\cleaned_ytb_search_results_tesla_model_y.xlsx
