# %% [markdown]
# # Setting and suporting functions

# %%
import os
from dotenv import load_dotenv
from googleapiclient.discovery import build
from youtube_transcript_api import YouTubeTranscriptApi
import pandas as pd
import time
import json
from typing import List, Dict, Optional
from yt_dlp import YoutubeDL
# Load environment variables
load_dotenv()

# Get YouTube API key
API_KEY = os.getenv("H_YOUTUBE_API_KEY")
if not API_KEY:
    raise ValueError("API key not found. Please ensure the '.env' file is set up correctly.")
youtube = build("youtube", "v3", developerKey=API_KEY)

# Constants
MAX_RESULTS_PER_PAGE = 50
CACHE_DIR = "cache"
os.makedirs(CACHE_DIR, exist_ok=True)

# %%
# Supporting Functions

def get_video_stats(video_id: str) -> Optional[Dict]:
    """
    Fetch statistics for a given video ID.
    """
    try:
        response = youtube.videos().list(
            part="snippet,statistics,contentDetails,liveStreamingDetails,paidProductPlacementDetails,status,topicDetails",
            id=video_id
        ).execute()
    except Exception as e:
        print(f"Error fetching video data: {e}")
        return None

    if not response.get("items"):
        print(f"No video found with ID: {video_id}")
        return None

    video_data = response["items"][0]
    return {
        "title": video_data.get("snippet", {}).get("title", ""),
        "description": video_data.get("snippet", {}).get("description", ""),
        "channelTitle": video_data.get("snippet", {}).get("channelTitle", ""),
        "publishTime": video_data.get("snippet", {}).get("publishedAt", ""),
        "channelId": video_data.get("snippet", {}).get("channelId", ""),
        "thumbnail": video_data.get("snippet", {}).get("thumbnails", {}).get("standard", {}).get("url", ""),
        "tags": video_data.get("snippet", {}).get("tags", []),
        "topicCategories": video_data.get("topicDetails", {}).get("topicCategories", []),
        "categoryId": video_data.get("snippet", {}).get("categoryId", None),
        "liveBroadcastContent": video_data.get("snippet", {}).get("liveBroadcastContent", None),
        "duration": video_data.get("contentDetails", {}).get("duration", None),
        "has_caption": video_data.get("contentDetails", {}).get("caption", None),
        "licensedContent": video_data.get("contentDetails", {}).get("licensedContent", None),
        "definition": video_data.get("contentDetails", {}).get("definition", None),
        "contentRating": video_data.get("contentDetails", {}).get("contentRating", None),
        "madeForKids": video_data.get("status", {}).get("madeForKids", None),
        "privacyStatus": video_data.get("status", {}).get("privacyStatus", None),
        "viewCount": video_data.get("statistics", {}).get("viewCount", None),
        "likeCount": video_data.get("statistics", {}).get("likeCount", None),
        "commentCount": video_data.get("statistics", {}).get("commentCount", None),
        "dislikeCount": video_data.get("statistics", {}).get("dislikeCount", None),
        "favoriteCount": video_data.get("statistics", {}).get("favoriteCount", None),
        "paidProductPlacement": video_data.get("paidProductPlacementDetails", {}).get("hasPaidProductPlacement", None)
    }

def get_channel_stats(channel_id: str) -> Optional[Dict]:
    """
    Fetch statistics for a given channel ID.
    """
    try:
        response = youtube.channels().list(
            part="snippet,statistics,contentDetails,topicDetails",
            id=channel_id
        ).execute()
    except Exception as e:
        print(f"Error fetching channel data: {e}")
        return None

    if not response.get("items"):
        print(f"No channel found with ID: {channel_id}")
        return None

    channel_data = response["items"][0]
    return {
        "channel_title": channel_data["snippet"]["title"],
        "channel_description": channel_data["snippet"]["description"],
        "channel_custom_url": channel_data["snippet"]["customUrl"],
        "channel_thumbnail": channel_data["snippet"]["thumbnails"]["default"]["url"],
        "channel_published_at": channel_data["snippet"]["publishedAt"],
        "channel_view_count": channel_data["statistics"].get("viewCount", None),
        "channel_subscriber_count": channel_data["statistics"].get("subscriberCount", None),
        "channel_video_count": channel_data["statistics"].get("videoCount", None),
        "channel_playlist_count": channel_data["statistics"].get("playlistCount", None),
        "channel_comment_count": channel_data["statistics"].get("commentCount", None),
        "channel_live_count": channel_data["statistics"].get("liveCount", None),
        "channel_topic_categories": channel_data["topicDetails"].get("topicCategories", []),
        "channel_topic_ids": channel_data["topicDetails"].get("topicIds", []),
        "channel_country": channel_data["snippet"].get("country", None),
    }

def get_comments(video_id: str, cmt_count: int = 200, max_results: int = 100) -> Dict:
    """
    Fetch comments for a given video ID.
    """
    all_comments = []
    next_page_token = None
    search_pages = (cmt_count // max_results) + (1 if cmt_count % max_results else 0)

    for i in range(search_pages):
        try:
            comment_request = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                pageToken=next_page_token,
                textFormat="plainText",
                maxResults=max_results,
                order="relevance"
            )
            comment_response = comment_request.execute()

            for item in comment_response['items']:
                top_comment = item['snippet']['topLevelComment']['snippet']
                all_comments.append({
                    'Timestamp': top_comment['publishedAt'],
                    'Username': top_comment['authorDisplayName'],
                    'VideoID': video_id,
                    'Comment': top_comment['textDisplay'],
                    'Date': top_comment.get('updatedAt', top_comment['publishedAt']),
                    "likeCount": top_comment["likeCount"],
                    "totalReplyCount": item["snippet"]["totalReplyCount"],
                })
            print(f"Page {i + 1} of comments fetched for video {video_id}")
            next_page_token = comment_response.get('nextPageToken')
            if not next_page_token:
                break
        except Exception as e:
            print(f"Error fetching comments for video {video_id}: {e}")
            break

    return {"top_comments": all_comments}

def get_transcript(video_id: str) -> Dict:
    """
    Fetch transcript for a given video ID.
    """
    try:
        transcript_list = YouTubeTranscriptApi.list_transcripts(video_id)
        transcript = transcript_list.find_transcript(['en'])
        transcript_src = transcript.fetch()
        transcript_txt = " ".join([line['text'] for line in transcript_src])
        return {"transcript": transcript_txt, "transcript_is_generated": transcript.is_generated}
    except Exception as e:
        print(f"Error fetching transcript for video {video_id}: {e}")
        return {"transcript": None, "transcript_is_generated": None}

def fetch_video_page(youtube, keyword: str, order: str, region: str, language: str, video_duration: str, 
                     published_start: str, published_end: str, video_quality: str, token: Optional[str] = None) -> Dict:
    """
    Fetch a single page of video search results from the YouTube API.
    """
    try:
        request = youtube.search().list(
            part="snippet",
            maxResults=MAX_RESULTS_PER_PAGE,
            q=keyword,
            order=order,
            type="video",
            regionCode=region,
            relevanceLanguage=language,
            videoDuration=video_duration,
            publishedAfter=published_start,
            publishedBefore=published_end,
            pageToken=token,
            videoDefinition=video_quality
        )
        return request.execute()
    except Exception as e:
        print(f"Error fetching video page: {e}")
        return {}

def extract_video_data(item: Dict, product_type: str, product_name: str) -> Dict:
    """
    Extract relevant video data from a single API response item.
    """
    return {
        "product_type": product_type,
        "product_name": product_name,
        "video_id": item["id"]["videoId"],
        "video_url": f"https://www.youtube.com/watch?v={item['id']['videoId']}",
        "video_title": item["snippet"]["title"],
        "video_description": item["snippet"]["description"],
        "video_channel": item["snippet"]["channelTitle"],
        "video_channel_id": item["snippet"]["channelId"],
        "video_published": item["snippet"]["publishedAt"],
        "video_thumbnail": item["snippet"]["thumbnails"]["default"]["url"]
    }

def save_to_cache(cache_file: str, keyword: str, response_list: List[Dict]) -> None:
    """
    Save the API response to a cache file.
    """
    cache_json = {'keyword': keyword, 'response_list': response_list}
    with open(cache_file, 'w') as f:
        json.dump(cache_json, f, indent=4, ensure_ascii=False)

def load_cache(cache_file: str) -> Dict:
    """
    Load cache from a file.
    """
    if os.path.exists(cache_file):
        with open(cache_file, "r") as f:
            return json.load(f)
    return {}

def update_cache(video_stats_cache: Dict, video_id: str, video_stats: Dict, cache_file: str) -> None:
    """
    Update cache with new video stats.
    """
    video_stats_cache[video_id] = video_stats
    with open(cache_file, "w") as f:
        json.dump(video_stats_cache, f)

def search_videos_by_keyword(youtube, product_type: str, product_name: str, region: str = 'US', language: str = "en", 
                            video_quality: str = "any", video_duration: str = "any", videos_count: int = 100, 
                            order: str = "viewCount", published_start: str = '2023-01-01T00:00:00Z', 
                            published_end: str = '2024-12-31T23:59:59Z', token: Optional[str] = None) -> List[Dict]:
    """
    Search for videos by keyword and return a list of video data.
    """
    keyword = f"{product_type} review"
    cache_file = os.path.join(CACHE_DIR, f'ytb_search_cache_{product_type}.json')
    # if cache_file exist load from cache file instead:
    response_list = load_cache(cache_file)
    if not response_list:
        response_list = []
    
        pages = (videos_count // MAX_RESULTS_PER_PAGE) + (1 if videos_count % MAX_RESULTS_PER_PAGE else 0)

        for i in range(pages):
            response = fetch_video_page(youtube, keyword, order, region, language, video_duration, 
                                    published_start, published_end, video_quality, token)
            if not response:
                break

            response_list.append(response)
            print(f"Page {i+1}: {response['pageInfo']['totalResults']} videos found. Next page token: {response.get('nextPageToken')}")

            token = response.get("nextPageToken")
            if not token:
                break
            # time.sleep(1)  # Avoid hitting API rate limits

        save_to_cache(cache_file, keyword, response_list)

    ytb_search_data = []
    for response in response_list:
        for item in response.get("items", []):
            video_data = extract_video_data(item, product_type, product_name)
            ytb_search_data.append(video_data)

    return ytb_search_data

def process_video_results(all_search_results: List[Dict], cache_file: str) -> List[Dict]:
    """
    Process video results, fetch stats, and update cache.
    """
    video_stats_cache = load_cache(cache_file)
    testing_search = []

    for result in all_search_results:
        video_id = result["video_id"]
        if video_id in video_stats_cache:
            print(f"Using cached data for video ID: {video_id}")
            video_stats = video_stats_cache[video_id]
        else:
            video_stats = get_video_stats(video_id)
            if video_stats:
                update_cache(video_stats_cache, video_id, video_stats, cache_file)
                print(f"Fetched and cached data for video ID: {video_id}")
            else:
                print(f"Failed to fetch data for video ID: {video_id}")
                continue

        result.update(video_stats)
        testing_search.append(result)

    return testing_search

def fetch_and_process_videos(product_type: str, product_name: str = "", videos_count: int = 1000) -> pd.DataFrame:
    """
    Fetch videos, process stats, fetch transcripts, and save results to a CSV file.
    """
    # Define cache file paths
    product_type_file = product_type.replace(" ", "_").lower()
    cache_file = os.path.join(CACHE_DIR, f"video_stats_cache_{product_type_file}.json")
    output_file = os.path.join(CACHE_DIR, f"ytb_search_combined_results_{product_type_file}.csv")

    # Load cache if it exists, or initialize an empty cache
    if os.path.exists(cache_file):
        with open(cache_file, "r") as f:
            video_stats_cache = json.load(f)
    else:
        video_stats_cache = {}

    # Fetch videos by keyword
    print(f"Searching for videos related to '{product_type}'...")
    search_results = search_videos_by_keyword(
        youtube=youtube,
        product_type=product_type,
        product_name=product_name,
        videos_count=videos_count,
        order="relevance",
        region="US",
        language="en",
        video_duration="medium",
        published_start='2023-01-01T00:00:00Z',
        published_end='2024-12-31T23:59:59Z'
    )
    print(f"Found {len(search_results)} videos for {product_type}.")

    # Process each video
    all_search_results = []
    for result in search_results:
        video_id = result["video_id"]

        # Fetch video stats (from cache or API)
        if video_id in video_stats_cache:
            print(f"Using cached data for video ID: {video_id}")
            video_stats = video_stats_cache[video_id]
        else:
            video_stats = get_video_stats(video_id)
            if video_stats:
                # Fetch transcript
                transcript_data = get_transcript(video_id)
                video_stats.update(transcript_data)  # Add transcript to video stats

                # Update cache
                video_stats_cache[video_id] = video_stats
                with open(cache_file, "w") as f:
                    json.dump(video_stats_cache, f)
                print(f"Fetched and cached data for video ID: {video_id}")
            else:
                print(f"Failed to fetch data for video ID: {video_id}")
                continue  # Skip to the next result if API call fails

        # Update result with video stats and add to the list
        result.update(video_stats)
        all_search_results.append(result)

    print(f"Total videos processed: {len(all_search_results)}")

    # Convert to DataFrame and save
    ytb_search_df = pd.DataFrame(all_search_results)
    ytb_search_df.to_csv(output_file, index=False)
    print(f"Data saved to {output_file}")

    return ytb_search_df



def save_results_to_csv(testing_search: List[Dict], keyword: str) -> None:
    """
    Save results to a CSV file.
    """
    keyword_file = keyword.replace(" ", "_").lower()
    ytb_search_df = pd.DataFrame(testing_search)
    output_file = os.path.join(CACHE_DIR, f"ytb_search_results_{keyword_file}.csv")
    ytb_search_df.to_csv(output_file, index=False)
    print(f"Data saved to {output_file}")


def fetch_video_metadata(video_id: str, ydl: YoutubeDL, cache_file: str, video_info_cache: Dict) -> Optional[Dict]:
    """
    Fetch metadata for a video using yt-dlp and update the cache.
    """
    if video_id in video_info_cache:
        print(f"Skipping {video_id}: Already in cache.")
        return video_info_cache[video_id]

    url = f"https://www.youtube.com/watch?v={video_id}"
    try:
        print(f"Fetching info for {video_id}...")
        info = ydl.extract_info(url, download=False)
        video_info_cache[video_id] = info
        return info
    except Exception as e:
        print(f"Error fetching info for {video_id}: {e}")
        return None

# %%
if __name__ == "__main__":
    product_type_to_search = "Galaxy ZFlip 6"
    df = fetch_and_process_videos(product_type_to_search, videos_count=10) #small number for testing
    print(df.head())
# Out:
# Using cached search results from cache\ytb_search_cache_galaxy_zflip_6.json
# Using cached video stats for video ID: _wDMdqbhyrg
# Using cached video stats for video ID: XNyrZ8FMfMY
# Using cached video stats for video ID: 5t1okmz8Pyw
# Using cached video stats for video ID: ulXeKHtePDI
# Using cached video stats for video ID: 2GaS97uC77w
# Using cached video stats for video ID: oBP25Rvy_OI
# Using cached video stats for video ID: BsL-kXX3Ns8
# Using cached video stats for video ID: A763kAaz1SE
# Using cached video stats for video ID: iDxyFtsWkUY
# Using cached video stats for video ID: zijUjJdegI8
# Using cached video stats for video ID: MCxxpMXFTg4
# Using cached video stats for video ID: IdAl5O0YqAU
# Using cached video stats for video ID: DLzKXBAAEcU
# Using cached video stats for video ID: xQ0hJS41MdQ
# Using cached video stats for video ID: 9SVPHHFtScE
# Using cached video stats for video ID: B4bbF_lo9mk
# Using cached video stats for video ID: KYDsc5UEANU
# Using cached video stats for video ID: -dMTU6deTPA
# Using cached video stats for video ID: 4GoTAodrUCM
# Using cached video stats for video ID: KSuS7Exz_Dc
# Using cached video stats for video ID: 0A-NlCqQp8E
# Using cached video stats for video ID: Y9Ozk5GmsM0
# Using cached video stats for video ID: 1Bn-lDdG-V8
# Using cached video stats for video ID: M5c4TOJEnGU
# Using cached video stats for video ID: 0LljppFPBmo
# Using cached video stats for video ID: K71t3IKf4fE
# Using cached video stats for video ID: C5WhpbrpBRk
# Using cached video stats for video ID: ArCgXpiBFnE
# Using cached video stats for video ID: KT5jO384KpQ
# Using cached video stats for video ID: F_AbL9BILxo
# Using cached video stats for video ID: bVYhT5ct2-c
# Using cached video stats for video ID: BaIqSxKPQz0
# Fetched and cached video stats (including transcript) for video ID: _porpuSn0fk
# Fetched and cached video stats (including transcript) for video ID: ID5N4QuZ5x0
# Fetched and cached video stats (including transcript) for video ID: 9onbCHhtKjY
# Fetched and cached video stats (including transcript) for video ID: i8Q80a6pnbY
# Fetched and cached video stats (including transcript) for video ID: NOs4iW1T7oI
# Fetched and cached video stats (including transcript) for video ID: 4oDAERVgDXE
# Fetched and cached video stats (including transcript) for video ID: d_QKkmPACJ0
# Fetched and cached video stats (including transcript) for video ID: d1f8i-Y3zdU
# Fetched and cached video stats (including transcript) for video ID: 6gHQCvtLKCo
# Fetched and cached video stats (including transcript) for video ID: m-wkF0s0l6o
# Fetched and cached video stats (including transcript) for video ID: 9HDJfW4FZFA
# Fetched and cached video stats (including transcript) for video ID: remXTpVkcmI
# Fetched and cached video stats (including transcript) for video ID: QYLiG_YhgX0
# Fetched and cached video stats (including transcript) for video ID: _T0UUTjdIls
# Fetched and cached video stats (including transcript) for video ID: pnJYUjds4rE
# Fetched and cached video stats (including transcript) for video ID: FixzncGkp58
# Fetched and cached video stats (including transcript) for video ID: 5k6MwPqGdf8
# Fetched and cached video stats (including transcript) for video ID: pwBO1o6s0oM
# Total videos processed: 50
# Combined data saved to cache\ytb_search_combined_results_galaxy_zflip_6.csv
#      product_type product_name     video_id  \
# 0  Galaxy ZFlip 6               _wDMdqbhyrg
# 1  Galaxy ZFlip 6               XNyrZ8FMfMY
# 2  Galaxy ZFlip 6               5t1okmz8Pyw
# 3  Galaxy ZFlip 6               ulXeKHtePDI
# 4  Galaxy ZFlip 6               2GaS97uC77w
#
#                                      video_url  \
# 0  https://www.youtube.com/watch?v=_wDMdqbhyrg
# 1  https://www.youtube.com/watch?v=XNyrZ8FMfMY
# 2  https://www.youtube.com/watch?v=5t1okmz8Pyw
# 3  https://www.youtube.com/watch?v=ulXeKHtePDI
# 4  https://www.youtube.com/watch?v=2GaS97uC77w
#
#                                          video_title  \
# 0  Is The SAMSUNG Galaxy Z FLIP 6 Worth It? HONES...
# 1  Samsung Galaxy Z Flip 6 - Pros &amp; Con 69 Ho...
# 2  Samsung Z Flip 6 / Z Fold 6 Review - Don&#39;t...
# 3   Galaxy Z FLIP 6 Review | More Than Just CUTE Now
# 4                      Samsung Galaxy Z Flip6 review
#
#                                    video_description      video_channel  \
# 0  Grab the Samsung Z Flip 6! https://sovrn.co/1l...        Tech Fowler
# 1  Samsung Galaxy Z Flip 6, Samaung latest mini f...         HotshotTek
# 2  My full review of Samsung's new foldables - Z ...     Mrwhosetheboss
# 3  This is my review of the Samsung Galaxy Z Flip...    Created by Ella
# 4  The Galaxy Z Flip6 brings a few improvements t...  GSMArena Official
#
#            video_channel_id       video_published  \
# 0  UCwMbSEgxhmOB5dXcxRTKHJQ  2024-08-04T13:00:39Z
# 1  UClQQoervgLHV2pAOxHJ16NA  2024-07-20T00:40:46Z
# 2  UCMiJRAwDNSNzuYeN2uWa0pA  2024-08-01T11:46:53Z
# 3  UCfuwnVrJuKnqb-2hQZbctsQ  2024-07-29T13:00:58Z
# 4  UCbLq9tsbo8peV22VxbDAfXA  2024-07-24T18:01:03Z
#
#                                   video_thumbnail  ... madeForKids  \
# 0  https://i.ytimg.com/vi/_wDMdqbhyrg/default.jpg  ...       False
# 1  https://i.ytimg.com/vi/XNyrZ8FMfMY/default.jpg  ...       False
# 2  https://i.ytimg.com/vi/5t1okmz8Pyw/default.jpg  ...       False
# 3  https://i.ytimg.com/vi/ulXeKHtePDI/default.jpg  ...       False
# 4  https://i.ytimg.com/vi/2GaS97uC77w/default.jpg  ...       False
#
#   privacyStatus viewCount likeCount commentCount dislikeCount favoriteCount  \
# 0        public    416516      3529          407         None             0
# 1        public    188119      1630          193         None             0
# 2        public   2824050     80322         4741         None             0
# 3        public    320015     15904          519         None             0
# 4        public    304328      2870          252         None             0
#
#   paidProductPlacement                                         transcript  \
# 0                False  is the brand new Samsung Galaxy Z flip 6 I man...
# 1                False  okay maybe it's been 70 hours but still this s...
# 2                False  a few weeks ago I switched out my Samsung Gala...
# 3                False  this is the new Z flip 6 the flip form factor ...
# 4                False  [Music] it's that time of year again and we ha...
#
#   transcript_is_generated
# 0                    True
# 1                    True
# 2                    True
# 3                    True
# 4                    True
#
# [5 rows x 35 columns]

# %%
search_products = [
    "COSRX Snail Mucin Serum",
    "Tesla Model Y",
    "Samsung OLED TV",
    "Liquid Death",
    "Stanley tumbler",
    "Apple AirTag",
    "Meta quest 3",
    "Samsung Galaxy Watch 7",
    "Macbook Pro M4",
    "Lululemon Align Pants",
]

# %%
for keyword in search_products[7:]:
    ytb_search_df = fetch_and_process_videos(product_type=keyword, videos_count=500)
    print(ytb_search_df.head())
    print(f"Finished processing {keyword} videos. Total videos: {len(ytb_search_df)}")
# Out:
# Fetching search results from YouTube API for keyword: Samsung Galaxy Watch 7 review
# Page 1: 925858 videos found. Next page token: CDIQAA
# Page 2: 925858 videos found. Next page token: CGQQAA
# Page 3: 926810 videos found. Next page token: CJYBEAA
# Page 4: 925857 videos found. Next page token: CMgBEAA
# Page 5: 925857 videos found. Next page token: CPoBEAA
# Page 6: 925857 videos found. Next page token: CKwCEAA
# Page 7: 925857 videos found. Next page token: CN4CEAA
# Page 8: 925859 videos found. Next page token: CJADEAA
# Page 9: 925857 videos found. Next page token: CMIDEAA
# Page 10: 925857 videos found. Next page token: CPQDEAA
# Error fetching transcript for video GhZq1wwC82U:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=GhZq1wwC82U! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: GhZq1wwC82U
# Error fetching transcript for video fqPEXaKHPcs:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=fqPEXaKHPcs! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: fqPEXaKHPcs
# Fetched and cached video stats (including transcript) for video ID: UrmVFtSSvE0
# Error fetching transcript for video lHzzG496rR4:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=lHzzG496rR4! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: lHzzG496rR4
# Error fetching transcript for video _i6o2xOS3yQ:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=_i6o2xOS3yQ! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: _i6o2xOS3yQ
# Error fetching transcript for video 8pCLyj-dwFQ:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=8pCLyj-dwFQ! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: 8pCLyj-dwFQ
# Error fetching transcript for video 7noaPsX3bZI:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=7noaPsX3bZI! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: 7noaPsX3bZI
# Fetched and cached video stats (including transcript) for video ID: KREwxYlzH48
# Error fetching transcript for video B_VSUOdVvsQ:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=B_VSUOdVvsQ! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: B_VSUOdVvsQ
# Fetched and cached video stats (including transcript) for video ID: mlhbqSt-GSk
# Error fetching transcript for video 46Q9a7qSJCg:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=46Q9a7qSJCg! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: 46Q9a7qSJCg
# Error fetching transcript for video NuH1TJzehBc:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=NuH1TJzehBc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: NuH1TJzehBc
# Error fetching transcript for video Ms2mdhOJGeE:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Ms2mdhOJGeE! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: Ms2mdhOJGeE
# Error fetching transcript for video iX4bd9rbXBo:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=iX4bd9rbXBo! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: iX4bd9rbXBo
# Error fetching transcript for video KVs1__S4C0E:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=KVs1__S4C0E! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: KVs1__S4C0E
# Fetched and cached video stats (including transcript) for video ID: -uDEB2OpuRI
# Error fetching transcript for video A4abcP_bNrw:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=A4abcP_bNrw! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: A4abcP_bNrw
# Error fetching transcript for video fpy18ZyiO4U:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=fpy18ZyiO4U! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: fpy18ZyiO4U
# Fetched and cached video stats (including transcript) for video ID: tK_A1a2DuPg
# Error fetching transcript for video cSgf1ukRVQ8:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=cSgf1ukRVQ8! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: cSgf1ukRVQ8
# Error fetching transcript for video uRJSbwFLgxY:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=uRJSbwFLgxY! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: uRJSbwFLgxY
# Error fetching transcript for video UKffsivi17Q:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=UKffsivi17Q! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: UKffsivi17Q
# Error fetching transcript for video 4LQ7SCQBGIM:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=4LQ7SCQBGIM! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: 4LQ7SCQBGIM
# Error fetching transcript for video mNCuAooBKPk:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=mNCuAooBKPk! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: mNCuAooBKPk
# Error fetching transcript for video ImWltmFLmAk:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=ImWltmFLmAk! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: ImWltmFLmAk
# Error fetching transcript for video gpo1vo9aC_M:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=gpo1vo9aC_M! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: gpo1vo9aC_M
# Error fetching transcript for video gOMAn23VAmE:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=gOMAn23VAmE! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: gOMAn23VAmE
# Error fetching transcript for video 6J_nNQP7d28:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=6J_nNQP7d28! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: 6J_nNQP7d28
# Error fetching transcript for video jNz9tMdBWBY:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=jNz9tMdBWBY! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: jNz9tMdBWBY
# Error fetching transcript for video Bm3G0KHsOm0:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Bm3G0KHsOm0! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: Bm3G0KHsOm0
# Error fetching transcript for video yGnPKW9bGrk:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=yGnPKW9bGrk! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: yGnPKW9bGrk
# Fetched and cached video stats (including transcript) for video ID: cCCurcHXfqc
# Fetched and cached video stats (including transcript) for video ID: 5P8hBJaM1uc
# Error fetching transcript for video o39ijeSaI3I:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=o39ijeSaI3I! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: o39ijeSaI3I
# Error fetching transcript for video Qk03kOJCgqM:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Qk03kOJCgqM! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: Qk03kOJCgqM
# Fetched and cached video stats (including transcript) for video ID: g8iBVb4a_lA
# Error fetching transcript for video HdQ_N-eeRp4:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=HdQ_N-eeRp4! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: HdQ_N-eeRp4
# Error fetching transcript for video sBzR-SkP2HU:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=sBzR-SkP2HU! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: sBzR-SkP2HU
# Error fetching transcript for video nGF31_CRUfo:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=nGF31_CRUfo! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: nGF31_CRUfo
# Error fetching transcript for video bG_Bdony0uI:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=bG_Bdony0uI! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: bG_Bdony0uI
# Error fetching transcript for video Ugz1hzpRtbE:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Ugz1hzpRtbE! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: Ugz1hzpRtbE
# Error fetching transcript for video CinUIqdcK4o:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=CinUIqdcK4o! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: CinUIqdcK4o
# Fetched and cached video stats (including transcript) for video ID: 3ShzI2GXs8I
# Error fetching transcript for video edKLviNIRp0:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=edKLviNIRp0! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: edKLviNIRp0
# Error fetching transcript for video 7ADxb28sVRI:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=7ADxb28sVRI! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: 7ADxb28sVRI
# Error fetching transcript for video IzMhwi8qIqs:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=IzMhwi8qIqs! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: IzMhwi8qIqs
# Error fetching transcript for video feKJZ5FtPAM:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=feKJZ5FtPAM! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: feKJZ5FtPAM
# Error fetching transcript for video UcxqTlbkXxQ:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=UcxqTlbkXxQ! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: UcxqTlbkXxQ
# Error fetching transcript for video HB2wkA0mXno:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=HB2wkA0mXno! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: HB2wkA0mXno
# Error fetching transcript for video ej1hcfZCE44:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=ej1hcfZCE44! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: ej1hcfZCE44
# Using cached video stats for video ID: HB2wkA0mXno
# Using cached video stats for video ID: ej1hcfZCE44
# Fetched and cached video stats (including transcript) for video ID: F0lHIMxoZEw
# Error fetching transcript for video CrwJyNizqeY:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=CrwJyNizqeY! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: CrwJyNizqeY
# Error fetching transcript for video KddlzOd1s2g:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=KddlzOd1s2g! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: KddlzOd1s2g
# Error fetching transcript for video fxkHSt_-vz0:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=fxkHSt_-vz0! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: fxkHSt_-vz0
# Error fetching transcript for video xAltZ0J1_Bw:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=xAltZ0J1_Bw! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: xAltZ0J1_Bw
# Error fetching transcript for video 3L6EqAMus3I:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=3L6EqAMus3I! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: 3L6EqAMus3I
# Error fetching transcript for video jjs5Es2g-bA:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=jjs5Es2g-bA! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: jjs5Es2g-bA
# Error fetching transcript for video RTE3ABIGIek:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=RTE3ABIGIek! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: RTE3ABIGIek
# Error fetching transcript for video RVO1bp39Tec:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=RVO1bp39Tec! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: RVO1bp39Tec
# Fetched and cached video stats (including transcript) for video ID: LWzp_uG_GV8
# Error fetching transcript for video boiOFgqj0Ag:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=boiOFgqj0Ag! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: boiOFgqj0Ag
# Error fetching transcript for video ZQZuMSTRRcU:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=ZQZuMSTRRcU! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: ZQZuMSTRRcU
# Error fetching transcript for video -EbbRUFQUyk:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=-EbbRUFQUyk! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: -EbbRUFQUyk
# Fetched and cached video stats (including transcript) for video ID: R68xc50UsSI
# Error fetching transcript for video T_8gEdTCDdU:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=T_8gEdTCDdU! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: T_8gEdTCDdU
# Fetched and cached video stats (including transcript) for video ID: ZDPN8I0LMUM
# Error fetching transcript for video UIXMwfqWfb8:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=UIXMwfqWfb8! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: UIXMwfqWfb8
# Fetched and cached video stats (including transcript) for video ID: DB_fxQHrqA8
# Error fetching transcript for video htH_G_AK6YQ:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=htH_G_AK6YQ! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: htH_G_AK6YQ
# Error fetching transcript for video F6v3blKoc3E:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=F6v3blKoc3E! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: F6v3blKoc3E
# Error fetching transcript for video X-3cBaoud_8:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=X-3cBaoud_8! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: X-3cBaoud_8
# Error fetching transcript for video HuyOE2NA7rA:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=HuyOE2NA7rA! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: HuyOE2NA7rA
# Error fetching transcript for video bE66o05p_l8:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=bE66o05p_l8! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: bE66o05p_l8
# Error fetching transcript for video sFmeRchEqeQ:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=sFmeRchEqeQ! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: sFmeRchEqeQ
# Fetched and cached video stats (including transcript) for video ID: oh-VrtVotrk
# Fetched and cached video stats (including transcript) for video ID: tYUC_Ni3lb4
# Fetched and cached video stats (including transcript) for video ID: nA057G1jIr8
# Error fetching transcript for video 5_Ahh1pKIGw:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=5_Ahh1pKIGw! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: 5_Ahh1pKIGw
# Error fetching transcript for video F-GkyDrUxxk:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=F-GkyDrUxxk! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: F-GkyDrUxxk
# Error fetching transcript for video sMdlWqIIgyE:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=sMdlWqIIgyE! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: sMdlWqIIgyE
# Error fetching transcript for video pUez1yNlA-E:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=pUez1yNlA-E! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: pUez1yNlA-E
# Error fetching transcript for video zijUjJdegI8:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=zijUjJdegI8! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: zijUjJdegI8
# Error fetching transcript for video iM54f7a5UPM:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=iM54f7a5UPM! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# ...
#
# For this video (H8cvIbUVKRk) transcripts are available in the following languages:
#
# (MANUALLY CREATED)
# None
#
# (GENERATED)
#  - ko ("Korean (auto-generated)")[TRANSLATABLE]
#
# (TRANSLATION LANGUAGES)
#  - ab ("Abkhazian")
#  - aa ("Afar")
#  - af ("Afrikaans")
#  - ak ("Akan")
#  - sq ("Albanian")
#  - am ("Amharic")
#  - ar ("Arabic")
#  - hy ("Armenian")
#  - as ("Assamese")
#  - ay ("Aymara")
#  - az ("Azerbaijani")
#  - bn ("Bangla")
#  - ba ("Bashkir")
#  - eu ("Basque")
#  - be ("Belarusian")
#  - bho ("Bhojpuri")
#  - bs ("Bosnian")
#  - br ("Breton")
#  - bg ("Bulgarian")
#  - my ("Burmese")
#  - ca ("Catalan")
#  - ceb ("Cebuano")
#  - zh-Hans ("Chinese (Simplified)")
#  - zh-Hant ("Chinese (Traditional)")
#  - co ("Corsican")
#  - hr ("Croatian")
#  - cs ("Czech")
#  - da ("Danish")
#  - dv ("Divehi")
#  - nl ("Dutch")
#  - dz ("Dzongkha")
#  - en ("English")
#  - eo ("Esperanto")
#  - et ("Estonian")
#  - ee ("Ewe")
#  - fo ("Faroese")
#  - fj ("Fijian")
#  - fil ("Filipino")
#  - fi ("Finnish")
#  - fr ("French")
#  - gaa ("Ga")
#  - gl ("Galician")
#  - lg ("Ganda")
#  - ka ("Georgian")
#  - de ("German")
#  - el ("Greek")
#  - gn ("Guarani")
#  - gu ("Gujarati")
#  - ht ("Haitian Creole")
#  - ha ("Hausa")
#  - haw ("Hawaiian")
#  - iw ("Hebrew")
#  - hi ("Hindi")
#  - hmn ("Hmong")
#  - hu ("Hungarian")
#  - is ("Icelandic")
#  - ig ("Igbo")
#  - id ("Indonesian")
#  - iu ("Inuktitut")
#  - ga ("Irish")
#  - it ("Italian")
#  - ja ("Japanese")
#  - jv ("Javanese")
#  - kl ("Kalaallisut")
#  - kn ("Kannada")
#  - kk ("Kazakh")
#  - kha ("Khasi")
#  - km ("Khmer")
#  - rw ("Kinyarwanda")
#  - ko ("Korean")
#  - kri ("Krio")
#  - ku ("Kurdish")
#  - ky ("Kyrgyz")
#  - lo ("Lao")
#  - la ("Latin")
#  - lv ("Latvian")
#  - ln ("Lingala")
#  - lt ("Lithuanian")
#  - lua ("Luba-Lulua")
#  - luo ("Luo")
#  - lb ("Luxembourgish")
#  - mk ("Macedonian")
#  - mg ("Malagasy")
#  - ms ("Malay")
#  - ml ("Malayalam")
#  - mt ("Maltese")
#  - gv ("Manx")
#  - mi ("Māori")
#  - mr ("Marathi")
#  - mn ("Mongolian")
#  - mfe ("Morisyen")
#  - ne ("Nepali")
#  - new ("Newari")
#  - nso ("Northern Sotho")
#  - no ("Norwegian")
#  - ny ("Nyanja")
#  - oc ("Occitan")
#  - or ("Odia")
#  - om ("Oromo")
#  - os ("Ossetic")
#  - pam ("Pampanga")
#  - ps ("Pashto")
#  - fa ("Persian")
#  - pl ("Polish")
#  - pt ("Portuguese")
#  - pt-PT ("Portuguese (Portugal)")
#  - pa ("Punjabi")
#  - qu ("Quechua")
#  - ro ("Romanian")
#  - rn ("Rundi")
#  - ru ("Russian")
#  - sm ("Samoan")
#  - sg ("Sango")
#  - sa ("Sanskrit")
#  - gd ("Scottish Gaelic")
#  - sr ("Serbian")
#  - crs ("Seselwa Creole French")
#  - sn ("Shona")
#  - sd ("Sindhi")
#  - si ("Sinhala")
#  - sk ("Slovak")
#  - sl ("Slovenian")
#  - so ("Somali")
#  - st ("Southern Sotho")
#  - es ("Spanish")
#  - su ("Sundanese")
#  - sw ("Swahili")
#  - ss ("Swati")
#  - sv ("Swedish")
#  - tg ("Tajik")
#  - ta ("Tamil")
#  - tt ("Tatar")
#  - te ("Telugu")
#  - th ("Thai")
#  - bo ("Tibetan")
#  - ti ("Tigrinya")
#  - to ("Tongan")
#  - ts ("Tsonga")
#  - tn ("Tswana")
#  - tum ("Tumbuka")
#  - tr ("Turkish")
#  - tk ("Turkmen")
#  - uk ("Ukrainian")
#  - ur ("Urdu")
#  - ug ("Uyghur")
#  - uz ("Uzbek")
#  - ve ("Venda")
#  - vi ("Vietnamese")
#  - war ("Waray")
#  - cy ("Welsh")
#  - fy ("Western Frisian")
#  - wo ("Wolof")
#  - xh ("Xhosa")
#  - yi ("Yiddish")
#  - yo ("Yoruba")
#  - zu ("Zulu")
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: H8cvIbUVKRk
# Fetched and cached video stats (including transcript) for video ID: oamvVbVo7AQ
# Fetched and cached video stats (including transcript) for video ID: viB8HLEQdic
# Fetched and cached video stats (including transcript) for video ID: UsNLjb-HRj8
# Fetched and cached video stats (including transcript) for video ID: o8yjzL2pI5E
# Fetched and cached video stats (including transcript) for video ID: qUl6qQLcGvo
# Fetched and cached video stats (including transcript) for video ID: 8d5yRV9Yu6M
# Using cached video stats for video ID: 8d5yRV9Yu6M
# Fetched and cached video stats (including transcript) for video ID: otp-eG8pjNI
# Fetched and cached video stats (including transcript) for video ID: cZgCk-b8DLI
# Fetched and cached video stats (including transcript) for video ID: LTGNBSkOkgE
# Fetched and cached video stats (including transcript) for video ID: ZTCoXp-6IOg
# Fetched and cached video stats (including transcript) for video ID: J-MvXJWYASo
# Fetched and cached video stats (including transcript) for video ID: 7PoAXxTB5pw
# Fetched and cached video stats (including transcript) for video ID: -t9I8DmoWe4
# Fetched and cached video stats (including transcript) for video ID: AjefLEkw6qM
# Fetched and cached video stats (including transcript) for video ID: AO4Ctm5Rz8I
# Fetched and cached video stats (including transcript) for video ID: 4J4bJEfE1RM
# Fetched and cached video stats (including transcript) for video ID: S5fd2RfFrJk
# Fetched and cached video stats (including transcript) for video ID: JHIZ9NEQU4E
# Fetched and cached video stats (including transcript) for video ID: DEW4yyDSXRU
# Fetched and cached video stats (including transcript) for video ID: dGln2chcHl0
# Fetched and cached video stats (including transcript) for video ID: CO0d4W7lJUU
# Fetched and cached video stats (including transcript) for video ID: j_hgtV1EYH0
# Fetched and cached video stats (including transcript) for video ID: 48LcTDSscU4
# Fetched and cached video stats (including transcript) for video ID: EDQ7ouP84ZY
# Fetched and cached video stats (including transcript) for video ID: En4TqrK7F9o
# Fetched and cached video stats (including transcript) for video ID: a0nrn-Kw16A
# Fetched and cached video stats (including transcript) for video ID: yBdxlVqFit0
# Fetched and cached video stats (including transcript) for video ID: SWutjTMILYQ
# Fetched and cached video stats (including transcript) for video ID: 5WxtLfMJC2g
# Fetched and cached video stats (including transcript) for video ID: xruHcvyEcLY
# Fetched and cached video stats (including transcript) for video ID: BNzwl6M-kO8
# Fetched and cached video stats (including transcript) for video ID: EsaGxvdlGaE
# Fetched and cached video stats (including transcript) for video ID: f_Ru1b92ECo
# Fetched and cached video stats (including transcript) for video ID: do7mwcaESdw
# Fetched and cached video stats (including transcript) for video ID: pcLPYNkQRFU
# Fetched and cached video stats (including transcript) for video ID: OUr_zHIP3D0
# Fetched and cached video stats (including transcript) for video ID: aDBlBFR3Qq4
# Fetched and cached video stats (including transcript) for video ID: P-MqmsYcaaE
# Fetched and cached video stats (including transcript) for video ID: MZbWuEOwkxk
# Error fetching transcript for video UIsRPWkDTeQ:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=UIsRPWkDTeQ! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Fetched and cached video stats (including transcript) for video ID: UIsRPWkDTeQ
# Fetched and cached video stats (including transcript) for video ID: pRyVuL_I_nU
# Fetched and cached video stats (including transcript) for video ID: b08LN-xJf2o
# Fetched and cached video stats (including transcript) for video ID: BwSatBeSm8k
# Fetched and cached video stats (including transcript) for video ID: fxr5quIBZ6w
# Fetched and cached video stats (including transcript) for video ID: P5myiyazLzk
# Fetched and cached video stats (including transcript) for video ID: Kx4unQUFrj8
# Fetched and cached video stats (including transcript) for video ID: bCwCnLB3j3g
# Fetched and cached video stats (including transcript) for video ID: TvmaQRXebtE
# Fetched and cached video stats (including transcript) for video ID: YkD0ysw-nJ8
# Fetched and cached video stats (including transcript) for video ID: H-ye25g2cj4
# Fetched and cached video stats (including transcript) for video ID: CVL16alUttE
# Fetched and cached video stats (including transcript) for video ID: 4LTd6dedmvc
# Fetched and cached video stats (including transcript) for video ID: Sjv9wRBjOWM
# Fetched and cached video stats (including transcript) for video ID: eRVt2msKNVg
# Fetched and cached video stats (including transcript) for video ID: aa2mpNvQfAU
# Fetched and cached video stats (including transcript) for video ID: QpYt-93ixcc
# Fetched and cached video stats (including transcript) for video ID: 4wDmHXISP5o
# Fetched and cached video stats (including transcript) for video ID: MTm22n8fKcs
# Fetched and cached video stats (including transcript) for video ID: cdWAVVGZ2OQ
# Fetched and cached video stats (including transcript) for video ID: 5BDQSEl7iMM
# Fetched and cached video stats (including transcript) for video ID: 3jjjKrsXLvE
# Fetched and cached video stats (including transcript) for video ID: ArKpfWJEDlI
# Fetched and cached video stats (including transcript) for video ID: Hz2B8LIvAHY
# Fetched and cached video stats (including transcript) for video ID: gU8o16WpJqo
# Fetched and cached video stats (including transcript) for video ID: nMF-1BbaDpk
# Fetched and cached video stats (including transcript) for video ID: PXdHheN9mmU
# Fetched and cached video stats (including transcript) for video ID: dXK56i7DB70
# Fetched and cached video stats (including transcript) for video ID: EjVBDtFNuKE
# Fetched and cached video stats (including transcript) for video ID: YmK5GL6IxUc
# Fetched and cached video stats (including transcript) for video ID: Ti002_qhP7k
# Fetched and cached video stats (including transcript) for video ID: UypTwXu5jzU
# Fetched and cached video stats (including transcript) for video ID: aCKKvx-1uq4
# Fetched and cached video stats (including transcript) for video ID: 7wX9KpTq6qk
# Fetched and cached video stats (including transcript) for video ID: 18URp4JDibE
# Fetched and cached video stats (including transcript) for video ID: ssjV5K4RUoE
# Fetched and cached video stats (including transcript) for video ID: MZu9mjRicPo
# Fetched and cached video stats (including transcript) for video ID: ArLoX2nPvg4
# Fetched and cached video stats (including transcript) for video ID: umH6yTFahnk
# Fetched and cached video stats (including transcript) for video ID: C85TWv5tHG0
# Fetched and cached video stats (including transcript) for video ID: fFNfwnkuNIU
# Fetched and cached video stats (including transcript) for video ID: hUWe7koKqp0
# Fetched and cached video stats (including transcript) for video ID: oL0iIu3R6ws
# Fetched and cached video stats (including transcript) for video ID: T3f1q5RnFiA
# Fetched and cached video stats (including transcript) for video ID: nUYy1I6qVYk
# Fetched and cached video stats (including transcript) for video ID: 3rQwYeVcvu4
# Fetched and cached video stats (including transcript) for video ID: cA9BmcyNXCw
# Fetched and cached video stats (including transcript) for video ID: 6rgSpWvRHaQ
# Fetched and cached video stats (including transcript) for video ID: IEHUoVlVGOk
# Fetched and cached video stats (including transcript) for video ID: kN0vapQMFuI
# Fetched and cached video stats (including transcript) for video ID: eEz8Sb7qHAw
# Fetched and cached video stats (including transcript) for video ID: 2UpnIA0xZ_Y
# Fetched and cached video stats (including transcript) for video ID: kw12AtaX2Zs
# Fetched and cached video stats (including transcript) for video ID: yVlxS6Rqtg8
# Fetched and cached video stats (including transcript) for video ID: 0pkJVif2htM
# Fetched and cached video stats (including transcript) for video ID: eGwQY9553HA
# Fetched and cached video stats (including transcript) for video ID: 1wlCUphcE2U
# Fetched and cached video stats (including transcript) for video ID: C6y6yPcwDZE
# Fetched and cached video stats (including transcript) for video ID: giTy85RANs4
# Fetched and cached video stats (including transcript) for video ID: 9UKwYpgqX4w
# Fetched and cached video stats (including transcript) for video ID: fReJZT-6ra0
# Fetched and cached video stats (including transcript) for video ID: rKrxa8wHrI0
# Fetched and cached video stats (including transcript) for video ID: LJhLhfgL3Og
# Fetched and cached video stats (including transcript) for video ID: 3DIVdqFfcwY
# Total videos processed: 498
# Combined data saved to cache\ytb_search_combined_results_lululemon_align_pants.csv
#             product_type product_name     video_id  \
# 0  Lululemon Align Pants               pE-jNu4i19M
# 1  Lululemon Align Pants               2Ji7P37kGzg
# 2  Lululemon Align Pants               sNZYR0gl7zo
# 3  Lululemon Align Pants               DTfjUYtZvWU
# 4  Lululemon Align Pants               iy5Saa_h9Mo
#
#                                      video_url  \
# 0  https://www.youtube.com/watch?v=pE-jNu4i19M
# 1  https://www.youtube.com/watch?v=2Ji7P37kGzg
# 2  https://www.youtube.com/watch?v=sNZYR0gl7zo
# 3  https://www.youtube.com/watch?v=DTfjUYtZvWU
# 4  https://www.youtube.com/watch?v=iy5Saa_h9Mo
#
#                                          video_title  \
# 0  What does it cost to make Lululemon Align legg...
# 1  LULULEMON LEGGINGS EXPLAINED | What You Need t...
# 2   LULULEMON ALIGN VS WUNDER TRAIN LEGGINGS UPDATED
# 3  LULULEMON *Align* vs. *Wunder Train* 23&quot; ...
# 4  NEW LULULEMON LEGGING! WUNDER UNDER EVERLUX HI...
#
#                                    video_description      video_channel  \
# 0  Instagram / Tik Tok: @Shiftfashiongroup Joe's ...  Shiftfashiongroup
# 1  LULULEMON LEGGINGS EXPLAINED | What You Need t...       Gabi LeMoine
# 2  Hi Hi Hi! Lululemon switched up their wunder t...               Maya
# 3  Get at least $30 on your 1st purchase via Raku...   Tawny Alessandra
# 4  Lululemon Wunder Under Everlux High Rise Tight...            Lindsey
#
#            video_channel_id       video_published  \
# 0  UC5Bs2BXfOU8VdQDNBIjHEew  2023-10-02T23:00:06Z
# 1  UCAlwbNvolMosuxPfanc-jLQ  2024-01-20T00:00:01Z
# 2  UCg8mp8FO35KOeJeEbcJm9hg  2023-03-17T15:00:44Z
# 3  UCNHIo8cvEL-Flfg-YdJRyrg  2023-07-05T21:06:25Z
# 4  UCrH9u6Q6SP-ZkceP4N58Seg  2024-10-03T19:00:23Z
#
#                                   video_thumbnail  ... madeForKids  \
# 0  https://i.ytimg.com/vi/pE-jNu4i19M/default.jpg  ...       False
# 1  https://i.ytimg.com/vi/2Ji7P37kGzg/default.jpg  ...       False
# 2  https://i.ytimg.com/vi/sNZYR0gl7zo/default.jpg  ...       False
# 3  https://i.ytimg.com/vi/DTfjUYtZvWU/default.jpg  ...       False
# 4  https://i.ytimg.com/vi/iy5Saa_h9Mo/default.jpg  ...       False
#
#   privacyStatus viewCount likeCount commentCount dislikeCount favoriteCount  \
# 0        public     14318       293           19         None             0
# 1        public     24106       370           44         None             0
# 2        public     37437       283           41         None             0
# 3        public     10654        73            2         None             0
# 4        public      4823        65           10         None             0
#
#   paidProductPlacement                                         transcript  \
# 0                False                                               None
# 1                False                                               None
# 2                False                                               None
# 3                False  hey guys welcome back to my channel if you're ...
# 4                False                                               None
#
#   transcript_is_generated
# 0                    None
# 1                    None
# 2                    None
# 3                    True
# 4                    None
#
# [5 rows x 35 columns]
# Finished processing Lululemon Align Pants videos. Total videos: 498

# %%
import logging 

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
def fetch_video_metadata(video_id: str, ydl: YoutubeDL, video_info_cache: Dict) -> Optional[Dict]:
    """
    Fetch metadata for a video using yt-dlp and update the cache.
    """
    if video_info_cache.get(video_id):
        print(f"Skipping {video_id}: Already in cache.")
        return None  # Return None consistently

    url = f"https://www.youtube.com/watch?v={video_id}"
    try:
        print(f"Fetching info for {video_id}...")
        info = ydl.extract_info(url, download=False)
        print(f"Successfully fetched info for {video_id}.")
        return info
        
    except Exception as e:
        print(f"Error fetching info for {video_id}: {e}")
        return None

def fetch_metadata_for_dataframe(df: pd.DataFrame, category: str, delay: float = 1.0) -> pd.DataFrame:
    """
    Fetch metadata for all videos in a DataFrame and update the cache.

    Args:
        df: The DataFrame containing video IDs.
        category: A string representing the category (used for cache file naming).
        delay: The delay in seconds between yt-dlp calls (for rate limiting).

    Returns:
        The updated DataFrame with a new 'metadata' column.
    """
    metadata_cache_file = os.path.join(CACHE_DIR, f"video_info_cache_{category}.json")
    video_info_cache = load_cache(metadata_cache_file)

    ydl_opts = {"quiet": True}
    ydl = YoutubeDL(ydl_opts)

    metadata_dict = {}
    for idx, video_id in enumerate(df["video_id"]):
        try:
            metadata = fetch_video_metadata(video_id, ydl, video_info_cache)
            if metadata:
                metadata_dict[video_id] = metadata
        except Exception as e:
            logging.error(f"Error processing video ID {video_id}: {e}")  # Log the error

        # Update cache
        if len(metadata_dict) == 10:
            # update video_info_cache every 10 videos
            video_info_cache.update(metadata_dict)
            with open(metadata_cache_file, "w") as f:
                json.dump(video_info_cache, f)
            logging.info(f"Processed {idx + 1} videos.  Cache updated.")
            # Reset metadata_list
            metadata_dict = {}

        #time.sleep(delay)  # Enforce delay

    # Update cache
    video_info_cache.update(metadata_dict)
    with open(metadata_cache_file, "w") as f:
        json.dump(video_info_cache, f)  
    # update_cache(video_info_cache, video_id, metadata, metadata_cache_file) #update cache
    logging.info("Metadata fetching complete. Cache updated.")

    df["metadata"] = metadata_dict
    return df

# %%
# Example usage
if __name__ == "__main__":
    product_type = "lululemon align pants"
    ytb_search_df = fetch_and_process_videos(product_type=product_type, videos_count=500)

    # Fetch metadata as a post-processing step
    ytb_search_df = fetch_metadata_for_dataframe(ytb_search_df, category="fashion_50")

    # Save the updated DataFrame
    output_file = os.path.join(CACHE_DIR, f"ytb_search_results_with_metadata_{product_type.replace(' ', '_').lower()}.csv")
    ytb_search_df.to_csv(output_file, index=False)
    print(f"Data with metadata saved to {output_file}")

# %% [markdown]
# # Clean text dataset

# %%
import pandas as pd

def add_cols(df: pd.DataFrame) -> pd.DataFrame:
    """
    Add new columns to the DataFrame and clean existing ones.
    """
    # Convert duration to seconds (e.g., PT4M20S to 260)
    try:
        df["duration_seconds"] = df["duration"].apply(lambda x: pd.to_timedelta(x).seconds)
    except Exception as e:
        print(f"Error converting duration to seconds: {e}")
        df["duration_seconds"] = None  # Fallback to None if conversion fails

    # Convert 'video_published' to datetime format
    df["video_published"] = pd.to_datetime(df["video_published"], errors="coerce")

    # Check for invalid dates
    if df["video_published"].isnull().any():
        print("Warning: Some values in 'video_published' could not be converted to datetime!")

    # Extract 'publish_month' in 'YYYY-MM' format
    df["publish_month"] = df["video_published"].dt.strftime("%Y-%m")

    # Convert numeric columns to numeric type
    numeric_cols = ["viewCount", "likeCount", "commentCount", "duration_seconds"]
    for col in numeric_cols:
        df[col] = pd.to_numeric(df[col], errors="coerce")

    # Sort the DataFrame by 'viewCount' in descending order
    df_sorted = df.sort_values(by=["viewCount"], ascending=False)
    return df_sorted

def drop_cols_rows(df: pd.DataFrame) -> pd.DataFrame:
    """
    Drop unnecessary columns and rows, and clean the DataFrame.
    """
    # Drop columns with all null values
    df = df.dropna(axis=1, how="all")

    # Drop rows with all null values
    df = df.dropna(how="all")

    # Drop duplicates, reset index, and sort by 'viewCount'
    df = df.drop_duplicates().reset_index(drop=True).sort_values(by=["viewCount"], ascending=False)
    # drop unnecessary columns
    try:
        df = df.drop(['liveBroadcastContent', 'contentRating', 'video_channel', 'title', 'video_channel_id', 'privacyStatus'], axis=1)
    except KeyError:
        pass

    # drop rows with null values in 'transcript'
    # df = df.dropna(subset=["transcript"])

    
    # drop dumplicate columns
    df = df.loc[:,~df.columns.duplicated()]
    return df

# %%
import glob

csv_combined = glob.glob(os.path.join(CACHE_DIR, "ytb_search_combined_results_*.csv"))
csv_combined = [file for file in csv_combined if not file.endswith('_metadata.csv')]
csv_combined
# Out:
# ['cache\\ytb_search_combined_results_apple_airtag.csv',
#  'cache\\ytb_search_combined_results_cosrx_snail_mucin_serum.csv',
#  'cache\\ytb_search_combined_results_liquid_death.csv',
#  'cache\\ytb_search_combined_results_lululemon_align_pants.csv',
#  'cache\\ytb_search_combined_results_macbook_pro_m4.csv',
#  'cache\\ytb_search_combined_results_meta_quest_3.csv',
#  'cache\\ytb_search_combined_results_samsung_galaxy_watch_7.csv',
#  'cache\\ytb_search_combined_results_samsung_oled_tv.csv',
#  'cache\\ytb_search_combined_results_stanley_tumbler.csv',
#  'cache\\ytb_search_combined_results_tesla_model_y.csv']

# %%
# clean the data and save it
for csv_search_file in csv_combined:
    df = pd.read_csv(csv_search_file)
    df = add_cols(df)
    df = drop_cols_rows(df)
    name_f = "cleaned_" + os.path.basename(csv_search_file)
    df.to_csv(os.path.join(CACHE_DIR, name_f), index=False)
    print(f"Data cleaned and saved to {os.path.join(CACHE_DIR, name_f)}")
    # remove timezone information
    df["video_published"] = df["video_published"].dt.tz_localize(None)
    # save to excel
    df.to_excel(os.path.join(CACHE_DIR, name_f.replace(".csv", ".xlsx")), index=False)
    print(f"Data cleaned and saved to {os.path.join(CACHE_DIR, name_f.replace('.csv', '.xlsx'))}")
# Out:
# Data cleaned and saved to cache\cleaned_ytb_search_combined_results_apple_airtag.csv
# Data cleaned and saved to cache\cleaned_ytb_search_combined_results_apple_airtag.xlsx
# Data cleaned and saved to cache\cleaned_ytb_search_combined_results_cosrx_snail_mucin_serum.csv
# Data cleaned and saved to cache\cleaned_ytb_search_combined_results_cosrx_snail_mucin_serum.xlsx
# Data cleaned and saved to cache\cleaned_ytb_search_combined_results_galaxy_zflip_6.csv
# Data cleaned and saved to cache\cleaned_ytb_search_combined_results_galaxy_zflip_6.xlsx
# Data cleaned and saved to cache\cleaned_ytb_search_combined_results_liquid_death.csv
# Data cleaned and saved to cache\cleaned_ytb_search_combined_results_liquid_death.xlsx
# Data cleaned and saved to cache\cleaned_ytb_search_combined_results_lululemon_align_pants.csv
# Data cleaned and saved to cache\cleaned_ytb_search_combined_results_lululemon_align_pants.xlsx
# Data cleaned and saved to cache\cleaned_ytb_search_combined_results_macbook_pro_m4.csv
# Data cleaned and saved to cache\cleaned_ytb_search_combined_results_macbook_pro_m4.xlsx
# Data cleaned and saved to cache\cleaned_ytb_search_combined_results_meta_quest_3.csv
# Data cleaned and saved to cache\cleaned_ytb_search_combined_results_meta_quest_3.xlsx
# Data cleaned and saved to cache\cleaned_ytb_search_combined_results_samsung_galaxy_watch_7.csv
# Data cleaned and saved to cache\cleaned_ytb_search_combined_results_samsung_galaxy_watch_7.xlsx
# Data cleaned and saved to cache\cleaned_ytb_search_combined_results_samsung_oled_tv.csv
# Data cleaned and saved to cache\cleaned_ytb_search_combined_results_samsung_oled_tv.xlsx
# Data cleaned and saved to cache\cleaned_ytb_search_combined_results_stanley_tumbler.csv
# Data cleaned and saved to cache\cleaned_ytb_search_combined_results_stanley_tumbler.xlsx
# Data cleaned and saved to cache\cleaned_ytb_search_combined_results_tesla_model_y.csv
# Data cleaned and saved to cache\cleaned_ytb_search_combined_results_tesla_model_y.xlsx

# %%
import glob

csv_combined = glob.glob(os.path.join(CACHE_DIR, "cleaned_ytb_search_combined_*.csv"))
#csv_combined = [file for file in csv_combined if not file.endswith('_metadata.csv')]
csv_combined
# Out:
# ['cache\\cleaned_ytb_search_combined_results_apple_airtag.csv',
#  'cache\\cleaned_ytb_search_combined_results_cosrx_snail_mucin_serum.csv',
#  'cache\\cleaned_ytb_search_combined_results_liquid_death.csv',
#  'cache\\cleaned_ytb_search_combined_results_lululemon_align_pants.csv',
#  'cache\\cleaned_ytb_search_combined_results_macbook_pro_m4.csv',
#  'cache\\cleaned_ytb_search_combined_results_meta_quest_3.csv',
#  'cache\\cleaned_ytb_search_combined_results_samsung_galaxy_watch_7.csv',
#  'cache\\cleaned_ytb_search_combined_results_samsung_oled_tv.csv',
#  'cache\\cleaned_ytb_search_combined_results_stanley_tumbler.csv',
#  'cache\\cleaned_ytb_search_combined_results_tesla_model_y.csv']

# %%
search_products.sort()
search_products
# Out:
# ['Apple AirTag',
#  'COSRX Snail Mucin Serum',
#  'Liquid Death',
#  'Lululemon Align Pants',
#  'Macbook Pro M4',
#  'Meta quest 3',
#  'Samsung Galaxy Watch 7',
#  'Samsung OLED TV',
#  'Stanley tumbler',
#  'Tesla Model Y']

# %%
import pandas as pd
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

def process_csv_with_fuzzy(csv_file, search_term="review", threshold=58):
    """
    Process CSV file to add fuzzy matching columns
    
    Args:
        csv_file (str): Path to CSV file
        search_term (str): Term to match against titles
        threshold (int): Fuzzy matching threshold
    
    Returns:
        pd.DataFrame: Processed dataframe with new columns
    """
    df = pd.read_csv(csv_file)
    
    # Calculate fuzzy ratios for all titles
    df['fuzzy_ratio_title'] = df['video_title'].apply(
        lambda x: fuzz.partial_ratio(search_term.lower(), str(x).lower())
    )
    
    # Add binary matched column
    df['matched_title'] = (df['fuzzy_ratio_title'] > threshold).astype(int)

    # Calculate fuzzy ratios for all descriptions
    df['fuzzy_ratio_description'] = df['video_description'].apply(
        lambda x: fuzz.partial_ratio(search_term.lower(), str(x).lower())
    )

    # Add binary matched column
    df['matched_description'] = (df['fuzzy_ratio_description'] > threshold).astype(int)

    # sort by 'viewCount' in descending order for matched_title=1
    df = df.sort_values(by=["matched_description", "matched_title", "viewCount"], ascending=[False, False, False])
    
    return df

# Process each CSV file
processed_dfs = []
for i, csv in enumerate(csv_combined):
    df_processed = process_csv_with_fuzzy(csv, search_term=search_products[i])
    
    # Print matching titles and their ratios
    matching_titles = df_processed[df_processed['matched_title'] == 1]
    print(f"\nMatching titles in {csv}:")
    print(matching_titles[['video_title', 'fuzzy_ratio_title']].to_string())

    # Print matching descriptions and their ratios
    matching_descriptions = df_processed[df_processed['matched_description'] == 1]
    print(f"\nMatching descriptions in {csv}:")
    print(matching_descriptions[['video_description', 'fuzzy_ratio_description']].to_string())


    
    processed_dfs.append(df_processed)
    
    # Print summary
    print(f"\nTotal matches Title for {csv}: {len(matching_titles)}")
    print(f"Total matches Description for {csv}: {len(matching_descriptions)}")
len(processed_dfs)
# Out:
# Matching titles in cache\cleaned_ytb_search_combined_results_apple_airtag.csv:
#                                                                                                       video_title  fuzzy_ratio_title
# 12                                               TRACK YOUR CAR with Apple AirTags! The BEST Anti-Theft Solution!                100
# 16                           Apple Watch Series 9 Tips, Tricks &amp; Hidden Features | YOU ABSOLUTELY MUST KNOW!!                 67
# 19                                                Versteckte Funktion: Wusstest du, dass dein AirTag das kann?! 😲                 67
# 23                                                                   Apple Watch Series 9 Review - 6 Months Later                 67
# 25                               Apple Watch Ultra 2 vs Apple Watch Series 10: Every single difference explained!                 67
# 29                                                   Apple Intelligence Setup: Your iPhone Will Never Be The Same                 67
# 31                               Apple Watch Series 9 Review for Sports &amp; Fitness // Do You Need To Go ULTRA?                 67
# 33                                                 Most people don&#39;t know this, how to properly AirTag a Bike                 75
# 38                                                         Apple Watch Series 9 In-Depth Review: Worth Upgrading?                 67
# 46                                                                     Apple Watch Series 10 46mm Unboxing - ASMR                 67
# 58                    iOS 18 Changes, Apple’s iPhone 16 Event, iPhone 17 Ultra, Crazy AirTag Story | Apple Weekly                 67
# 62                        iOS 18.2 &amp; How ChatGPT Actually Works, New M4 Macs, Crazy AirTags Story &amp; More!                 67
# 66                                        Apple Watch Ultra 2 Review for Sports and Fitness // Worth the Upgrade?                 67
# 70                                            Apple AirTags nach über 2 Jahren - Wie nützlich waren sie wirklich?                100
# 71                                                          Rastreando Carro com a AirTag da Apple! FUNCIONA BEM?                 67
# 79                                                     Besser als AirTags! Das kann der Samsung Galaxy SmartTag2!                 75
# 96             DON’T BE FOOLED - WORTHLESS BIKE SECURITY: Why Apple AirTags Won&#39;t Help Find Your Stolen Bike!                100
# 100                                                                             The 9 Best AirTag Wallets For EDC                 67
# 107                                         Apple Airtag vs Jio JioTag - Jiotag is Apple Airtag killer, Ghanta...                100
# 108                                                                  MiTag Xiaomi - Funciona como a AirTag Apple!                 67
# 115                                                         Apple AirTags 2 Years Later (still worth it in 2023?)                100
# 128                                                  Apple AirTag Holder for Bicycles | Hidden Bike Mounts Review                100
# 137          hoco E91 - бюджетный аналог apple AirTag. Hoco E91 сравнить с AirTag. Hoco E91 обзор, hoco e91 отзыв                100
# 138                                                                        15 Best AirTag Cases &amp; Accessories                 67
# 139                                               AirTag de Apple vs BARATOS ¿Qué diferencias hay? 💥 Mira esto...                 67
# 150                                                      Review Airtag sau gần 1 năm: Theo dõi cái gì thì nên mua                 67
# 151                                                    Is Eufy&#39;s SmartTrack Link better than an Apple AirTag?                100
# 165                                                                The Best AirTag Alternative is now on Android!                 67
# 166                                                                                 How to Connect AirTag to iPad                 67
# 167                             Using Apple AirTag as a Car Tracker ( republished with speaker remove deleted ! )                100
# 168                                                                      FAKE Apple Airtag Better than the REAL??                100
# 175                                           MiLi MiTag Dog Cat GPS Tracker - Best AirTag Alternative iOS Review                 67
# 176                                 Apple Airtag Alternative in India for Rs 699 | Portronics World Tag Review ⚡️                100
# 179                                         World&#39;s Thinnest AirTag - Seinxon Finder Card Unboxing and Review                 67
# 180                                                     The Best Airtag Alternative - Mitag Bluetooth Item Finder                 67
# 181                                           Jio Tag Air New (2024) vs Apple Air Tag - Which is ACTUALLY Better?                 92
# 182                                                Apple Watch Ultra 2 - Review. It&#39;s better than you think !                 67
# 184                                           The 5 Best Airtag Wallet 2023 [Don&#39;t Get One Before Watch This]                 67
# 192                                  Spigen Passport Holder, AirTag Holder &amp; Apple AirTag (Unboxing + Review)                100
# 200                                      Apple AirTag Review from COSTCO - still worth it? (watch before you buy)                100
# 203                                          Wat is een Apple Airtag? | Wij leggen je uit hoe die werkt! | Expert                100
# 204                                                     How to use Apple AirTag with Android? / Read description!                100
# 205                                                           The Atuvos Bluetooth Tracker - Better than AirTags?                 67
# 206                                     Easily Track Your Car With your iPhone &amp; Apple AirTag (The Right Way)                100
# 208                                                  Apple AirTag Sharing // Useful Feature For Your Bike AirTag!                100
# 213                            Best Micro Tracker to Secure Your Assets - MagTag vs AirTag - MagTag Micro Tracker                 67
# 216       Generic Apple AirTag Alternatives Cost Half of What Apple&#39;s Cost and work with the Find My Network!                100
# 218                                                        Could the iTag replace the AirTags? Watch out Apple...                 67
# 219                              Real life Test with Apple AirTag Vs Jio Tag Air | Setup, Range Test &amp; Review                100
# 220                                          JioTag Air | Works with Apple Find My | Apple AirTag vs Jio TagAir ?                100
# 227                                                              MOMAX Pinpop: Airtag Alternative under PhP1,000!                 75
# 237                                                     Two INCREDIBLE Westaur AirTag wallets REVIEW and COMPARE!                 67
# 245                                           WXM Minimalist Wallet with RFID and AirTag Support. Is It Any Good?                 67
# 247                             Apple Airtag Vault for Land Rover / Range Rover Wheel Centre Cap Tracker Security                100
# 250             Beli AirTag Apple di Tahun ini Tidak Worth It Karena Kemahalan ? Alat GPS Apple Paling Canggih !!                 75
# 253                                      An AirTag Made for Wallets??? Rolling Square Aircard UNBOXING and SETUP!                 67
# 254                                          Apple AIRTAG WALLET REVIEW - Never lose your wallet again with Lozor                100
# 262                               eufy SmartTrack Link Tag - unboxing and set up review - Apple AirTag equivalent                100
# 267                                                                          How to setup and best use the AirTag                 67
# 268          รีวิว Apple Airtag ดีมั๊ย แค่ 2เหตุผลที่ควรใช้งาน(แชร์ตำแหน่งไม่ได้) รีวิวข้อดี/ข้อเสีย/ปัญหา pantip                100
# 269                                                 5 Best AirTag Case | Top 5 AirTag Cases with Key Ring in 2023                 67
# 272                                                  TOP 5 Best AirTag Wallets - Best AirTag Wallet Review (2024)                 67
# 274                  Jio Tag review - you can get it for Rs. 749 only! Jio Tag vs Apple Air Tag | Best Technicals                 92
# 275                                                               Apple Watch Series 10 vs 5: My honest thoughts.                 67
# 276                                    USB-C AirPods Pro 2 &amp; AirTags unboxing 🎧✨ accessories, aesthetic, ASMR                 75
# 277                                                                               13 Best EDC AirTag Wallets 2024                 67
# 280                                               iOS 18.2 Beta 3 Released - A MASSIVE AirTags Features OVERHAUL!                 67
# 283                                                        Review Pulseira Kids Para Colocar a AirTag em Crianças                 67
# 288       Jio Tag Unboxing &amp; Review with Real Test | Apple Air Tag Killer | Jio Tracker | Jio Tag 2023 Telugu                 92
# 289                         Losing Your Keys Is A Pain, But Apple Airtags Can Help!  Apple airtags review 2023                 100
# 294                                                                                   Apple AirTags: A week Later                100
# 299                                                 Apple AirTag in 2024 - What&#39;s New and Why It Still Rocks!                100
# 300                                                               Does the Apple Airtag work on a lost FPV drone?                100
# 301                                                 Best Airtag Wallets in 2025 - How to Choose an Airtag Wallet?                 67
# 302                            Never Put An AirTag In Your Wallet Again! | Nomad Tracking Card Review &amp; Setup                 67
# 303                                            Nomad Apple Airtag Accesories y Tracking Card, #review  en español                100
# 304                                                           Apple AirTag Malayalam review | phonetech education                100
# 305                                                                            Apple AirTag: 2 Years Later Review                100
# 310                                                                                Apple Airtags for Drones? WHY?                100
# 311                                                                         Apple AirTags and what I use them for                100
# 314                                  WHICH IS BETTER? &quot;Battle of the Trackers: AirTag vs. SmartTag 2&quot; 📱                 67
# 315                               Apple AirTag Review (inkl. Batteriewechsel) in 2023 - Lohnt sich der Kauf noch?                100
# 317                                                  Moje prvo iskustvo sa Apple AirTag -om - Unboxing i upotreba                100
# 318                                               Temu AirTag VS Apple AirTag | Product Review | Which Is Better?                100
# 319                                                    Apple AirTag - Hidden features and NFC uses - in malayalam                100
# 320                                                          Apple Watch Ultra 2 Review: Is It Worth The Upgrade?                 67
# 324                        Jio Tag: A Cheaper Alternative to Apple AirTag? Is it worth buying fro Rs. 749? #Tamil                100
# 328                                                                       alternative type apple airtag - SEINXON                100
# 333                                                           5 Best Airtag Wallet | Top 5 Airtag Wallets in 2024                 67
# 337                                                               Apple Airtag Vs JioTag | Tamil | Scroll With Me                100
# 338                                                    JJC CP-AT1 Arca Swiss Quick Release Plate for Apple AirTag                100
# 339                                                 SMALLRIG Cage for  Apple AirTag Protect Your Camera Equipment                100
# 343                                                     Is This An AirTag Killer? | Ekster Find My Tracker Review                 67
# 346                                             Using Apple Airtags to find and recall my livestock guardian dog.                100
# 348                                                       How Jio Tag is Better Than Air Tag | HT Tech | Tech 101                 67
# 349                                                                   Top 5 BEST Apple AirTag in 2024 for amazon.                100
# 357                                                     Apple AirTag Review: Unboxing, Setup, and Real-World Test                100
# 359                                                                        AIRTAG APPLE! O MAIS PRECISO DO MUNDO!                 67
# 362                                                          Apple AirTag📍AirTags Tracker im Test &amp; Review 🇩🇪                100
# 364                                                                 Apple AirTag - Never lose your car keys again                100
# 368                                                                      Top 5 Best AirTag of 2023 (buying guide)                 67
# 369                                                             Apple Air Tag Wallet - Never Lose a Wallet Again!                 92
# 370                                                     The Most Reliable Key Finder... yet (Apple AirTag Review)                100
# 371                                                                                           Apple AirTag Review                100
# 372                                                Jio Tag Air unboxing and review ⚡️apple air tag vs jio tag air                 92
# 373                                                     Apple AirTag Tracker Review: Everything You Need to Know!                100
# 375                                                                              Tile vs Air Tag honest review. .                 67
# 377                                                                    Apple AirTag Unboxing &amp; Testing | ASMR                100
# 378                                                                               Apple AirTags and How They Work                100
# 380                                      Review Chaveiro Survival Como Colocar e Ajustar a AirTag - Baú do Viking                 67
# 381                                                                 Top 7 Best Apple AirTag Accessories in [2024]                100
# 383                                                                                    Apple Airtag 4 Pack Review                100
# 384                                How a $30 Apple AirTag can help you track your car for any situation you have!                100
# 385             Apple  AirTag Review: The Ultimate Tracking Device or Just Hype?💻 #apple #airtags #trending #tech                 92
# 386                                             Is Apple AirTag worth buying? AirTag Unboxing, Setup, and Review!                100
# 388                                                    Trakbond Trail vs Apple AirTag - Which is the Best Tracker                100
# 389                                                             FAKE Apple AirPods Pro 2 - Perfect Clone - review                 75
# 394                                                                                 Apple AirTags Unboxing   ASMR                100
# 396                                               MI HA SALVATO DA PERDERE TUTTO! | Recensione Apple Airtag | ITA                100
# 397                                                              Apple Airtag Extreme Test Review - Unboxing ASMR                100
# 398                                                                         Apple AirTag Unboxing test ASMr.anson                100
# 404                                                        Apple AirTag || বাংলা রিভিউ || SOHAiL || Deshi Bhai ||                100
# 405                  ANN air Tag review is it the same as apple air tag with 59% off with promo code limited time                 92
# 406                                          DO NOT buy an Apple Air Tag for your Dog | APPLE AIR TAG VS BYTE TAG                 92
# 407                                             El útil e infaltable en los accesorios de tu Iphone: Apple Airtag                100
# 409                                            Apple AirTag Quick Unboxing in 2023 - The Ultimate Item Tracker!🔥🔥                100
# 412                                                Save Money and Heartaches With Apple AirTags. 😢 Why Not Money.                100
# 413                                                                                     Review da AirTag da Apple                 67
# 414                                                                     Apple AirTag Unboxing &amp; Small Reviews                100
# 415                             Best Airtag 2024 | Best Airtag Review Video | #bestairtag #airtag #bestairtag2024                 67
# 416                                                                         Top 5 Best AirTag 2023 (buying guide)                 67
# 417                                   Apple AirTag Quick Review: Is It Worth the Hype? Pros &amp; Cons Explained!                100
# 418                  NEVER Lose Your Wallet Again: GAOCHALE AirTag Wallet Review (2024 Travel Security Essential)                 83
# 419                                                                         Apple Airtag vs Tile Mate older model                100
# 422                 Jio Launch JioTag tracker Rival Apple AirTag || JioTag Price | Review &amp; Unboxing In Hindi                100
# 423                                                            Apple AirTag - Unboxing, Review and Setup (in 4k*)                100
# 424                                                                     Apple AirTag Review 2024 | Back To School                100
# 427                                                    Never Lose Anything Again! Apple AirTag Review &amp; Guide                100
# 429                                                                       Review Apple AirTag官方保固至2025年11月(附原廠序號）                100
# 431                                                                                Top 5 Best AirTag Reviews 2024                 67
# 432           Apple AirTag: Your Trusty Sidekick for Effortless Tracking and Peace of Mind #CraVe # Apple #Review                100
# 434                                                        &quot;Apple AirTag Review: The Ultimate Tracker?&quot;                100
# 435          REVIEW APPLE AIRTAG || Apple Airtag&#39;i inceleyin || Kira-kira worth it gak ya❓ ||ENGLISH SUBTITLE                100
# 436                                                  🔥 Apple Airtag 4 Pack Deal or NO Deal. Podcast Just the Best                100
# 437                                                         Hablemos de: Apple AirTag Review [Experiencia de Uso]                100
# 439                                                                             Best AirTag 2023 AI Review Expert                 67
# 440                        Car tracking: Apple AirTag v Samsung SmartTag+ v GPS comparison review: Which is best?                100
# 442                                                 Apple AirTag Review: The Good, The Bad,and why you should buy                100
# 444                                                                     Air Tag ! Best Air Tag Review on Amazon !                 67
# 445                                                                 Honest Review: Apple AirTag - Is it Worth It?                100
# 446                                                                             Review Apple AirTag 蘋果 白色 現貨 蝦皮直送                100
# 447                   Apple Watch series 8| 41mm series 8 Watch | Apple air tag | Apple products series | reviews                 92
# 450                                                         &quot;Apple AI: The GAME-Changer in Modern Tech&quot;                 75
# 451                                              Our experience and honest review for Apple Airtag use as car GPS                100
# 452                                                     Unboxing Apple AirTag 4 Pack – Never Lose Anything Again!                100
# 454                                                                                     Apple AirTags for travel?                100
# 457                                                                    Apple AirTag Review: The Ultimate Tracker?                100
# 458                                                       Find &amp; Reunite With Your Items: Apple Airtag 4-Pack                100
# 460                              Apple AirTag 4 Pack Review: A Game-Changer for My Forgetful Mind 🛠️ | PADReviews                100
# 464                                                                                 Apple Airtag Holders under $5                100
# 466                                                                Review Apple AirTag 1 Pack แอร์แท็ก by Studio7                100
# 467                                                                                    Apple AirTag 4 Pack review                100
# 468                                                                                                  Apple AirTag                100
# 6                                           Apple CarPlay is AWESOME when you know how to use it! (FULL Tutorial)                 75
# 22                                                             iOS 18.1 Apple CarPlay is HERE! | 10 NEW FEATURES!                 75
# 34                                                       Apple Watch Series 9 Review: Slightly Smarter and Faster                 67
# 51                          Jio Tag review - you can get it for Rs. 749 only! (it is not an Apple Air Tag Killer)                 92
# 53                  Bike Theft: You May Regret Your Apple AirTag or Tile Stickers. Plus Bonus Anti-Theft Options.                100
# 64                                                                                        Tile vs. AirTag in 2023                 67
# 78                 How To Find A Hidden AirTag Or GPS Tracker Using The Knight KT9000 Or KT8000 Anti Spy Detector                 67
# 80                                                              Moto Tag: Der 1. ECHTE AirTag-Killer für Android!                 67
# 82                        Jio Tag unboxing &amp; review With Realtime Test, Apple AirTags Killer  || In Telugu ||                100
# 87                                                                  SMART FINDER : Le AIRTAG de ACTION pour IOS !                 75
# 89                                                          ALDI AirTag vs Apple AirTag: Lohnt sich das Original?                100
# 90                                     ONE WEEK with Android&#39;s NEW AirTag alternatives (Chipolo vs Pebblebee)                 67
# 92                                                                                    10 Best Ways to Use AirTags                 67
# 97                            Better Than AirTags For Stolen E-Bikes and Vehicles | How to Remove Atuvos Speakers                 67
# 99                                                       How To Disable Apple AirTag Speaker Sound | Voltlog #440                100
# 106                                      【MOMAX PINTAG 廉價版AirTag詳細測試】搜救Mini2 表現如何?｜FIND MY 網絡全球定位｜APPLE AIRTAG大對決                100
# 110                                      Jio Tag Unboxing &amp; Review || Apple AirTag vs JioTag Full Comparison!                100
# 112                                iOS 18.2 review - Apple Intelligence se hace más POTENTE (y hay más sorpresas)                 67
# 117                Apple Airtags VS GPS trackers - What Is The Difference Between A GPS Tracker &amp; An Air Tag?                100
# 120                                                       Goedkoper, maar ook BETER? Google Tags vs Apple AirTags                100
# 124                                         Ultimate Air Tag Test - Triple Header Flight, Four AirTags in Luggage                 75
# 125                                                    Smart Tag RẺ hơn 4 lần AirTag đạt chuẩn MFI Nhưng Rất Ngon                 67
# 126                                              This Smart Tracker For Android Works Like An AirTag! | PebbleBee                 67
# 130                                                                                Le re-test des AirTags en 2024                 67
# 141                                            Muc-Off Redesign Their Bicycle AirTag Mount... and this one works!                 75
# 146                                                                   US$9 Chinese🇨🇳made airtags on Aliexpress?!?                 75
# 147                                                        This DESTROYS Apple AirTag. Groove Wallet Trace Review                100
# 152                    Apple FindMy Tracking Available with 4iiii Power Meters // Track Your Bike Like an AirTag!                 67
# 154                                     How to set up the Cheapest Car Tracker GPS   AirTag Galaxy SmartTag+ Test                 67
# 156                                             Comparing 3 Different Cat Tracker // AirTag vs TabCat vs Tractive                 67
# 160                                      Đánh giá Divitag - “AirTag” của người Việt, giá bằng 1/3! Mua con này Ok                 67
# 163                          2-in-1 Pet Tag - an Apple Find My Tracker &amp; Pet Identification - like an AirTag!                 67
# 169                                                              Apple AirTag Unboxing and Review || in Telugu ||                100
# 172                                            Apple AirTag itu mahal, tapi yang ini versi murahnya. - Mili MiTag                100
# 173                               Leichtes, praktisches und günstiges AirTag-Portemonnaie: Bazza Armonica im Test                 67
# 188                                                              Chipolo ONE Point Review: the AirTag of Android?                 67
# 196                                     Nomad Tracking Card vs Chipolo Card Spot: Like an AirTag for your wallet!                 67
# 202                  (Almost) All the Ridge Accessories: AirTag Accessories, Valet Tray, Bottle Openers, and More                 67
# 209          TOOL THEFT PREVENTION using trackers like apple airtag, galaxy smart tag, milwaukee tick and winnes.                100
# 214                 JioTag Air | Works with Apple Find My &amp; JioThings | Better Than Apple AirTag ? *UNBOXING*                100
# 222            NEW Apple AirTag FineWoven Key Ring | In-Depth Review (ALL COLORS!) | Is this better than Leather?                100
# 223                                                  Has ANYTHING changed? Ekster Parliament AirTag Wallet REVIEW                 75
# 224                              5 MELHORES RASTREADORES BLUETOOTH para COMPRAR em 2024 ➽ SmartTag, AirTag e mais                 67
# 229        2024 Apple Watch Ultra 2 | Unboxing &amp; Short-Term Month Review | Small Upgrade or Nice Refinements?                 67
# 233                          Cheaper AirTag Alternative - Momax PinTag Find My Tracker Unboxing &amp; Explanation                 83
# 235  THE RIDGE Wallet &amp; Key Holder, Air Tag Cash Strap &amp; Money Clip Installation  EVERYTHING IN 5 MINUTES                 67
# 239                        Portronics World Tag Tracker | unboxing and setup | Airtag for Rs 500 🤯| Apple Find My                 67
# 248                                     Why ATUVOS SlimTag is the (Almost) Perfect AirTag Alternative for Wallets                 67
# 255         JioTag Go | Works with Android Find My Device &amp; JioThings | Better Than Apple AirTag ? *UNBOXING*                100
# 261                                                                                Apple AirTag vs Tile Mate 2024                100
# 266                                               Rossm Carbon Fiber AirTag Wallet Unboxing, Overview, and Set-up                 67
# 284                                                         Jio Tag Unboxing &amp; Review | Apple AirTag Killer 🔥                100
# 285                      How To Pair JioTag Air with Iphone Find My App | JioTag Air Unboxing | JioTag Air Review                 67
# 290              Ronin Smart Tracker R101 unboxing and review | Initial setup | Apple AirTag Clone?? | 2024 model                100
# 295                                                        Apple AirTag Alternative Smart Finder Action VS Atuvos                100
# 308                                                    Protronics World Tag, a best alternative of Apple Airtags.                100
# 309                    JioTag Air Unboxing &amp; Review 🔥 | Best Alternative to Apple AirTags for Just Rs.1,499 ?                100
# 322                                                                             Lorzor Apple AirTag Wallet Review                100
# 325                                                          UTAG GPS Trackers ( Cheaper than Apple AirTags ) #ad                100
# 326                                                                          SecuLife Kids GPS Tracker VS AirTags                 67
# 329                                      Apple Airtag pack 4 Unboxing and features in Hindi #airtag #apple Vlog 4                100
# 330                                        JioTag- ഒരു അടിപൊളി lost and found Tracker | Apple AirTag Alternative!                100
# 331      Rs 750 JioTag: Unboxing, review, &amp; comparison with Apple AirTag. JioTag vs. AirTag which one to buy?                100
# 332                                       Samsung Galaxy Tag 2 Full Review |  Is It Better Than Airtag |  Tamil |                 67
# 334                                                          Apple AirTag Review avoid thieves stealing your car.                100
# 335          📦Unboxing &amp; Review PITAKA Accessories for iPhone + iPad Pro + Apple Watch + AirPods Pro + AirTag                 67
# 336                                  Apple airtag alternative | world tag | portronics world tag review in telugu                100
# 341                                                UAG SCOUT APPLE AIRTAG HOLDER (super fast unboxing and review)                100
# 345                                           The Better Rechargeble Airtag?! Seinxion Finder Series Short Review                 75
# 351   No one will expect there&#39;s an Apple AirTag stored right here. | Kalauto Bike Light | Unbox &amp; Review                100
# 352                                                                         Men&#39;s Apple Airtag Wallet- REVIEW                100
# 354                                                    AirTag de APPLE: Nadie te ha contado esto... [REVIEW 2024]                 67
# 360                                             Nur eine Spielerei oder wirklich nützlich? // Das AirTag - Review                 67
# 363                           Smart Tag ကဘာလုပ်လို့ရလဲ ? Apple Air Tag နဲ့ Samsung Smart Tag ဆိုရင်ရောဘာရွေးမလဲ ?                 92
# 365                                                       Keepaws review - Apple AirTag collar and tactical leash                100
# 367                                THE RIDGE WALLET: North Shore and Apple AirTag Money Clip Bulk Review and Test                100
# 374                                                                             How to setup Apple AirTag. #apple                100
# 376                                                              Amazing Apple Airtags Bluetooth Tracker ANNNWZZS                100
# 379           HOW TO FIND LOST AIRPODS + AIRPODS 3 REVIEW (3RD GENERATION) + BUILT IN AIRTAG + AIRPODS COMPARISON                 67
# 387                                                               Apple AirTag | Dispositivo localizador | Review                100
# 390                                       Toronata iPhone Wallet Case, Apple Watch Band, and AirTag Holder Review                 67
# 391                                             Unboxing, comparison, and review of alternatives to Apple Airtags                100
# 393                                 Eufy Smarttrack Link for iPhone…AirTag Alternative? #unboxing #review #amazon                 67
# 399            HOW TO REPLACE APPLE AIRTAG BATTERY + FINDING LOST AIRTAG + STORYTIME  + BIGGERFIVE TRACKER REVIEW                100
# 400                                                         Apple Airtag Pack Unboxing Full Video Review Best TAG                100
# 408                                                     Tars Airtag Wallet Review | Never Lose Your Wallet Again!                 67
# 411                                           Never Lose Anything Again! Explore the Wonders of Apple AirTag! 🚀🔑🔍                100
# 425                                                                                          Apple Airtag reviews                100
# 426                                                                     Apple AirTag Review - GPS Location Device                100
# 430                                                                        Apple AirTag | Locator device | Review                100
# 433                                                 Apple Airtag Review: Mehr Sicherheit und andere Einsatzzwecke                100
# 438                                                                                           Apple AirTag Review                100
# 448                     Apple Air Tag unboxing in Tamil | Apple Air Tag review in Tamil | Air tag review in Tamil                 92
# 449                                             Apple AirTag 4 Pack, Unboxing, Review and how to connect and use.                100
# 453                                                                           Apple Airtag | UNBOXING AND REVIEW!                100
# 456                AiraTag எப்படி இருக்கு|  AirTag unboxing in Tamil | AirTag Review in Tamil @ProductReviewTamil                 67
# 459                                                              Why Your Wi-Fi Router Doubles as an Apple AirTag                100
# 461                                                                      Apple AirTag Review: The Pros and Cons 🤔                100
# 465                                                                         Apple Airtag 3 Reviews - Good and Bad                100
#
# Matching descriptions in cache\cleaned_ytb_search_combined_results_apple_airtag.csv:
#                                                                                                                                      video_description  fuzzy_ratio_description
# 12                  I show you how to properly modify and track your car with Apple AirTags. Apple AirTags are wonderful tracking devices that can ...                      100
# 16                      In this video I show you all the top Tips, Tricks & Hidden Features on the Apple Watch Series 9 that you absolutely MUST KNOW!                       67
# 19                   In diesem Video zeige ich dir eine versteckte und extrem praktische Funktion für deine AirTags, die du so bestimmt noch nicht ...                       67
# 23                      What parts of the Apple Watch Series 9's experience really make it stand out from previous models 6 Months Later? What new ...                       67
# 25                 Here's every single difference between the Apple Watch Ultra 2 and the Apple Watch Series 10, covering everything from price to ...                       67
# 29               Installing the Apple Intelligence update will add a whole new layer of features and functions to your iPhone! After testing Apple ...                       67
# 31                       In-depth sports and fitness review of the new Apple Watch Series 9 covering heart rate accuracy, GPS accuracy, and how it ...                       67
# 33              This video shows the best way to add an Apple AirTag to your bike to prevent it from being found so you can locate the position if ...                      100
# 38                  Here's your complete Apple Watch Series 9 review, diving into all the new features and how well they work! Buy the Apple Watch ...                       67
# 46                                   Today I will be unboxing the 46mm version of the Apple Watch Series 10. I hope you enjoy! #asmr #apple #unboxing.                       67
# 58                            iOS 18 & iOS 18.1 Beta - More New Features, Performance, Battery Life, New iPhone 17 Leaks, Crazy AirTags Story, & More!                       67
# 62                 iOS 18.2 Beta - More Apple Intelligence Features, Performance, Battery Life, M4 Macs Released, Vision Pro, Crazy AirTags Story, ...                       67
# 66                  Comprehensive review of the Apple Watch Ultra 2 and how it compares to the original Apple Watch Ultra. You can get the Ultra 2 ...                       67
# 70                    Seit über 2 Jahren nutze ich mehrere AirTags im Alltag. In diesem Video erzähle ich euch aus meiner bisherigen Erfahrung und ...                       67
# 71                                      moto teg https://mercadolivre.com/sec/2QeyxqE AirTag https://mercadolivre.com/sec/1QTpYST Galaxy SmartTag2 ...                       67
# 79                        Warum der Galaxy SmartTag2 von Samsung der beste smarte Tracker überhaupt ist, und warum er die Apple AirTags und andere ...                      100
# 96                Last year I had two bikes stolen. Many viewers commented that they hide an Apple AirTag on their bike so they could locate it if ...                      100
# 100            All in all, if you need to keep track of your gear and you're running on Apple, an AirTag is a low cost, high quality piece of tech ...                       67
# 107              Here is Apple airtag unboxing and I also compared the Apple Airtag with the JioTag. Is this Jiotag really an apple airtag killer, ...                      100
# 108                         Xiaomi lança Smart Tag que funciona na Apple. Mais uma AirTag genérica para você comprar que é muito mais barata que a ...                       67
# 115     In todays video we take a first (late) look at the AirTag from Apple. Is it still worth it in 2023 and whats next? Lets take a look! Apple ...                       67
# 128         Looking for the best AirTag mounts for your bicycle? Look no further! In this video, we'll take a closer look at the top AirTag mounts ...                       67
# 137                           Ещё один из, бюджетных, аналогов apple AirTag - hoco E91. Мне понадобился ещё один AirTag, но покупать дорогой apple ...                      100
# 138               In this hands-on guide, we've rounded up our favorite Apple AirTag accessories from keychains, cases, and holders - all of which ...                      100
# 139                Comparativa entre el AirTag de Apple original y las alternativas más baratas y con mejores precios. Hay algunas diferencias que ...                       67
# 150                    Mua ngay Airtag chính hãng tại: https://didongviet.vn/phu-kien/apple-airtag.html?utm_source=reviewos AirTag sử dụng chip U1 ...                       92
# 151             Is Eufy's SmartTrack Link better than an Apple AirTag? Pick up yours here: https://amzn.to/3ydkX0Y In this wonderful video (LOL) I ...                      100
# 165             You guys complained, and Mili listened! My favorite AirTag alternative is now on Android! The Mili MiTag Go is not only affordable ...                       67
# 166                                                                                                     apple #airtag - iPad mini, iPad Pro, iPad Air.                       92
# 167          In this video we compare different types of car tracker to the Apple AirTag - is this the future of car tracking and could it help to ...                      100
# 168           Fake Airtag that is better than the real? This is the question, we will be putting that to the test today! Thank you all so much for ...                       75
# 175                                                              MiLi MiTag Dog Cat GPS Tracker - Best AirTag Alternative iOS Review Product Link: ...                       67
# 176             Is Portronics World Tag is a competitive device for Apple Airtag? Check this review to know more. Check latest price & deals here: ...                      100
# 179       If you've ever felt the apple air tag to be too big for your wallet then this is might me the device for you. Check out my review of the ...                       92
# 180              Introducing Mitag, the best alternative to Apple's Airtag. With the same functions and even more affordable, Mitag is the perfect ...                       83
# 181                    Jio Tag Air New (2024) vs Apple Air Tag - Which is ACTUALLY Better? Jio just launched their new Tag Air 2024 edition, We're ...                       92
# 182                    This is my full review of my new Apple Watch Ultra 2. Spoiler - YOU SHOULD BUY IT ! ✓ Subscribe to get the most out of your ...                       67
# 184         If you looking for Best Airtag Wallet 2023. This video is for you. Here a collection you got a see. Lets get started. Check The Price: ...                       67
# 192                                 Spigen Passport Holder, AirTag Holder & Apple AirTag (Unboxing + Review) Spigen Passport Holder Purchase Link: ...                      100
# 200                       Joel shares an Apple AirTags review to help you decide if it is worth buying. BUY THE AIRTAGS ➡️ https://amzn.to/3UsmqMu ...                      100
# 203      Ben je je sleutels wel eens kwijt of wil je jouw koffer niet verliezen? Dan is dit dingetje wel wat voor jou, de Apple Airtag. Wat het is ...                      100
# 204                            Please download the app: " Tracker Detect " from Google Play Are Android users really missing out on Apple's AirTag ...                       83
# 205             I wanted to try out a bluetooth tracker for the first time, that was Apple compatible, but didn't cost the Earth! Here's how I got on.                       67
# 206             Where to get yours: 1. Apple AirTag: https://amzn.to/4bcJxk4 2. Apple AirTag Magnetic Protective Vault: https://amzn.to/49Zd0gq In ...                      100
# 208               Apple AirTags have to be one of the most interesting products I've come across in the last few years. Their application goes far ...                      100
# 213                  airtags #apple #tracking #tracker #magtag #aussieprepper #howto #carsecurity #preppeing #securitytags #cartracker #dogtracker ...                       67
# 216        Find some of them here: https://lon.tv/nu8ly (compensated affiliate link) - Apple's AirTag is a great product but the cost can escalate ...                       83
# 218               Today I'm reviewing the Apple AirTag to the iTag. It promises many features but does it I've up to the hype? Find out and let me ...                      100
# 219                    Real life Test with Apple AirTag Vs Jio Tag Air | Setup, Range Test & Review Introducing the new JioTag Air, a cutting-edge ...                      100
# 220                                airtag #apple #jiotagair JioTag Air | Works with Apple Find My Better Than Apple AirTag ? BUY NOW - Jio Tag air ...                       75
# 227                                Digital Walker and Beyond the Box are now selling this waaaaay more affordable alternative to Airtag. Buy here: ...                       67
# 237                  Westaur Leather has produced a great AirTag wallet which is slim, but works best as an everyday carry case for the Apple tracker!                       67
# 245           In this video, we're taking a look at the WXM Minimalist Wallet with RFID and AirTag support. Is it any good? This minimalist wallet ...                       67
# 247       In this video we show our latest design of a spare wheel apple airtag holder. Ideal to track your vehicle if it is stolen etc. These are ...                      100
# 250                  Hallo guys welcome back to my youtube channel. Di video kali ini gue akan bahas Beli AirTag Apple di Tahun ini Tidak Worth It ...                       75
# 253            This video is me unboxing the rolling square aircard, and alternative to the apple AirTag designed to be used in wallets, and still ...                      100
# 254                                 Lozor Apple AirTag Wallet - https://amzn.to/3vb5EYG Apple AirTag - https://amzn.to/4aap1jn Other Lozor Wallets ...                      100
# 262                 eufy SmartTrack Link Tag - unboxing and set up review - eufy's answer to Apple AirTag Follow us on Facebook at the worlds most ...                      100
# 267                      Find out how it works and how to configure Apple AirTags in 2023. Complete guide with information to make the most of the ...                      100
# 268  แนะนำสั่งซื้อ AirTag ราคา promotion ได้ที่ Apple Flagship store ราคาถูกกว่า (รอช่วงโปร) ตาม link ร้านนี้เลยครับ https://s.lazada.co.th/l.1j1v ...                       67
# 269              5 Best AirTag Case | Top 5 AirTag Cases with Key Ring in 2023 AirTags have no built-in keychain hole, but you can fix that easily ...                       67
# 272                   Are you looking for the Best AirTag Wallet? Check the list below for the Best AirTag Wallets currently on the market. See my ...                       67
# 274                  Jio Tag review - you can get it for Rs. 749 only! Jio Tag vs Apple Air Tag | Best Technicals Open your Upstox account and get ...                       92
# 275                 Apple Watch Series 10 (46mm, jet black) vs Series 5 (40mm, space grey). My brutally honest, sleep-deprived thoughts. Instagram ...                       67
# 276                             Hey! Join me in this cozy unboxing as we check out the amazing USB-C AirPods Pro 2 and the cool AirTags! ✨ ✨ Links ...                       67
# 277                        If you want to avoid the hassle of losing your cash or cards, you should consider getting a wallet that includes an AirTag.                       67
# 280                     iOS 18.2 Beta 3 Released - What's New? Apple Intelligence Features | iOS 18 Features, Changes, Performance & Battery Apple ...                       67
# 283                      Como colocar e ajustar a AirTag na pulseira kids. Somos o Baú do Viking, especializados em Apple Watch, AirTags e AirPods ...                       67
# 288                                Jio Tag Unboxing & Review with Real Test | Apple Air Tag Killer | Jio Tracker | Jio Tag 2023 Telugu Buy Jio Tag ...                       92
# 289                 Apple airtags review 2023 - I kept losing my keys and hoped to find a solution. That's why I decided to try out the Apple AirTags.                      100
# 294               The Apple AirTags are little disc-shaped Bluetooth tracking devices that you can use to to track anything from your keys to your ...                      100
# 299            Dive into the future with us as we revisit the Apple AirTag in 2024! Join this exciting review where we explore the latest updates, ...                      100
# ...
# 375                                                    We like to save money us Yorkshire folk so we're test driving a Tesla electric car this week…                       62
# 377                    Best Car Seats For Tesla Model Y ▽ ▻ Britax One4Life: https://amzn.to/3ywHPMw ▻ Graco Extend2Fit: https://amzn.to/44SEXFu ...                      100
# 379              This is an honest review of the Tesla Model Y Long Range after driving it for 10000 miles. We have had the Model Y for almost 1 ...                      100
# 380            In this honest Tesla Model Y review, we take a look at the car and how it has held up after 25000 miles. We also discuss the cost ...                      100
# 381          If you think the Model Y is right for you, please consider using my affiliate link below. Thanks for watching! http://ts.la/jason27133.                       69
# 382                      2025 Tesla Model Y Unveiled: The Ultimate Electric SUV Full Review!! Join us on MotorMinds as we explore the 2025 Tesla ...                      100
# 383               We recently tested the new 2024 Tesla Model Y, which has been on sale in Ireland since 2022 and is designed as a larger SUV to ...                      100
# 385                New wheels and tires for the Tesla Model Y - Find out what I bought! 2023 Please LIKE and Subscribe. Comment all you want but ...                      100
# 386             in the video review I go over the new 2024 Tesla Model Y with one of the worst 3rd rows I have ever seen in a vehicle that is on ...                      100
# 389                     "Bad News for 2025 Tesla Model Y Juniper Review: Price, Range, Features, Performance & Interior" Bad News for 2025 Tesla ...                      100
# 390                     tesla #elonmusk #juniper No More Model Y. Elon Musk Announces 2025 Tesla Model Y Juniper Official Unveiled. Get ready to ...                       69
# 391                      For an upcoming road trip my family needed a way to mount a Starlink Mini in our 2024 Tesla Model Y Performance to have ...                      100
# 392                         Review of my 2021 Tesla Model Y Long Range with over 100000 miles! Runs like new! The good, the bad, and the in-between!                      100
# 393                        tesla #modely #model3 Fog Lifhts Installation and First Impression Video: https://youtu.be/GeSGFA-biuo?feature=shared ...                       92
# 394               Welcome to the 2023 Tesla Model Y Dual Motor Test Drive & Review. The range starts off with a rwd base Model Y starting in the ...                      100
# 396                 Use my Tesla Referral Code for up to $1000 Off A Brand New Tesla: https://ts.la/timothy312927 My New Model Y Dual Motor Long ...                       69
# 397               Today we take a look at Tesla Model Y 2025 Full Review and Test Drive! Finally, it is here! What do you think of the NEW Tesla ...                      100
# 399              Installation, Review and Test Drive after installation of Otrifowd Magshade for Tesla Model Y and Tesla Model 3 Glass Roof with ...                      100
# 400            My Dad has wanted to make another video test driving the new Tesla Model Y, so during a recent visit, he got to test drive it and ...                      100
# 401             The Tesla Model Y spoiler install was way easier than I could have anticipated. With only taking about 10-15 mins for the entire ...                      100
# 403             Welcome to our detailed review of the 2024 Tesla Model Y! In this video, we're taking a close look at the styling, features, and ...                      100
# 404                        New 2024 Tesla Model Y Review: The Greatest EV Ever Made That Will Blow Your Mind. DON'T WAIT!!! === 00:00 Intro 00:45 1.                      100
# 405                     2025 Tesla Model Y Review: The Future of Electric SUVs Description: Step into the 2025 Tesla Model Y, where cutting-edge ...                      100
# 406                                    Rivian R2 VS R3 Test Drive : https://youtu.be/WAhfiSiva6s?feature=shared Tesla Model Y 2 Seater Launched: ...                      100
# 407                        2025 Tesla Model Y REVIEW: Unveiling the Game-Changing Features and Next-Gen Upgrade! The 2025 Tesla Model Y with the ...                      100
# 408     Links to the Best tires for tesla model y 2025 is in below ▽ In this Best tires for tesla model y reviews video, we try to pick the Best ...                      100
# 409              2025 Tesla Model Y Review: The best electric SUV! Juniper is here? In this review, we take a deep dive into the new Tesla Model ...                      100
# 410               Are you interested in the new Tesla Model Y? In this video, we'll review all the new features and tips for the Tesla Model Y 2024.                      100
# 411             In this video we will be talking about Tesla Model Y. We will give a full honest review on it. Everything from the Tesla Model Y ...                      100
# 412                        What is the best Tesla model? When you compare the Tesla Model Y vs Model 3, which one comes out on top? Car reviewer ...                       92
# 413                       2025 Tesla Model Y Review The EV That Changes EVERYTHING! Get ready to experience the future of electric SUVs with our ...                      100
# 414                            Watch▻Tesla Model Y Car Review With New Features | @sumantvnewyorknewjersey #tesla #teslamodely #modely #elonmusk ...                      100
# 415                 The 2025 Tesla Model Y Is a Total Game-Changer Discover the groundbreaking updates in the 2025 Tesla Model Y, from its sleek ...                      100
# 416            Do I regret upgrading from a Tesla Model 3 to a Tesla Model Y? Should I have waited for a refreshed tesla model? This is my tesla ...                      100
# 418                   a review of the 2023 tesla model y (performance) https://www.tesla.com/ https://www.tesla.com/compare?selectedModel=modely ...                      100
# 420                      Thanks For Watching Order A New Tesla With £2000 Off Here - https://ts.la/shaun207678 Tesla Model 3 Performance Review: ...                       92
# 423                  Join me as I introduce my 2023 Tesla Model Y. If you like what you see, use my referral link to purchase a Tesla product or ...                      100
# 424               Hi everyone, in this video I go over my thoughts about the Tesla Model Y we purchased back in May 2024. I discuss the charging ...                      100
# 425           Get ready for the future of electric vehicles with the 2025 Tesla Model Y Juniper! In this comprehensive review, we dive deep into ...                      100
# 426                    2025 Tesla Model Y Review: Efficiency Meets Style Disclaimer:- The information presented in this video is based on topics ...                      100
# 428                  2025 Tesla Model Y Review – Range, Performance & Features Explained! #tesla #teslamodely In this video, we take an in-depth ...                      100
# 429             "Discover the ultimate Tesla Model Y review by Auto Trend 9 Master. Explore its performance, technology, interior, and practicality.                      100
# 430                   teslanews #teslacar #teslamodely #teslamodelyperformance Welcome to 2023, and today we are going to take a look at the new ...                       85
# 431                      Top Hashtags: #ToyotaBZ4X #TeslaModelY #EVReview Title: 2025 Toyota bZ4X Review: Tesla Model Y's New Rival? Is the 2025 ...                      100
# 432               Check out the Tlyard 7-Inch Rear Display Screen for Tesla Model 3 & Y. This screen adds comfort and entertainment for backseat ...                       92
# 434       Be sure to follow Lisa channel here: If you would like to purchase a Tesla, use my referral link find out what you could get for using ...                       69
# 436                 2025 Tesla Model Y is here, and it's packed with incredible upgrades that will make you rethink what an electric vehicle can do!                      100
# 437               Description in Paragraph: The 2025 Tesla Model Y brings exciting upgrades and impressive features that make it one of the most ...                      100
# 438                    "Tesla Model Y Review: Best Discounts, Full Self-Driving, Range, Charging, and Accessories You Need to Know!" Tesla Model ...                      100
# 439                           Correction** It does work for the 7 Passenger Model Y =) LASFIT Second Row Seats Back Cover Mats All Weather Link: ...                       69
# 440                    2024 Tesla Model Y: The Future of Electric SUVs . The 2024 Tesla Model Y takes electric SUVs to the next level, combining ...                      100
# 441                       If you're planning on taking the plunge into the growing world of EVs, the Tesla Model Y may be your new favourite choice.                      100
# 443                  Join us as we take a closer look at the performance, design, and overall driving experience of the 2024 Model Y. We'll also ...                       62
# 444             We thought it was a hoax when we got an email from Tesla asking whether we'd like to try out the Tesla Model Y. Turns out it was ...                      100
# 445             In this video, we take an in-depth look at the 2025 Tesla Model Y, covering everything from its sleek new exterior design to the ...                      100
# 446                  This video is the unboxing & review of the Basenor Rear Seat Back Cover for the Tesla Model Y. -------- Check Price or Buy: ...                      100
# 447               In this comprehensive review of the 2024 Tesla Model Y, we dive deep into what makes this electric vehicle a contender for the ...                      100
# 449                      teslamodely #tesla #elonmusk 2025 Tesla Model Y Opal: Elon Musk Reviews 7 Game-Changing Features That Make It Worth the ...                      100
# 450            "Join us for an in-depth review of the all-new 2025 Tesla Model Y Juniper! In this video, we explore Tesla's latest electric SUV, ...                      100
# 451                                                                                           This is the review of a 2025 Tesla Model Y Long Range.                      100
# 452                   2025 Tesla Model Y Review: Features, Performance, and More Paragraph: The 2025 Tesla Model Y is a standout in the electric ...                      100
# 453                                                                            50k Mile Tesla Model Y Review - Is It Worth It?! Thanks for Watching.                      100
# 454             Discover the all-new 2025 Tesla Model Y Juniper, a revolutionary electric SUV that redefines luxury, performance, and technology ...                      100
# 456               Hey guys, in this video i do a quick recap/review of my 2023 Tesla Model Y RWD after 1 year of ownership. The Jay Leno video I ...                      100
# 457                       "2025 Tesla Model Y Review: Design, Performance, Range, Autopilot & New Features" **Description**: Welcome back to our ...                      100
# 458                Welcome to our comprehensive review of the Tesla Model Y 2023. In this video, we leave no stone unturned as we dive deep into ...                      100
# 459                Discover the Tesla Model Y Long Range All-Wheel Drive in our overview! From its impressive efficiency and remarkable range to ...                      100
# 460           teslamodely #tesla 2025 tesla model y refresh - In this video, we take a deep dive into the highly anticipated 2025 Tesla Model Y, ...                      100
# 461                 Welcome to our in-depth review of the highly anticipated 2023 Tesla Model Y with Daniel Romero. In this comprehensive video, ...                      100
# 462             If you're looking to purchase a Tesla product please use my referral link. You'll earn credits to redeem for Supercharging miles ...                       62
# 463                                                                                                                Tesla Model Y walk-around review.                      100
# 464                     Here's a detailed and engaging description for your YouTube video: --- 2025 Tesla Model Y Review: Everything You Need to ...                      100
# 467                       Exploring the Tesla Model Y! Discover the future of electric SUVs with me as we delve into the impressive features and ...                      100
# 468                    Tesla Model Y Juniper: Full Review, New Features & Design Upgrades! ⚡ Welcome to our in-depth review of the Tesla Model Y ...                      100
# 469               Hello Everyone Welcome Back to My channel In this comprehensive review of the Tesla Model Y, we dive deep into every detail of ...                      100
# 470                                                                                       Here is a full in-depth review of this 2022 Tesla Model Y!                      100
# 471                                                                                                                     Tesla Model Y Review. Day 1.                      100
# 472                    New Tesla model y review-longer range And cheaper!The Ultimate Ev Game Changer! Discover the exciting new features of the ...                      100
# 474                 Tesla Model Y 2025: Charging, Range, and Real-World Use! Full Review Discover the 2025 Tesla Model Y: The Future of Electric ...                      100
# 475         In this detailed review, we take a closer look at the all-new 2025 Tesla Model Y. From its sleek exterior design to its cutting-edge ...                      100
# 476                Hey everyone, welcome back to the channel! Today, we're diving into an in-depth review of the Tesla Model Y, Tesla's electric ...                      100
# 477                 "2025 Tesla Model Y Juniper Review: A New Era in Electric Driving" The 2025 Tesla Model Y Juniper is here, and it's changing ...                      100
# 5               In this video, you will learn about 23 hidden features in the Tesla Model Y and 3 that you may not know about. Even if you think ...                      100
# 13                            I've had the Model Y for over a year, and here is my long term review! How does this care compare to the VS Mach-E ...                       77
# 148       In this video, share my review of the Tesla Model Y Long Range after driving it for 20000 miles. I discuss all of the associated costs ...                      100
# 152  Picking a tint for your Tesla can be difficult, especially if you have white seats. In this video I go over: the advantages of tinting your ...                       62
# 189             This may be the best update for Tesla Model Y yet. Lets check out the S3XY Knob and it's best features like autopilot update and ...                      100
# 206              I purchased the Tesla Homelink for my Tesla Model Y for $350. I thought it was the best. But then I realized it stays with that ...                      100
# 335                    Tesla offering 0% interest but with some rules you need to know plus, the $7500 EV tax credit is going away (what to expect).                       62
# 367                    Tesla eyes 2025 with new incentives and features! A more affordable Tesla is coming plus the refresh Model Y Juniper spotted.                       77
# 369                                            Bought this Tesla Pet Liner ONLY for Model Y / S / 3 . Link to buy below ⬇️ Model S/3/Y Pet Liner ...                       62
#
# Total matches: 457
# 10

# %%
for i, df in enumerate(processed_dfs):
    output_path = csv_combined[i].replace('.csv', '_matched_keywords.csv')
    df.to_csv(output_path, index=False)
    print(f"Processed data saved to {output_path}")
# Out:
# Processed data saved to cache\cleaned_ytb_search_combined_results_apple_airtag_matched_keywords.csv
# Processed data saved to cache\cleaned_ytb_search_combined_results_cosrx_snail_mucin_serum_matched_keywords.csv
# Processed data saved to cache\cleaned_ytb_search_combined_results_liquid_death_matched_keywords.csv
# Processed data saved to cache\cleaned_ytb_search_combined_results_lululemon_align_pants_matched_keywords.csv
# Processed data saved to cache\cleaned_ytb_search_combined_results_macbook_pro_m4_matched_keywords.csv
# Processed data saved to cache\cleaned_ytb_search_combined_results_meta_quest_3_matched_keywords.csv
# Processed data saved to cache\cleaned_ytb_search_combined_results_samsung_galaxy_watch_7_matched_keywords.csv
# Processed data saved to cache\cleaned_ytb_search_combined_results_samsung_oled_tv_matched_keywords.csv
# Processed data saved to cache\cleaned_ytb_search_combined_results_stanley_tumbler_matched_keywords.csv
# Processed data saved to cache\cleaned_ytb_search_combined_results_tesla_model_y_matched_keywords.csv

# %%
import glob

csv_matched = glob.glob(os.path.join(CACHE_DIR, "cleaned_ytb_search_combined_*matched_keywords.csv"))
#csv_combined = [file for file in csv_combined if not file.endswith('_metadata.csv')]
csv_matched
# Out:
# ['cache\\cleaned_ytb_search_combined_results_apple_airtag_matched_keywords.csv',
#  'cache\\cleaned_ytb_search_combined_results_cosrx_snail_mucin_serum_matched_keywords.csv',
#  'cache\\cleaned_ytb_search_combined_results_liquid_death_matched_keywords.csv',
#  'cache\\cleaned_ytb_search_combined_results_lululemon_align_pants_matched_keywords.csv',
#  'cache\\cleaned_ytb_search_combined_results_macbook_pro_m4_matched_keywords.csv',
#  'cache\\cleaned_ytb_search_combined_results_meta_quest_3_matched_keywords.csv',
#  'cache\\cleaned_ytb_search_combined_results_samsung_galaxy_watch_7_matched_keywords.csv',
#  'cache\\cleaned_ytb_search_combined_results_samsung_oled_tv_matched_keywords.csv',
#  'cache\\cleaned_ytb_search_combined_results_stanley_tumbler_matched_keywords.csv',
#  'cache\\cleaned_ytb_search_combined_results_tesla_model_y_matched_keywords.csv']

# %%
for csv in csv_matched:
    df = pd.read_csv(csv)
    # Use parentheses and & or | operators for boolean operations in pandas
    df_matched = df[
        (df['matched_title'] == 1) | 
        (df['matched_description'] == 1)
    ].copy()  # Use .copy() to avoid SettingWithCopyWarning
    
    print(f"\nAnalysis for {csv}:")
    print(f"Total matched rows: {len(df_matched)}")
    
    # Count non-null transcripts in matched rows
    transcript_count = df_matched['transcript'].notna().sum()
    print(f"Total non-empty transcripts: {transcript_count}")


    # try to recover transcript for videos with no transcript using get_transcript
    for index, row in df_matched.iterrows():
        if pd.isnull(row['transcript']):
            video_id = row['video_id']
            transcript_dict = get_transcript(video_id)
            df_matched.at[index, 'transcript'] = transcript_dict['transcript']
            df_matched.at[index, 'transcript_is_generated'] = transcript_dict['transcript_is_generated']
            print(f"Transcript recovered for video ID: {video_id}")

    # # Count non-null transcripts in matched rows
    # transcript_count = df_matched['transcript'].notna().sum()
    # print(f"Total non-empty transcripts after recovery: {transcript_count}")

    # # Save updated DataFrame with recovered transcripts
    # df_matched.to_csv(csv, index=False)
    # print(f"Processed data saved to {csv}")
# Out:
# Analysis for cache\cleaned_ytb_search_combined_results_apple_airtag_matched_keywords.csv:
# Total matched rows: 306
# Total non-empty transcripts: 221
#
# Analysis for cache\cleaned_ytb_search_combined_results_cosrx_snail_mucin_serum_matched_keywords.csv:
# Total matched rows: 288
# Total non-empty transcripts: 155
#
# Analysis for cache\cleaned_ytb_search_combined_results_liquid_death_matched_keywords.csv:
# Total matched rows: 307
# Total non-empty transcripts: 285
#
# Analysis for cache\cleaned_ytb_search_combined_results_lululemon_align_pants_matched_keywords.csv:
# Total matched rows: 286
# Total non-empty transcripts: 282
#
# Analysis for cache\cleaned_ytb_search_combined_results_macbook_pro_m4_matched_keywords.csv:
# Total matched rows: 276
# Total non-empty transcripts: 192
#
# Analysis for cache\cleaned_ytb_search_combined_results_meta_quest_3_matched_keywords.csv:
# Total matched rows: 449
# Total non-empty transcripts: 421
#
# Analysis for cache\cleaned_ytb_search_combined_results_samsung_galaxy_watch_7_matched_keywords.csv:
# Total matched rows: 386
# Total non-empty transcripts: 238
#
# Analysis for cache\cleaned_ytb_search_combined_results_samsung_oled_tv_matched_keywords.csv:
# Total matched rows: 288
# Total non-empty transcripts: 237
#
# Analysis for cache\cleaned_ytb_search_combined_results_stanley_tumbler_matched_keywords.csv:
# Total matched rows: 353
# Total non-empty transcripts: 307
#
# Analysis for cache\cleaned_ytb_search_combined_results_tesla_model_y_matched_keywords.csv:
# Total matched rows: 466
# Total non-empty transcripts: 442

# %%
# append metadata to the dataframes
import glob
import pandas as pd

csv_matched = glob.glob(os.path.join(CACHE_DIR, "cleaned_ytb_search_combined_*matched_keywords.csv"))
for csv in csv_matched:
    df = pd.read_csv(csv)
    # Use parentheses and & or | operators for boolean operations in pandas
    df_matched = df[
        (df['matched_title'] == 1) | 
        (df['matched_description'] == 1)    
    ]

    df_matched = fetch_metadata_for_dataframe(df_matched, category="fashion_50")
    df_matched.to_csv(csv, index=False)

# %%
import glob

csv_matched = glob.glob(os.path.join(CACHE_DIR, "cleaned_ytb_search_combined_*matched_keywords.csv"))
#csv_combined = [file for file in csv_combined if not file.endswith('_metadata.csv')]
csv_matched
# Out:
# ['cache\\cleaned_ytb_search_combined_results_apple_airtag_matched_keywords.csv',
#  'cache\\cleaned_ytb_search_combined_results_cosrx_snail_mucin_serum_matched_keywords.csv',
#  'cache\\cleaned_ytb_search_combined_results_liquid_death_matched_keywords.csv',
#  'cache\\cleaned_ytb_search_combined_results_lululemon_align_pants_matched_keywords.csv',
#  'cache\\cleaned_ytb_search_combined_results_macbook_pro_m4_matched_keywords.csv',
#  'cache\\cleaned_ytb_search_combined_results_meta_quest_3_matched_keywords.csv',
#  'cache\\cleaned_ytb_search_combined_results_samsung_galaxy_watch_7_matched_keywords.csv',
#  'cache\\cleaned_ytb_search_combined_results_samsung_oled_tv_matched_keywords.csv',
#  'cache\\cleaned_ytb_search_combined_results_stanley_tumbler_matched_keywords.csv',
#  'cache\\cleaned_ytb_search_combined_results_tesla_model_y_matched_keywords.csv']

# %%
# fetch meta data for each df, then save to csv and excel

for csv in csv_matched[:]:
    ytb_search_df = pd.read_csv(csv)
    category = os.path.basename(csv).split("results_")[-1].split(".")[0].replace("_matched_keywords", "")
    print(category)
    ytb_search_df = fetch_metadata_for_dataframe(ytb_search_df, category=category)
    # ytb_search_df.to_csv(os.path.join(CACHE_DIR, f"ytb_search_combined_results_{category}_metadata.csv"), index=False)
    # ytb_search_df.to_excel(os.path.join(CACHE_DIR, f"ytb_search_combined_results_{category}_metadata.xlsx"), index=False)
    print(f"Finished processing {category} videos. Total videos: {len(ytb_search_df)}")
# Out:
# apple_airtag
# Skipping cB9ukX5_tp8: Already in cache.
# Skipping CLOOLOdg5Jw: Already in cache.
# Skipping cSkYaHGPfBQ: Already in cache.
# Skipping wM16xWaJHbU: Already in cache.
# Skipping zj-dM0B1l28: Already in cache.
# Skipping F2tXw74fyxc: Already in cache.
# Skipping R4JXjsbx45U: Already in cache.
# Skipping hiivC_4li8Q: Already in cache.
# Skipping 44FEs8jAN9Y: Already in cache.
# Skipping xNAJkhDW8tg: Already in cache.
# Skipping 7mOoMwxpN04: Already in cache.
# Skipping BmgCyR-JXhA: Already in cache.
# Skipping zhvv5_Kag28: Already in cache.
# Skipping okD4MfKU6Y4: Already in cache.
# Skipping lB1ZHmhmFHA: Already in cache.
# Skipping TLVxLnh2Pak: Already in cache.
# Skipping wROcuvDJscg: Already in cache.
# Skipping X27UudoqbVg: Already in cache.
# Skipping sfCUVTmeQ98: Already in cache.
# Skipping 7LK9QcH-Dtg: Already in cache.
# Skipping PUkDzWVo1Xc: Already in cache.
# Skipping zutcGa73kbM: Already in cache.
# Skipping lPSVhTGkorE: Already in cache.
# Skipping zeL2iaS2qOk: Already in cache.
# Skipping e2tMZFev0ow: Already in cache.
# Skipping RpWtA86cUQk: Already in cache.
# Skipping 4MivZ5Rw4gI: Already in cache.
# Skipping fO7WjtosJA4: Already in cache.
# Skipping GXaGi1xZ7AI: Already in cache.
# Skipping gqOsYKIP7JE: Already in cache.
# Skipping A_W0H6MESQM: Already in cache.
# Skipping GHUCcsjODpw: Already in cache.
# Skipping PJcLg8J20e8: Already in cache.
# Skipping CpniR4ggCHk: Already in cache.
# Skipping B5gRVkRqDRU: Already in cache.
# Skipping oxdWI_UBqao: Already in cache.
# Skipping Xfs-V8QdHUg: Already in cache.
# Skipping v4cPMgQJQO8: Already in cache.
# Skipping rrDxyltGpRI: Already in cache.
# Skipping DZM3Rsj_aiw: Already in cache.
# Skipping nZ21wqBPKng: Already in cache.
# Skipping -nzoDWr2zIc: Already in cache.
# Skipping 0ES6BkAkcQI: Already in cache.
# Skipping S9UadpurxmY: Already in cache.
# Skipping V9XyeNxAvjI: Already in cache.
# Skipping nV3vjf__FJ4: Already in cache.
# Skipping EDHJkuA8fc8: Already in cache.
# Skipping 1aOrxkOGf9k: Already in cache.
# Skipping iCjd7K_JPSQ: Already in cache.
# Skipping -q7Rg95yuDo: Already in cache.
# Skipping g_Co-IvjQ8M: Already in cache.
# Skipping AFIphT3j4v4: Already in cache.
# Skipping lkh_quzTWHE: Already in cache.
# Skipping ENdeBjg_khY: Already in cache.
# Skipping L-ruvBwUuWU: Already in cache.
# Skipping lVNwBm8kMQY: Already in cache.
# Skipping 2er59p89Hwo: Already in cache.
# Skipping dI7AYkQQZ2I: Already in cache.
# Skipping DBKGt-tg_mQ: Already in cache.
# Skipping 0fMslg_ioL0: Already in cache.
# Skipping 1XoIx7yJB8M: Already in cache.
# Skipping P0BvzvKQ6bY: Already in cache.
# Skipping PUY0-ju018Q: Already in cache.
# Skipping RIUxs65sneU: Already in cache.
# Skipping _2pz5YRcD4s: Already in cache.
# Skipping zJLIj6heKlM: Already in cache.
# Skipping XL5_0z1ybCM: Already in cache.
# Skipping 8yHZcsRcAdU: Already in cache.
# Skipping O1b-udw_QXY: Already in cache.
# Skipping g4ASDMIxx4w: Already in cache.
# Skipping mrs-pay9d_8: Already in cache.
# Skipping 5Yzs7HbP5TI: Already in cache.
# Skipping -2xOoQrbZcg: Already in cache.
# Skipping DELcV9-HlMs: Already in cache.
# Skipping FDhplS6Hzl0: Already in cache.
# Skipping RUI6e8zyZfY: Already in cache.
# Skipping 1fa9iYntkCw: Already in cache.
# Skipping ZUsXJbgGAXo: Already in cache.
# Skipping X-WUdU1leaA: Already in cache.
# Skipping 8kXDyDwZldI: Already in cache.
# Skipping rJ66FA8Jr8g: Already in cache.
# Skipping wG1AzHoaEkk: Already in cache.
# Skipping pQb-UByE_fM: Already in cache.
# Skipping PztNKZu4sAs: Already in cache.
# Skipping KFElk9GoGzA: Already in cache.
# Skipping MZFYht-dzG8: Already in cache.
# Skipping 9f10MLW4mA0: Already in cache.
# Skipping g9904jTbHk0: Already in cache.
# Skipping glJQgnDMyGc: Already in cache.
# Skipping m3T3Lum87MI: Already in cache.
# Skipping Xr38VSCotKY: Already in cache.
# Skipping v2n3HGLldnI: Already in cache.
# Skipping 1gFml5gs1Hk: Already in cache.
# Skipping F08Mmk3qqj8: Already in cache.
# Skipping Nt1th1DE15w: Already in cache.
# Skipping eYuXD6aYgWM: Already in cache.
# Skipping 3Pzo33D4s1A: Already in cache.
# Skipping o6g7OqgR1zw: Already in cache.
# Skipping xJZkicBtUGY: Already in cache.
# Skipping 8hGjQQK3Pqo: Already in cache.
# Skipping T8r7BGlqwEc: Already in cache.
# Skipping GRTaOVq3aIo: Already in cache.
# Skipping 3TWsIn_oVmA: Already in cache.
# Skipping BmOrsYlMVdY: Already in cache.
# Skipping jt83_QHEYB0: Already in cache.
# Skipping r6IjWBGSdJo: Already in cache.
# Skipping OYbrMX2wem4: Already in cache.
# Skipping xFfufPw64wE: Already in cache.
# Skipping t0v3aoc-VxM: Already in cache.
# Skipping 3-6JYorq5MI: Already in cache.
# Skipping PbstNqsrJcQ: Already in cache.
# Skipping UAcRGcLT6nI: Already in cache.
# Skipping hD08UR8iNdM: Already in cache.
# Skipping wxlbexME27o: Already in cache.
# Skipping m9Y3yAe5ZJM: Already in cache.
# Skipping Dx4isRtXQYA: Already in cache.
# Skipping HVVgm55QWr4: Already in cache.
# Skipping TZUtucI7FOI: Already in cache.
# Skipping SBvTwzgmxd8: Already in cache.
# Skipping w8wVLD62s3g: Already in cache.
# Skipping wNyvwa0w3_M: Already in cache.
# Skipping faNIuRdh6Dk: Already in cache.
# Skipping cOIMdDVEPow: Already in cache.
# Skipping DgB9VD45OB8: Already in cache.
# Skipping bCxuunqRj84: Already in cache.
# Skipping iyRXnUGRD_g: Already in cache.
# Skipping FXZe01EnbBE: Already in cache.
# Skipping LAcC6EQonBI: Already in cache.
# Skipping dS3oYv_IIGw: Already in cache.
# Skipping giHt95l39jE: Already in cache.
# Skipping k9_2LSw41rU: Already in cache.
# Skipping _sXJS_IIJSk: Already in cache.
# Skipping _IS57IyI6Gw: Already in cache.
# Skipping AlrMg98mVQg: Already in cache.
# Skipping l8zCHTCCJXc: Already in cache.
# Skipping wiCUnBh1cWw: Already in cache.
# Skipping Xj9X9XyZk7g: Already in cache.
# Skipping e-s5yc5_G50: Already in cache.
# Skipping vrBBmLf5Gjc: Already in cache.
# Skipping kjSJHJTrXg0: Already in cache.
# Skipping FD_frOI5fao: Already in cache.
# Skipping YEX62C5lGQE: Already in cache.
# Skipping 9bwnp4njtVc: Already in cache.
# Skipping vuEss1M4KgQ: Already in cache.
# Skipping 6LSLHDo6_7Q: Already in cache.
# Skipping oSqlVjws_FU: Already in cache.
# Skipping YM0iJHkxCZs: Already in cache.
# Skipping dU_KVULl7LQ: Already in cache.
# Skipping vdK-tAVV9wc: Already in cache.
# Skipping 31SGAMjDGIg: Already in cache.
# Skipping l3fGfniRedw: Already in cache.
# Skipping 8K36OtCI3JA: Already in cache.
# Skipping VtI7SJ6lGMo: Already in cache.
# Skipping lWSdA1t0mMc: Already in cache.
# Skipping Ko6jRwdnt7o: Already in cache.
# Skipping 4lnTVeURByM: Already in cache.
# Skipping si6QrCtoh-k: Already in cache.
# Skipping bmL_ts_IN4k: Already in cache.
# Skipping kTiW9LEcrr4: Already in cache.
# Skipping U5IOTlBggK8: Already in cache.
# Skipping nQ1aUfC-EGg: Already in cache.
# Skipping DrPyRX1BT2w: Already in cache.
# Skipping AlfXrtrhJP8: Already in cache.
# Skipping Pi5i06aJEZM: Already in cache.
# Skipping JqU-GrQsYwY: Already in cache.
# Skipping cQQCRlJaq08: Already in cache.
# Skipping Ka6s5Y6txCo: Already in cache.
# Skipping wfl8lb6p7PM: Already in cache.
# Skipping kzOKurS0ep4: Already in cache.
# Skipping LeBdvRd91Es: Already in cache.
# Skipping VaO_iK_i_W0: Already in cache.
# Skipping qEmUuQ_vnFU: Already in cache.
# Skipping 19awXvcs_qo: Already in cache.
# Skipping tHg-4UFafx8: Already in cache.
# Skipping WMXuaJh3E3Y: Already in cache.
# Skipping 3NtMsTh8cIY: Already in cache.
# Skipping UD33J7cV5AI: Already in cache.
# Skipping F7nW8k8MS8w: Already in cache.
# Skipping XJk1TqvnIHw: Already in cache.
# Skipping HENva4_gngc: Already in cache.
# Skipping 5m3op4yGybI: Already in cache.
# Skipping 7Ta6w_58xzA: Already in cache.
# Skipping F2_9NkFTvvc: Already in cache.
# Skipping wpsOLjsXn_c: Already in cache.
# Skipping BORz82IQU9M: Already in cache.
# Skipping -nLM7DAX0qw: Already in cache.
# Skipping -qX7j9tgbZ8: Already in cache.
# Skipping QKgLd8iDFvU: Already in cache.
# Skipping l_cUuc_MJaA: Already in cache.
# Skipping lpHhjhiWSkA: Already in cache.
# Skipping mzl33lQaYNU: Already in cache.
# Skipping gIaMz8hKBV4: Already in cache.
# Skipping nsgNsjJWBz4: Already in cache.
# Skipping hdFrqTX6IGQ: Already in cache.
# Skipping -5CBELHiNKQ: Already in cache.
# Skipping wFRoobiUlL0: Already in cache.
# Skipping Db2VF-PaUeE: Already in cache.
# Skipping Rq7L5N0ZKDE: Already in cache.
# Skipping K7EhlZZWTCk: Already in cache.
# Skipping 725exJKkbj0: Already in cache.
# Skipping CIDWPU_Jn48: Already in cache.
# Skipping rETiXi7mriU: Already in cache.
# Skipping MXt_bGWakdU: Already in cache.
# Skipping moeWW1grJcY: Already in cache.
# Skipping coP3dB8mZI8: Already in cache.
# Skipping 4D8UciBzbGk: Already in cache.
# Skipping G7l1wJ4TYCs: Already in cache.
# Skipping GGAYv3Iuwys: Already in cache.
# Skipping WSqn5E_39B8: Already in cache.
# Skipping 5gkiXZ_DjOw: Already in cache.
# Skipping NGyjFCi7NZI: Already in cache.
# Skipping IcPtdlWu2fk: Already in cache.
# Skipping wjpqXOV86KE: Already in cache.
# Skipping p-j8hRPnv7s: Already in cache.
# Skipping da1-Db8YZmQ: Already in cache.
# Skipping _ju8h6v76Qw: Already in cache.
# Skipping e4rg2SOT73s: Already in cache.
# Skipping nftnXl6OsIQ: Already in cache.
# Skipping 3EAu08m5Lbc: Already in cache.
# Skipping BH4HT463Nes: Already in cache.
# Skipping 1Wg3QEBb8NY: Already in cache.
# Skipping CHr_MtxY51U: Already in cache.
# Skipping pgzqIb90UaA: Already in cache.
# Skipping wfLnAIKx3DY: Already in cache.
# Skipping wZo11yDLMn0: Already in cache.
# Skipping G3-_LydUx-4: Already in cache.
# Skipping qSVWRlssVH8: Already in cache.
# Skipping bWjZozst7Ws: Already in cache.
# Skipping A7zXS9yEMz8: Already in cache.
# Skipping J9-bv3UGmu0: Already in cache.
# Skipping Na2j18KH-fU: Already in cache.
# Skipping rxnuUpUrMBU: Already in cache.
# Skipping 2Ic_DOIdkjo: Already in cache.
# Skipping Hr0X9vQctSY: Already in cache.
# Skipping 9v4yFQJupis: Already in cache.
# Skipping sQLjaYmqltU: Already in cache.
# Skipping C9XM6O0rGtU: Already in cache.
# Skipping 4ghpcZYptJk: Already in cache.
# Skipping ZUEoqLrzN3g: Already in cache.
# Skipping C4qt6pztYBM: Already in cache.
# Skipping DTrDGOPj_wg: Already in cache.
# Skipping vh2VxJ-FjgU: Already in cache.
# Skipping lEExdcOu5u8: Already in cache.
# Skipping DkOzDmOdJnc: Already in cache.
# Skipping JpLPd5ibZGU: Already in cache.
# Skipping gKoxlbdS_6w: Already in cache.
# Skipping G5Df9mnze_0: Already in cache.
# Skipping 7LemtsR2m90: Already in cache.
# Skipping ZU3dZ0O8Iec: Already in cache.
# Skipping NvMoJFTu2QE: Already in cache.
# Skipping hrlOmfxH-X4: Already in cache.
# Skipping yaegB_tEHXg: Already in cache.
# Skipping Az-AoI3asTo: Already in cache.
# Skipping PFAdiHhARdw: Already in cache.
# Skipping LqqpOhO4WHM: Already in cache.
# Skipping WVebYicSK9E: Already in cache.
# Skipping t2dbw3IKn5U: Already in cache.
# Skipping GIg1KhXp15Y: Already in cache.
# Skipping XbnTPw1xjbE: Already in cache.
# Skipping k_7HTvJtZSQ: Already in cache.
# Skipping ICPq5Y3Db98: Already in cache.
# Skipping 5IFVPAL5CF0: Already in cache.
# Skipping iMohZle-6j8: Already in cache.
# Skipping UyUDF0ufeLA: Already in cache.
# Skipping wjQxnH_BAvg: Already in cache.
# Skipping JbT3WpAWT8s: Already in cache.
# Skipping gaGwp7O7gZY: Already in cache.
# Skipping Q4GXlOX_bqc: Already in cache.
# Skipping 2hWmat2ayas: Already in cache.
# Skipping -mnRohr4xUs: Already in cache.
# Skipping l0OV6dY08S4: Already in cache.
# Skipping 2MIfxKcL3wk: Already in cache.
# Skipping VOJUJOh2nCE: Already in cache.
# Skipping _JKZii83DhY: Already in cache.
# Skipping IV3ZRg1S6Ds: Already in cache.
# Skipping k_unwQnwguo: Already in cache.
# Skipping gBnyKkiWdUQ: Already in cache.
# Skipping qpqj_5uA5EY: Already in cache.
# Skipping IVQEkwTDdVg: Already in cache.
# Skipping BPE-Z0D2Lrc: Already in cache.
# Skipping YHPNsQBao9k: Already in cache.
# Skipping ZRc_mHtFZ38: Already in cache.
# Skipping rmVbI8hP6e0: Already in cache.
# Skipping j2OX3XXVPjE: Already in cache.
# Skipping 5zQ-mcAUHSI: Already in cache.
# Skipping S_SX-SHHA_Q: Already in cache.
# Skipping mCprBzgUgoE: Already in cache.
# Skipping r__undITxUs: Already in cache.
# Skipping etctX5IWgb0: Already in cache.
# Skipping P-pGm_8fXpg: Already in cache.
# Skipping 72jZRLFzzbc: Already in cache.
# Skipping xFEROOPvJ3Y: Already in cache.
# Skipping 8tAeXaG3MvM: Already in cache.
# Skipping JzxuFdOjTg4: Already in cache.
# Skipping rvvByjmTgzM: Already in cache.
# Skipping Ns2UOKejWIU: Already in cache.
# Skipping ATvkCwRYAOc: Already in cache.
# Skipping KxfrVgwZiMI: Already in cache.
# Skipping -PvCFlG5xOM: Already in cache.
# Skipping O7J0_9iYaNQ: Already in cache.
# Skipping 397l_B9OilM: Already in cache.
# Skipping qB1dsXT4omI: Already in cache.
# Skipping z0nXQMLkImE: Already in cache.
# Skipping A55jXVfaPlk: Already in cache.
# Skipping BgahezBI9a4: Already in cache.
# Skipping scTV5t_YsPE: Already in cache.
# 2025-02-14 16:27:53,806 - INFO - Metadata fetching complete. Cache updated.
# Finished processing apple_airtag videos. Total videos: 306
# cosrx_snail_mucin_serum
# Skipping qZlItN__Cnw: Already in cache.
# Skipping sRPVUxpMzIM: Already in cache.
# Skipping ymM3KdVrChc: Already in cache.
# Skipping PppMg_5Xnr8: Already in cache.
# Skipping aALYla5Uqt4: Already in cache.
# Skipping A1h8vOb0h6Q: Already in cache.
# Skipping 8M1eKfOEkTQ: Already in cache.
# Skipping mNj4heCfdsY: Already in cache.
# Skipping A1IVGzMIRi0: Already in cache.
# Skipping JtgqoAZ0rx0: Already in cache.
# Skipping Lw2aJiLH_40: Already in cache.
# Skipping kcF5z8JsuVk: Already in cache.
# Skipping aKtn7A9VLA0: Already in cache.
# Skipping 30Ypi9sfRR4: Already in cache.
# Skipping 9uJMMuZAT_Y: Already in cache.
# Skipping kfbJ4bulK0A: Already in cache.
# Skipping yR5VdfTmxHI: Already in cache.
# Skipping qs85rDxHp0c: Already in cache.
# Skipping mm-35E-PpIM: Already in cache.
# Skipping THVsvCSbIh0: Already in cache.
# Skipping zu3gNnAcYzo: Already in cache.
# Skipping DW9vON1DRA8: Already in cache.
# Skipping zRNhuV-FiL4: Already in cache.
# Skipping 7CfQg80v3xE: Already in cache.
# Skipping IgFoJ9WIJZE: Already in cache.
# Skipping vpl5TCjHwCU: Already in cache.
# Skipping nTg8hrEQIvM: Already in cache.
# Skipping EPKSJUI54gc: Already in cache.
# Skipping qVbuBDPzgDs: Already in cache.
# Skipping AhwfzUTJEec: Already in cache.
# Skipping mEdbpg4g1Cs: Already in cache.
# Skipping pe6bmkgUmvw: Already in cache.
# Skipping X6mfMOF7TZM: Already in cache.
# Skipping 5nUlnd0-r5E: Already in cache.
# Skipping e5SsUzryWPY: Already in cache.
# Skipping reISnmzrbfk: Already in cache.
# Skipping bxCJDn6uQSE: Already in cache.
# Skipping ZZoD7vwdR-w: Already in cache.
# Skipping Sb8copYtmBY: Already in cache.
# Skipping RmjGgUAZoBU: Already in cache.
# Skipping YqGxAF-hWKE: Already in cache.
# Skipping 2zpxwwtUpg0: Already in cache.
# Skipping Beq9r_kCEoE: Already in cache.
# Skipping Ek0CPFLTeYQ: Already in cache.
# Skipping G5kFmqLonBg: Already in cache.
# Skipping LmVKEDoypo8: Already in cache.
# Skipping WEDEESv0fSw: Already in cache.
# Skipping LuhtDyZf90U: Already in cache.
# Skipping 3GFXHp7mfuM: Already in cache.
# Skipping 6xF04XfiYzI: Already in cache.
# Skipping QAqQyOyZ2J0: Already in cache.
# Skipping ISh8Ab_4Go0: Already in cache.
# Skipping XqOtmKmmDXc: Already in cache.
# Skipping KXMRZJ8GuNc: Already in cache.
# Skipping WCw7d69EOKY: Already in cache.
# Skipping rAWWU0VGk8c: Already in cache.
# Skipping ERmPU6Tbmpk: Already in cache.
# Skipping CtwFyg6zhrg: Already in cache.
# Skipping oGmp5VpGmyI: Already in cache.
# Skipping _kEMY9frIkI: Already in cache.
# Skipping i6WSE7enVdU: Already in cache.
# Skipping 01dqEN1idHI: Already in cache.
# Skipping Pa6KuZjd1jQ: Already in cache.
# Skipping j0fHRPdD1cc: Already in cache.
# Skipping eHQ-dUDYDFk: Already in cache.
# Skipping B3fDBa0TtBY: Already in cache.
# Skipping xrMnCGFPLGA: Already in cache.
# Skipping 9tSX6bxK-UA: Already in cache.
# Skipping KpFLbsg8qio: Already in cache.
# Skipping K-qGYWF8fBU: Already in cache.
# Skipping o7CbwGxvuSc: Already in cache.
# Skipping HwXUByET_qU: Already in cache.
# Skipping EIPkBVHCfao: Already in cache.
# Skipping qXPnHxlbz2E: Already in cache.
# Skipping cwVtEJtBU7Y: Already in cache.
# Skipping Y24y7JRu3gA: Already in cache.
# Skipping rhO5Ji1v58w: Already in cache.
# Skipping aW98_4toyYs: Already in cache.
# Skipping _H_jYxGInpQ: Already in cache.
# Skipping lVT3Ay2GcIk: Already in cache.
# Skipping GjPXEaMAf0c: Already in cache.
# Skipping zu19E0clnBs: Already in cache.
# Skipping sYAzyshp_KI: Already in cache.
# Skipping HkyHT42GsFw: Already in cache.
# Skipping 93Em7iY78bs: Already in cache.
# Skipping cTtHZ0LJbvg: Already in cache.
# Skipping KHVJCNlBWsw: Already in cache.
# Skipping FqX8X-3ZQK8: Already in cache.
# Skipping Ctzl4Xoy8XI: Already in cache.
# Skipping zCSeJ4VXSNw: Already in cache.
# Skipping 9-MuszspUJI: Already in cache.
# Skipping pHidQlhVNtE: Already in cache.
# Skipping XaKKrlLJMzE: Already in cache.
# Skipping sepwKCeoKi4: Already in cache.
# Skipping ntwcwnTy4tM: Already in cache.
# Skipping qtJyifl1wTQ: Already in cache.
# Skipping Ic_4m7ZleSQ: Already in cache.
# Skipping f3iJlJ_rQVg: Already in cache.
# Skipping Vw6x7wxqLN8: Already in cache.
# Skipping Wg2WKlc6Oec: Already in cache.
# Skipping Wvcmvb9JLhU: Already in cache.
# Skipping n28k_pmk0yU: Already in cache.
# Skipping 3tqwAusigwE: Already in cache.
# Skipping C0CaKiR-Yfo: Already in cache.
# Skipping nToH0x70I54: Already in cache.
# Skipping s0J_RFXnTmk: Already in cache.
# Skipping NWPWhkiIvT0: Already in cache.
# Skipping 29fzhiuVUk8: Already in cache.
# Skipping 18anKizSz5g: Already in cache.
# Skipping cCR5L1qa1hA: Already in cache.
# Skipping PkedllR-npE: Already in cache.
# Skipping 66SUZJPa7Cs: Already in cache.
# Skipping JNk2ZrbcnZA: Already in cache.
# Skipping TRrVZl24pWI: Already in cache.
# Skipping S64_xjqYfbA: Already in cache.
# Skipping cpqhmseMGAQ: Already in cache.
# Skipping A3lVevG5dvo: Already in cache.
# Skipping dmd5XU3xBOA: Already in cache.
# Skipping q7b2yHT9tRI: Already in cache.
# Skipping MAtasks5zMs: Already in cache.
# Skipping E0WeCxD6gSk: Already in cache.
# Skipping f8NVT8g-PRI: Already in cache.
# Skipping ioffq9hvI2c: Already in cache.
# Skipping JMHgacA0fiQ: Already in cache.
# Skipping lM9OcRL5DYM: Already in cache.
# Skipping cIGbyhXl3Mg: Already in cache.
# Skipping NO6Ys4W45T8: Already in cache.
# Skipping qg1kYQeInoY: Already in cache.
# Skipping jpkw9iHC_9M: Already in cache.
# Skipping Rnxl0M1vgS4: Already in cache.
# Skipping 0sWi9frlEEk: Already in cache.
# Skipping gZ7LxsEwQnk: Already in cache.
# Skipping Tl68Qg5BzqU: Already in cache.
# Skipping Ci2Mi2H6JIA: Already in cache.
# Skipping 4_3aZAviPyk: Already in cache.
# Skipping mgs1qyhwmkE: Already in cache.
# Skipping xko2nkplCXk: Already in cache.
# Skipping -P86pwMV7jA: Already in cache.
# Skipping KwFtS6-ZLOg: Already in cache.
# Skipping HSGmwSNhSg0: Already in cache.
# Skipping L9fUMKitccI: Already in cache.
# Skipping qNICKEpC4YM: Already in cache.
# Skipping Fez0bT485Rk: Already in cache.
# Skipping DYRG-QL6iD8: Already in cache.
# Skipping _J38KJhIQQY: Already in cache.
# Skipping g9NDMarsJ_Y: Already in cache.
# Skipping BXUuWpQaOBA: Already in cache.
# Skipping 0HbXYTcli6E: Already in cache.
# Skipping oTbUXen1uD8: Already in cache.
# Skipping CZ2ynApHPX0: Already in cache.
# Skipping bif055zoaR4: Already in cache.
# Skipping oAFN9dXn9YA: Already in cache.
# Skipping FotuM-w8AAU: Already in cache.
# Skipping y85HA4ijA6I: Already in cache.
# Skipping DY1Zoe8QpdA: Already in cache.
# Skipping pxrOmG7q53E: Already in cache.
# Skipping 6HJGU0Nz918: Already in cache.
# Skipping VX5f1gL7imY: Already in cache.
# Skipping VSI66iYNDKE: Already in cache.
# Skipping Vl94A9tNcdA: Already in cache.
# Skipping -0gDOj_TWsw: Already in cache.
# Skipping 4wmPts4MHKk: Already in cache.
# Skipping CFGEolAMNns: Already in cache.
# Skipping _ltmIERs4oQ: Already in cache.
# Skipping -ewEZpTKRwQ: Already in cache.
# Skipping 2xLwDsAPzZc: Already in cache.
# Skipping O776pwEUFOk: Already in cache.
# Skipping JPCWzWGYJbY: Already in cache.
# Skipping 6gcdDlxL2pw: Already in cache.
# Skipping h_hApXifzho: Already in cache.
# Skipping VbVc_C1oFS4: Already in cache.
# Skipping u-sXGOVmp4Q: Already in cache.
# Skipping Yl0ZsjARp_c: Already in cache.
# Skipping wCfRyHBG3nw: Already in cache.
# Skipping KshfJuxilDk: Already in cache.
# Skipping Js980Enpqsw: Already in cache.
# Skipping CMNIt5ikF1k: Already in cache.
# Skipping 0vw3NBkVqbE: Already in cache.
# Skipping e98NQUhZm9Y: Already in cache.
# Skipping ayjvgyVmR7U: Already in cache.
# Skipping 3U-4nz-wV8g: Already in cache.
# Skipping prsjN7r6gDc: Already in cache.
# Skipping M0ibwFXR7TI: Already in cache.
# Skipping pm2_OOBOYPA: Already in cache.
# Skipping 0WMWbtrFvj0: Already in cache.
# Skipping 5x-8Kla0xX0: Already in cache.
# Skipping _PIPuw2wU2E: Already in cache.
# Skipping hTDhmbBF5dU: Already in cache.
# Skipping y_OWFJ9L9K0: Already in cache.
# Skipping 5nr5VOLFZSI: Already in cache.
# Skipping j9Rp5YLEb_0: Already in cache.
# Skipping sPl9tbuCktM: Already in cache.
# Skipping Bufko4xtl2I: Already in cache.
# Skipping Msdedy0GatU: Already in cache.
# Skipping 2PkG2-WArcA: Already in cache.
# Skipping 9DRLPF1T5zA: Already in cache.
# Skipping _rtDAxbNSHA: Already in cache.
# Skipping qxItZQPFcuk: Already in cache.
# Skipping cJ2Ry0xWPmE: Already in cache.
# Skipping tt-eS1RVG00: Already in cache.
# Skipping hZdgtmKMiI0: Already in cache.
# Skipping snyT-nbFvng: Already in cache.
# Skipping CqFULXZpxsg: Already in cache.
# Skipping X0mLdBNFoeI: Already in cache.
# Skipping 0sMzW03JS4U: Already in cache.
# Skipping KC9GdfKbVxs: Already in cache.
# Skipping Uh4BToClDtQ: Already in cache.
# Skipping SBleMHPZWqs: Already in cache.
# Skipping ZE9EgA1x8kc: Already in cache.
# Skipping uiwterDSxok: Already in cache.
# Skipping kbnehCTFTJc: Already in cache.
# Skipping gKw-gvrqPxQ: Already in cache.
# Skipping 5-3fzlTV-vc: Already in cache.
# Skipping 4Rdkb1KErXA: Already in cache.
# Skipping 8Mcyuhs2maw: Already in cache.
# Skipping dCGaXrUR2W0: Already in cache.
# Skipping x_KMb0RVOlw: Already in cache.
# Skipping No07y-pGqsY: Already in cache.
# Skipping Q4-0xq89pgU: Already in cache.
# Skipping fXMGZiB7M-Q: Already in cache.
# Skipping XpEtRe-luHQ: Already in cache.
# Skipping tlbhwWvQGIs: Already in cache.
# Skipping GAZlJHnzWNw: Already in cache.
# Skipping 1Cncef5-Ny0: Already in cache.
# Skipping U6N4vfoOwNg: Already in cache.
# Skipping FL2rbzYcKFU: Already in cache.
# Skipping m41DAfFWjJ0: Already in cache.
# Skipping QHt4kHMQVL8: Already in cache.
# Skipping VlU2kIi_O6E: Already in cache.
# Skipping HZL-y9c7WBw: Already in cache.
# Skipping 3_MeuktkHnw: Already in cache.
# Skipping XdVlLYDGxU0: Already in cache.
# Skipping Wbe_mm3CNOA: Already in cache.
# Skipping Mf37aeg-D08: Already in cache.
# Skipping DXsCUcjH3Rk: Already in cache.
# Skipping VPwPwu0TSpE: Already in cache.
# Skipping jKVNDsE-5KM: Already in cache.
# Skipping w4ImxJav3ZA: Already in cache.
# Skipping Sx_9m708wBg: Already in cache.
# Skipping xowOmGJAfig: Already in cache.
# Skipping s2dhUNskasw: Already in cache.
# Skipping 70fczlw94XQ: Already in cache.
# Skipping iY1AKRtRjdY: Already in cache.
# Skipping gZz3SEy081o: Already in cache.
# Skipping 4ZCjQtFn13E: Already in cache.
# Skipping Gg6CKJ3KGoc: Already in cache.
# Skipping iLOOkse9LDQ: Already in cache.
# Skipping IMNh69h-0HI: Already in cache.
# Skipping xXnrjDH7leo: Already in cache.
# Skipping GxB2tc8KVaY: Already in cache.
# Skipping ENUljq33Ltk: Already in cache.
# Skipping iVwLFXlZt8k: Already in cache.
# Skipping vZShYMtLgOM: Already in cache.
# Skipping Rn45Vu6BNlY: Already in cache.
# Skipping 4FEOt3tfWvQ: Already in cache.
# Skipping icVMco0G2eU: Already in cache.
# Skipping MUikC0zl7IE: Already in cache.
# Skipping c5YKiNLs530: Already in cache.
# Skipping WE4Y_tkHSxU: Already in cache.
# Skipping fephunJwK6E: Already in cache.
# Skipping 0gsfRyWsooc: Already in cache.
# Skipping og5kT9SufZU: Already in cache.
# Skipping Yt0RSARmOfc: Already in cache.
# Skipping gTh4xFv02Gw: Already in cache.
# Skipping DXCKF_hUOME: Already in cache.
# Skipping MbhWiKsft2c: Already in cache.
# Skipping EMXrw5FoC0s: Already in cache.
# Skipping Xq_ujoL3xyA: Already in cache.
# Skipping JM_SFlm6shE: Already in cache.
# Skipping H-x4IqdAWAc: Already in cache.
# Skipping GCJQEq0modU: Already in cache.
# Skipping OUe388eHEak: Already in cache.
# Skipping MVdZTLI-_cI: Already in cache.
# Skipping y0piJKMW7ZI: Already in cache.
# Skipping lopVhPQ8dWY: Already in cache.
# Skipping pWbedOsRGlk: Already in cache.
# Skipping 8Hvn1ji63YY: Already in cache.
# Skipping BN6g-jtZLjA: Already in cache.
# Skipping AFjTf3SMA-M: Already in cache.
# Skipping Tq5S9ewjEDo: Already in cache.
# Skipping MFoHE5SmWPw: Already in cache.
# Skipping apJNigGdqaU: Already in cache.
# Skipping dhFlv3aGOYU: Already in cache.
# Skipping CwyqzLI4xWU: Already in cache.
# Skipping CqH-zLIlfr8: Already in cache.
# Skipping JT9oQa1ZjQY: Already in cache.
# Skipping YWjnsY7wNl8: Already in cache.
# Skipping Go2jH7aTFIw: Already in cache.
# 2025-02-14 16:27:57,534 - INFO - Metadata fetching complete. Cache updated.
# Finished processing cosrx_snail_mucin_serum videos. Total videos: 288
# liquid_death
# Skipping UfpBPk8HiaY: Already in cache.
# Skipping ZKulKTBG4z8: Already in cache.
# Skipping 2NVKMZEut_o: Already in cache.
# Skipping W98dsnZsix4: Already in cache.
# Skipping fe9H3nrUE64: Already in cache.
# Skipping g4R5Nz5agz4: Already in cache.
# Skipping TcejRPUhF3c: Already in cache.
# Skipping -awPOByIu_0: Already in cache.
# Skipping OhsS4d9b9qQ: Already in cache.
# Skipping 5yXa6OmUPMA: Already in cache.
# Skipping z8CI3hhFfVg: Already in cache.
# Skipping _0XQs2ntvL4: Already in cache.
# Fetching info for aMGs9HhjeWQ...
# ERROR: [youtube] aMGs9HhjeWQ: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# Error fetching info for aMGs9HhjeWQ: ERROR: [youtube] aMGs9HhjeWQ: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# Skipping g3lsJjSDJ6s: Already in cache.
# Fetching info for hgiV-800TjU...
# ERROR: [youtube] hgiV-800TjU: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# Error fetching info for hgiV-800TjU: ERROR: [youtube] hgiV-800TjU: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# Skipping GQyEdDbXdL8: Already in cache.
# Skipping WbItZj-gLEs: Already in cache.
# Skipping pgaWGhnhsCQ: Already in cache.
# Skipping yHf-X9LjcjI: Already in cache.
# Skipping uHOzEmElfds: Already in cache.
# Skipping 5_2loB1dyLY: Already in cache.
# Skipping z6g1Iy5w7tE: Already in cache.
# Skipping PlcXJHmk9tk: Already in cache.
# Skipping OJ4-VROjtxo: Already in cache.
# Skipping J2eLz30zJDo: Already in cache.
# Skipping 23VjaLSkW_A: Already in cache.
# Skipping 6D6EA0_qnnM: Already in cache.
# Skipping g9N4gH-mRb0: Already in cache.
# Skipping j1PVZGbnu6o: Already in cache.
# Skipping 0x_Erxvplbg: Already in cache.
# Skipping tOQs0PEVim4: Already in cache.
# Skipping A5OIyYUC9Vw: Already in cache.
# Skipping F_ezPqydFiQ: Already in cache.
# Skipping HUUZN791Eg0: Already in cache.
# Skipping NWW0oXYqCiw: Already in cache.
# Skipping -FLK1qmnET8: Already in cache.
# Skipping hFU8CJRhTMw: Already in cache.
# Skipping UWTgz_dbNxc: Already in cache.
# Skipping ZoI-79VlzAY: Already in cache.
# Skipping iX8uvJkdJaM: Already in cache.
# Skipping SEiYBp7OZlI: Already in cache.
# Skipping yN3mWn5wg7U: Already in cache.
# Skipping F-MXnMk36bs: Already in cache.
# Skipping 573WhNYhWeY: Already in cache.
# Skipping 3t20rCFKp3s: Already in cache.
# Skipping y0c9F2ti4dM: Already in cache.
# Skipping jlndeALYtME: Already in cache.
# Skipping TiN7o_SVPEk: Already in cache.
# Skipping dGUpYAvUFl8: Already in cache.
# Skipping SvjuQOYp4G4: Already in cache.
# Skipping kz4f-ncd898: Already in cache.
# Skipping TIkynpghdxw: Already in cache.
# Skipping uu71pHN24wQ: Already in cache.
# Skipping KDvSRSsFvfA: Already in cache.
# Skipping H3kl9VCPRZs: Already in cache.
# Skipping tob-BEcbtvI: Already in cache.
# Skipping bVXzgLxmk6o: Already in cache.
# Skipping ovg24rFmZH4: Already in cache.
# Skipping s4ijM1RNUrI: Already in cache.
# Skipping rH0ataQaIps: Already in cache.
# Skipping 89TAmWZiTo8: Already in cache.
# Skipping WxWwhpYWtwE: Already in cache.
# Skipping ZwmRMid7Snw: Already in cache.
# Skipping 75gThpEanD4: Already in cache.
# Skipping Xpl4FxZJvGI: Already in cache.
# Skipping O8TpnFA9fEw: Already in cache.
# Skipping 5IqBbbW-MGM: Already in cache.
# Skipping DX2jTtt6PAQ: Already in cache.
# Skipping l2jcNTAlItI: Already in cache.
# Skipping ypg1pqzUU6E: Already in cache.
# Skipping xoofFMLNma8: Already in cache.
# Skipping d_CBehK1_aw: Already in cache.
# Skipping O0mBLbSUZA0: Already in cache.
# Skipping lUNonDhlsKU: Already in cache.
# Skipping msFPyE4ZFU8: Already in cache.
# Skipping wNU_xiE_QHY: Already in cache.
# Skipping Q0XBMpSeBtc: Already in cache.
# Skipping IV7WMSeqRJc: Already in cache.
# Skipping g9NFzGzAQko: Already in cache.
# Skipping a9t8Lj2iJVE: Already in cache.
# Skipping GY3LwR7qBlM: Already in cache.
# Skipping x_rsK1RUy7c: Already in cache.
# Skipping 9UMlPoZlFtA: Already in cache.
# Skipping Q5Cv5CGhG2A: Already in cache.
# Skipping vphohh2V6Us: Already in cache.
# Skipping ugRIUA4bbnI: Already in cache.
# Skipping xQdiJtMaUkE: Already in cache.
# Skipping BVdSCtK-xjY: Already in cache.
# Skipping 6N6ZPu2R2qY: Already in cache.
# Skipping 4UgRVIGKZv8: Already in cache.
# Skipping NCshNbzEAcE: Already in cache.
# Skipping gbSND0nIq44: Already in cache.
# Skipping Do69Ko9FavU: Already in cache.
# Skipping lQqxTPL_Zjg: Already in cache.
# Skipping g_KcKLncvTo: Already in cache.
# Skipping 9RHNuwVwUXI: Already in cache.
# Skipping 2XdZWVbi288: Already in cache.
# Skipping VlgME70J2KE: Already in cache.
# Skipping w_8th9_6fn4: Already in cache.
# Skipping c386nWkf4Sc: Already in cache.
# Skipping ooUuL-61pNo: Already in cache.
# Skipping 4YdZgAsNJUM: Already in cache.
# Skipping PM_HcErKFdU: Already in cache.
# Skipping ykFu14ZAZL4: Already in cache.
# Skipping 4RbMgkXuE20: Already in cache.
# Skipping 32_Qy39Zx8k: Already in cache.
# Skipping L7LhxY8S39k: Already in cache.
# Skipping olA9oUEiStw: Already in cache.
# Skipping HIkwlrB7GWo: Already in cache.
# Skipping 1SYpA6G52iY: Already in cache.
# Skipping bmNBeJ-ZKjI: Already in cache.
# Skipping sgkM7EUCyAQ: Already in cache.
# Skipping flTLcDvk03A: Already in cache.
# Skipping nRfdswnTFn0: Already in cache.
# Skipping VBeJ-jNsyWQ: Already in cache.
# Skipping t0C6bCJjZeE: Already in cache.
# Skipping ukGrbJljfbI: Already in cache.
# Skipping fKZsTdM6HhU: Already in cache.
# Skipping h1DfpQ5A6kM: Already in cache.
# Skipping krswk9I5m2o: Already in cache.
# Skipping QM83-DhYKxA: Already in cache.
# Skipping JWCa1-Hj7K8: Already in cache.
# Skipping w0j4r_xCxsY: Already in cache.
# Skipping WLgBUqpsAgY: Already in cache.
# Skipping VLYoONuK4Lg: Already in cache.
# Skipping c9RmRxn9zmY: Already in cache.
# Skipping tqNpioKkgIQ: Already in cache.
# Skipping qoh8RXH0reM: Already in cache.
# Skipping hQgLn8jTBUI: Already in cache.
# Skipping uVPU5Zn2jxk: Already in cache.
# Skipping gnviv6hIets: Already in cache.
# Skipping ZHoY8xuevIQ: Already in cache.
# Skipping jgyywE3ufws: Already in cache.
# Skipping WcHl8NzNoF8: Already in cache.
# Skipping WT_MeROgiPQ: Already in cache.
# Skipping ZNB5QPTaz-U: Already in cache.
# Skipping i6e_EMEoB4w: Already in cache.
# Skipping 8UTAsaZ_kuA: Already in cache.
# Skipping I3fbYo4nLKA: Already in cache.
# Skipping aOL-klo2FNM: Already in cache.
# Skipping r-dYiz90bNc: Already in cache.
# Skipping qj5bhiGzdDo: Already in cache.
# Skipping hz1-A3HXvLg: Already in cache.
# Skipping VvInEX0-fcA: Already in cache.
# Skipping HX1IGmtK4Uw: Already in cache.
# Skipping bpsj2eGyRLs: Already in cache.
# Skipping 0oFazVhPtQo: Already in cache.
# Skipping GAiL83FJQnU: Already in cache.
# Skipping hoP3WX0SBb4: Already in cache.
# Skipping egxjeT2ZXJk: Already in cache.
# Skipping -8mH-Avoxnw: Already in cache.
# Skipping qXS4iNwRXWI: Already in cache.
# Skipping VXY8VgGf2cQ: Already in cache.
# Skipping hx4O1CfBBiM: Already in cache.
# Skipping HIQ3UwMn-Ds: Already in cache.
# Skipping p0fJM2KjDDE: Already in cache.
# Skipping oyTt24cqTIA: Already in cache.
# Skipping eslOeChkRf0: Already in cache.
# Skipping rhYZvQhFdcY: Already in cache.
# Skipping glQRxIE-prE: Already in cache.
# Skipping 93UjXJxJM2w: Already in cache.
# Skipping PAjd7_q-D-M: Already in cache.
# Skipping bNRpKUCQASc: Already in cache.
# Skipping ff6VhMd3i94: Already in cache.
# Skipping Re7CDkSURRM: Already in cache.
# Skipping 2_zwGW7aT-M: Already in cache.
# Skipping ozVD3uOovto: Already in cache.
# Skipping 3fuATQynRx4: Already in cache.
# Skipping boEtpQqO2BI: Already in cache.
# Skipping BAAqyytjDk8: Already in cache.
# Fetching info for UDxq0vnGNhg...
# ERROR: [youtube] UDxq0vnGNhg: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# Error fetching info for UDxq0vnGNhg: ERROR: [youtube] UDxq0vnGNhg: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# Skipping AfxraoHATD4: Already in cache.
# Skipping FznTXcawFZk: Already in cache.
# Skipping muSt4p3p9gs: Already in cache.
# Skipping JbR5EcfC9VA: Already in cache.
# Skipping kGMY0pN4wxg: Already in cache.
# Skipping ukMmUja20iQ: Already in cache.
# Fetching info for htPlnC4Ket8...
# ERROR: [youtube] htPlnC4Ket8: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# Error fetching info for htPlnC4Ket8: ERROR: [youtube] htPlnC4Ket8: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# Skipping dU2KImgBiR8: Already in cache.
# Skipping _F9lELbm5-g: Already in cache.
# Skipping FzMbWq-cG84: Already in cache.
# Skipping 438Bopfus5c: Already in cache.
# Fetching info for PI8CDi71fXQ...
# ERROR: [youtube] PI8CDi71fXQ: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# Error fetching info for PI8CDi71fXQ: ERROR: [youtube] PI8CDi71fXQ: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# Skipping ld2qy1IPmcw: Already in cache.
# Fetching info for CJCW6nlIpos...
# ERROR: [youtube] CJCW6nlIpos: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# Error fetching info for CJCW6nlIpos: ERROR: [youtube] CJCW6nlIpos: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# Skipping UPjveDv8mBI: Already in cache.
# Skipping ZMosQXRE7IM: Already in cache.
# Skipping bZCELadmrEQ: Already in cache.
# Skipping 0zlSra_MV64: Already in cache.
# Skipping qc7eDBgbwlA: Already in cache.
# Skipping FJnaoytjvGA: Already in cache.
# Skipping 8s8NpY11P1k: Already in cache.
# Skipping GcZkUyUJP-Q: Already in cache.
# Skipping 4T6x9I4TdPA: Already in cache.
# Skipping o_VAHmsy5iQ: Already in cache.
# Skipping 2NkKtJFum2s: Already in cache.
# Skipping yBqohDzgfqs: Already in cache.
# Skipping 9Lk_-IT1R7U: Already in cache.
# Skipping 3LjBpUd2__A: Already in cache.
# Skipping sSq-Uj97S7Q: Already in cache.
# Skipping pn3KJFpRJa8: Already in cache.
# Skipping g8dITWUCF5E: Already in cache.
# Skipping c-_87RWGrPk: Already in cache.
# Skipping ZX-zBmoYWUI: Already in cache.
# Skipping zU14eguzuZ0: Already in cache.
# Skipping 2FG1jv_s00U: Already in cache.
# Skipping TBxGypzviHs: Already in cache.
# Skipping wb5Grd-bVzE: Already in cache.
# Skipping 3e-Qp7FZVG0: Already in cache.
# Skipping BkNvD0jDyes: Already in cache.
# Skipping wGDBITI2CRo: Already in cache.
# Skipping ANo7sKA4CS8: Already in cache.
# Skipping 92Sh9-AdCtw: Already in cache.
# Skipping lv7-aZUkw9A: Already in cache.
# Skipping Rs-AmcY9OE8: Already in cache.
# Skipping 1YH7wtjU7mM: Already in cache.
# Skipping XiKUKx7YgDQ: Already in cache.
# Skipping tMiBNw39bEE: Already in cache.
# Skipping XD9uCC6evkc: Already in cache.
# Skipping VN-za91HAIw: Already in cache.
# Skipping PL6pE3y9Z3E: Already in cache.
# Skipping lmY5saaYgjQ: Already in cache.
# Skipping NEkXBiMMvHY: Already in cache.
# Skipping yzW8HJq2u8k: Already in cache.
# Skipping KXZp6tO3YNk: Already in cache.
# Skipping nSQVeOW0wis: Already in cache.
# Skipping a1MUOuMT7ZM: Already in cache.
# Skipping IKPbRtoDvHs: Already in cache.
# Skipping JQCi3T4zdhA: Already in cache.
# Skipping WXKTBThYJzA: Already in cache.
# Skipping 7cz30adh2gk: Already in cache.
# Skipping 18Jb8LATPO8: Already in cache.
# Skipping YNjypiGk3-8: Already in cache.
# Skipping BfdcnIgqQtI: Already in cache.
# Skipping sd7X7ncZLSs: Already in cache.
# Skipping 6mOtJZhfUi8: Already in cache.
# Skipping xgGMdy3qYhU: Already in cache.
# Skipping pu_pLAG840o: Already in cache.
# Skipping OuU36FN7EeY: Already in cache.
# Skipping ikK_W-zUMg8: Already in cache.
# Skipping -9swUo3y4_g: Already in cache.
# Skipping EgCObL1WlMI: Already in cache.
# Skipping 0qw_FG8xBe8: Already in cache.
# Skipping 0YvwxDbJnMs: Already in cache.
# Skipping kCzCDAMYgCA: Already in cache.
# Skipping yED1FsMcKp0: Already in cache.
# Skipping g_gbMtqkQq0: Already in cache.
# Skipping 1tWDNNvy4cY: Already in cache.
# Skipping xk8PF_oILI0: Already in cache.
# Skipping GTLR49VI-_w: Already in cache.
# Skipping 2EBjYdVxAuE: Already in cache.
# Skipping 0H3BWTGpdow: Already in cache.
# Skipping XkTGUyASpxo: Already in cache.
# Skipping 8LwrSJ7YEM4: Already in cache.
# Skipping n1Z8hj53rBY: Already in cache.
# Skipping UzQc48ggRWY: Already in cache.
# Skipping -7mxnZ5VH5w: Already in cache.
# Skipping Za1JiMBOd3Y: Already in cache.
# Skipping XJVZ--EdqDU: Already in cache.
# Skipping r5OvicfQ-WM: Already in cache.
# Skipping Utow2fx5q_c: Already in cache.
# Skipping 4uRBIVROTZc: Already in cache.
# Skipping A32P7KFvScU: Already in cache.
# Skipping ER33RSygrUg: Already in cache.
# Skipping I6tkgg65LtA: Already in cache.
# Skipping aFwoMGQpfZs: Already in cache.
# Skipping tzq_S3Hcy9I: Already in cache.
# Skipping KON32Ul-XdI: Already in cache.
# Skipping DktZvP6UI1I: Already in cache.
# Skipping jBIcIK1u1ks: Already in cache.
# Skipping oHl_7iT8wwI: Already in cache.
# Skipping k7eI_3rVSF4: Already in cache.
# Skipping mwio6Vp_RQA: Already in cache.
# Skipping HMQv6jQ2bco: Already in cache.
# Skipping 7bCNscwuXAo: Already in cache.
# Skipping j7wIDDmItRU: Already in cache.
# Skipping 6_QoTWwxIMk: Already in cache.
# Skipping nHe_F7B130A: Already in cache.
# Skipping vVrd6VhdbGo: Already in cache.
# Skipping WpiDdtD0O8w: Already in cache.
# Skipping t2XHJRo0Yr4: Already in cache.
# Skipping LtI_CjMhkZg: Already in cache.
# Skipping hUa2BJCKzEc: Already in cache.
# Skipping uH0oJBjKz4o: Already in cache.
# Skipping oI8H1p6Ayto: Already in cache.
# Skipping LQ4730aswjU: Already in cache.
# Skipping nKpzvguS1X0: Already in cache.
# Skipping ldCxqi8-pgU: Already in cache.
# Skipping F7FeJGNuDyk: Already in cache.
# Skipping 9w08D1Ubpuk: Already in cache.
# Skipping LSuvKWlLPH4: Already in cache.
# Skipping Jcuadu1DWhY: Already in cache.
# Skipping Fk1R6jzEu6o: Already in cache.
# Skipping RgB19EEZ5C0: Already in cache.
# Skipping _1nPtRk9Y3k: Already in cache.
# Skipping WzygH6YkO7A: Already in cache.
# Skipping n_z3WNMC9tA: Already in cache.
# Skipping 2QRMx17eAvc: Already in cache.
# Skipping vH1ALW09BII: Already in cache.
# Skipping Use73HNix8k: Already in cache.
# Skipping rIKHbzFmdSs: Already in cache.
# Skipping MxeKTwixyrg: Already in cache.
# Skipping IzeWteFGpzc: Already in cache.
# Skipping bN-Q3Kp5UKU: Already in cache.
# Skipping Q5QF0Bl2DXo: Already in cache.
# Skipping -J2ppoEKmn0: Already in cache.
# Skipping C60sk3Xr_sA: Already in cache.
# 2025-02-14 16:28:08,153 - INFO - Metadata fetching complete. Cache updated.
# Finished processing liquid_death videos. Total videos: 307
# lululemon_align_pants
# Skipping UrUJ9tzJ1kY: Already in cache.
# Skipping at9hcz9qDQY: Already in cache.
# Skipping JHVzTOkfTa4: Already in cache.
# Skipping mfIzJCpWAIU: Already in cache.
# Skipping sNZYR0gl7zo: Already in cache.
# Skipping cZgCk-b8DLI: Already in cache.
# Skipping FvgBwEYkdCw: Already in cache.
# Skipping lOe0gTapJ1k: Already in cache.
# Skipping 2Ji7P37kGzg: Already in cache.
# Skipping 0cOSNHNjAmM: Already in cache.
# Skipping C85TWv5tHG0: Already in cache.
# Skipping 6AyM9vUO0Dg: Already in cache.
# Skipping aTfIpdIuCHg: Already in cache.
# Skipping XB6P1s7pQAI: Already in cache.
# Skipping YmK5GL6IxUc: Already in cache.
# Skipping 7PoAXxTB5pw: Already in cache.
# Skipping FhKjv21DlDk: Already in cache.
# Skipping yVlxS6Rqtg8: Already in cache.
# Skipping BmZIW0Q1Hm8: Already in cache.
# Skipping MlfIQ3z1p18: Already in cache.
# Skipping x_509DbXc0Q: Already in cache.
# Skipping t4AYlDoFAwQ: Already in cache.
# Skipping L-Z2kgkEA3M: Already in cache.
# Skipping 76SiO4T_-Vc: Already in cache.
# Skipping 0pRih-uISrA: Already in cache.
# Skipping _UjRcGDOg74: Already in cache.
# Skipping Hz2B8LIvAHY: Already in cache.
# Skipping 9S6cHJMToN8: Already in cache.
# Skipping OFC6866KkBI: Already in cache.
# Skipping z-CTiwDB2GM: Already in cache.
# Skipping 8Pnj8ykzUzw: Already in cache.
# Skipping 8CSPzC_o8L4: Already in cache.
# Skipping a2lUJe8IkLQ: Already in cache.
# Skipping aZ5-HasikVg: Already in cache.
# Skipping sMzQuQuj94I: Already in cache.
# Skipping 1u3RhQGHiCU: Already in cache.
# Skipping M3X86EBHVbw: Already in cache.
# Skipping o8yjzL2pI5E: Already in cache.
# Skipping nl_YCGzn84A: Already in cache.
# Skipping bb0nQfFs8p8: Already in cache.
# Skipping nDV-uTvmzo0: Already in cache.
# Skipping e0wZY6Xq4bo: Already in cache.
# Skipping r-BwNfzliRw: Already in cache.
# Skipping jp7Jwf3t7AI: Already in cache.
# Skipping 3YcdO3IrmHo: Already in cache.
# Skipping ZzEdGi5wX4Y: Already in cache.
# Skipping _hITyquFQz4: Already in cache.
# Skipping hUWe7koKqp0: Already in cache.
# Skipping 4e-Gg8yDTfQ: Already in cache.
# Skipping M5Yocx45Oog: Already in cache.
# Skipping iy5Saa_h9Mo: Already in cache.
# Skipping jgX-bEVLrFg: Already in cache.
# Skipping OwJRTT2G6yA: Already in cache.
# Skipping VxaGlIS2mQ8: Already in cache.
# Skipping KvoVtF5oHCo: Already in cache.
# Skipping B7LlK0xKApA: Already in cache.
# Skipping ZNym4HwUzd8: Already in cache.
# Skipping QiCBF8ADW1E: Already in cache.
# Skipping 7nhd4hOsXUY: Already in cache.
# Skipping g0vb0yoHmRA: Already in cache.
# Skipping mhKhQB5VtcI: Already in cache.
# Skipping WZgbX7Yo7HQ: Already in cache.
# Skipping PU2c6oVGoVU: Already in cache.
# Skipping TvmaQRXebtE: Already in cache.
# Skipping uVAVpX20VaU: Already in cache.
# Skipping ERhSlZvxWDc: Already in cache.
# Skipping h_i5bybM8vE: Already in cache.
# Skipping HxU0uYJ0w9A: Already in cache.
# Skipping _rTXusqaCUM: Already in cache.
# Skipping C9H1FzIUSbI: Already in cache.
# Skipping ygaMya8UtMA: Already in cache.
# Skipping sKizT123I68: Already in cache.
# Skipping 83GroPr3h5M: Already in cache.
# Skipping oLf4mDF9TCY: Already in cache.
# Skipping kqCPHo0q-3w: Already in cache.
# Skipping 6rgSpWvRHaQ: Already in cache.
# Skipping iUajtbS3AlQ: Already in cache.
# Skipping Ru1spoFB9T8: Already in cache.
# Skipping 2prbC9vOR7M: Already in cache.
# Skipping UEQ_Axonlk8: Already in cache.
# Skipping NsP15FVEpKY: Already in cache.
# Skipping CO0d4W7lJUU: Already in cache.
# Skipping Kf_YHiMGpKw: Already in cache.
# Skipping nYsp8qtq0eA: Already in cache.
# Skipping StLOUFhpbeU: Already in cache.
# Skipping ZQd9gx9mK2U: Already in cache.
# Skipping 7g7erRM7Y4U: Already in cache.
# Skipping B-36yXX7vXY: Already in cache.
# Skipping GwYB7kuUee4: Already in cache.
# Skipping RCnLV1xbohk: Already in cache.
# Skipping dnLUl38PCwM: Already in cache.
# Skipping vdkiVpp41ow: Already in cache.
# Skipping wLBsFeLFSWw: Already in cache.
# Skipping Btg0flJzTGM: Already in cache.
# Skipping 9JVndLg31T8: Already in cache.
# Skipping mA7v_Sx4dqA: Already in cache.
# Skipping 3Pclu4OcIw0: Already in cache.
# Skipping kup0TkyNRYM: Already in cache.
# Skipping gTRG2Rtg6HM: Already in cache.
# Skipping d8uIoNPsYGU: Already in cache.
# Skipping PJp19VKau_s: Already in cache.
# Skipping 4wDmHXISP5o: Already in cache.
# Skipping oNZZcrYjjLw: Already in cache.
# Skipping eRVt2msKNVg: Already in cache.
# Skipping So4jGEEpLoM: Already in cache.
# Skipping j9Ri3N7qSlA: Already in cache.
# Skipping LTGNBSkOkgE: Already in cache.
# Skipping g_uLLkddR-M: Already in cache.
# Skipping 92CIMGnUgM0: Already in cache.
# Skipping QAmTIXzPa9M: Already in cache.
# Skipping w7mSr1b9hQc: Already in cache.
# Skipping PAIi0zRL5oM: Already in cache.
# Skipping 4LTd6dedmvc: Already in cache.
# Skipping 8-P4RwK6d_c: Already in cache.
# Skipping xW4lxZKfN2E: Already in cache.
# Skipping -tnStJbD2s0: Already in cache.
# Skipping maGccSOoVrQ: Already in cache.
# Skipping bQAJQjwUMgI: Already in cache.
# Skipping wixMDffqlcQ: Already in cache.
# Skipping kN0vapQMFuI: Already in cache.
# Skipping 4ttcjpABH5E: Already in cache.
# Skipping VSC12m9kwSA: Already in cache.
# Skipping suVrui2jMRc: Already in cache.
# Skipping WLAenGkEjeg: Already in cache.
# Skipping Hl10qeQSj68: Already in cache.
# Skipping actP4oIvVis: Already in cache.
# Skipping UIsRPWkDTeQ: Already in cache.
# Skipping trgCE1F-Qq4: Already in cache.
# Skipping 0pkJVif2htM: Already in cache.
# Skipping f3WTGcLhYI0: Already in cache.
# Skipping rDgISDmUJRg: Already in cache.
# Skipping k2nqX05WkPY: Already in cache.
# Skipping VdxvDlqWGsc: Already in cache.
# Skipping pH_t8Lj92FY: Already in cache.
# Skipping PjU3mxx4Ub8: Already in cache.
# Skipping Fg6EB3cTxyY: Already in cache.
# Skipping xEbYFEEP1cg: Already in cache.
# Skipping lMCvRIcT2f4: Already in cache.
# Skipping fwSshC5otec: Already in cache.
# Skipping hB5c_Oh5BJU: Already in cache.
# Skipping 1XNGEv7iUUI: Already in cache.
# Skipping DAWvudt-VS0: Already in cache.
# Skipping QeDc2vDbrKc: Already in cache.
# Skipping 7bqRNen9uwg: Already in cache.
# Skipping qBJKbtejUAg: Already in cache.
# Skipping QW9QBdddRAE: Already in cache.
# Skipping Cif0Kl8ILLs: Already in cache.
# Skipping CvvzIEfNZNE: Already in cache.
# Skipping 2dI2gwismCg: Already in cache.
# Skipping Dxw4J1Mc-sk: Already in cache.
# Skipping x4P-XF4PViI: Already in cache.
# Skipping qEgfCuEUbg0: Already in cache.
# Skipping 6Xdt7GoFn2w: Already in cache.
# Skipping otp-eG8pjNI: Already in cache.
# Skipping EsaGxvdlGaE: Already in cache.
# Skipping iT69ywltEk0: Already in cache.
# ...
# Skipping 7oeaEzGaVJA: Already in cache.
# Skipping t2l4Bwz9Mmg: Already in cache.
# Skipping l5GlM0b9XH0: Already in cache.
# Skipping EpuKvz0rQZk: Already in cache.
# Skipping N_c3j1NXo4s: Already in cache.
# Skipping vyc7v-_oaIw: Already in cache.
# Skipping XSTvZhJXffY: Already in cache.
# Skipping AD5erh1sGww: Already in cache.
# Skipping r0VHVSVVWGc: Already in cache.
# Skipping _7zHTYMiApg: Already in cache.
# Skipping viMrn16wq7s: Already in cache.
# Skipping 90MGen89cK0: Already in cache.
# Skipping NBJO-tRRLIk: Already in cache.
# Skipping IDMCHn8V4vI: Already in cache.
# Skipping mfqo90EzJxA: Already in cache.
# Skipping Ndl9G1CqPWc: Already in cache.
# Skipping mRgd3xJNyBM: Already in cache.
# Skipping xQ8VQ05OJWE: Already in cache.
# Skipping cVsFlh5O88Q: Already in cache.
# Skipping 0zhhdxMUtWA: Already in cache.
# Skipping IXtMnM6u148: Already in cache.
# Skipping MtVUNUMenaA: Already in cache.
# Skipping 08H8R6pNiXI: Already in cache.
# Skipping 2oUw_fPMqqE: Already in cache.
# Skipping Xt3achui2ws: Already in cache.
# Skipping 0e1Og7Jc-P4: Already in cache.
# Skipping a2G8ufgjkL0: Already in cache.
# Skipping GbQJm6Viavc: Already in cache.
# Skipping 3nSslxu5vgs: Already in cache.
# Skipping VrfSG8X65Mo: Already in cache.
# Skipping VeZt_q_6IH8: Already in cache.
# Skipping 0CkFGKHdmbw: Already in cache.
# Skipping fDN7MNMiY-o: Already in cache.
# Skipping JYQgqwnMdKM: Already in cache.
# Skipping P7H4illtmhI: Already in cache.
# Skipping H1k7CJKmiC0: Already in cache.
# Skipping 4pVsthHUTwA: Already in cache.
# Skipping TOD0srR2qYM: Already in cache.
# Skipping q62UrtM7lmA: Already in cache.
# Skipping SYRBji3VL9Q: Already in cache.
# Skipping 9tu3Hm2Hsl4: Already in cache.
# Skipping JHIkRCOUhBA: Already in cache.
# Skipping 2m7-pNDHJx0: Already in cache.
# Skipping dquZt2B85E8: Already in cache.
# Skipping 4Ute6P3mAcM: Already in cache.
# Skipping HPvWCx0nkvI: Already in cache.
# Skipping UhYz37SIsac: Already in cache.
# Skipping 7l0XbHnfSyg: Already in cache.
# Skipping FlWeyHJHj-8: Already in cache.
# Skipping 9hiAmPaHoiY: Already in cache.
# Skipping srLJ4eqc68k: Already in cache.
# Skipping Ll4L3r1TCpI: Already in cache.
# Skipping qau_V-nt5KY: Already in cache.
# Skipping PUBYF_i-N4M: Already in cache.
# Skipping 46mqgK7XL6U: Already in cache.
# Skipping AVKYEarKk_8: Already in cache.
# Skipping fkxHmcRus44: Already in cache.
# Skipping hmhF2biPVnc: Already in cache.
# Skipping PB0tUH9f3Yc: Already in cache.
# Skipping E9iFptXIK0M: Already in cache.
# Skipping -iYI4GSZqic: Already in cache.
# Skipping CbAb1qLgKXA: Already in cache.
# Skipping vL4cbZW7pjA: Already in cache.
# Skipping 0hVKC6iqAoM: Already in cache.
# Skipping qiJaHYD9Ypg: Already in cache.
# Skipping 9SAk4vFAkUk: Already in cache.
# Skipping hQLVw8ufoj8: Already in cache.
# Skipping Qj8J2N36X5M: Already in cache.
# Skipping yyg8k_r0ZEU: Already in cache.
# Skipping arkk1I_0k7k: Already in cache.
# Skipping jgStSqA3r1E: Already in cache.
# Skipping kAddeYdabmg: Already in cache.
# Skipping tMrWMsyPB8k: Already in cache.
# Skipping OYxNXkyCghg: Already in cache.
# Skipping UPWDj9_oarM: Already in cache.
# Skipping QEWF-e1vuU0: Already in cache.
# Skipping Pn1PRpoMpJo: Already in cache.
# Skipping ILv8VqrPJA8: Already in cache.
# Skipping 6O8_IgeG1EA: Already in cache.
# Skipping lYWG508ASlk: Already in cache.
# Skipping hBhGOur-fGU: Already in cache.
# Skipping rXuwMs4LILs: Already in cache.
# Skipping 48BZA4JIIDg: Already in cache.
# Skipping k2ZVsDNCTdw: Already in cache.
# Skipping trEnfqcJU78: Already in cache.
# Skipping aBBR6TSxJRs: Already in cache.
# Skipping ljMDHocoxxM: Already in cache.
# Skipping C5NFT_z-PpQ: Already in cache.
# Skipping PAbqKfU0a58: Already in cache.
# Skipping CPV7hla6yuc: Already in cache.
# Skipping sul74QocxMA: Already in cache.
# Skipping 4pXQlN-7uDY: Already in cache.
# Skipping zvU9Nwj0YlQ: Already in cache.
# Skipping COSGE2Lmto0: Already in cache.
# Skipping 6KLv8C9wppA: Already in cache.
# Skipping BoFz2G7BaIY: Already in cache.
# Skipping oOIRB3znJI8: Already in cache.
# Skipping lT3bESlDXL8: Already in cache.
# Skipping UXcg5skvzg0: Already in cache.
# Skipping GVLkXNehQo0: Already in cache.
# Skipping 3RHcAAcDKso: Already in cache.
# Skipping ZpK4sqW42pE: Already in cache.
# Skipping wJtpa1ToaNA: Already in cache.
# Skipping wGLLmsMKc_k: Already in cache.
# Skipping PcZGdrKp2bs: Already in cache.
# Skipping bWzlyjdmaY4: Already in cache.
# Skipping RUqUAjVmwvc: Already in cache.
# Skipping Hg00UL3pmU8: Already in cache.
# Skipping 6PbNPvNqMGc: Already in cache.
# Skipping yDCe6t7VM98: Already in cache.
# Skipping nYJSxtJJ7R4: Already in cache.
# Skipping 4YUDs5iKs1U: Already in cache.
# Skipping xC9TyCiD-BQ: Already in cache.
# Skipping Ng5dJ1Dh71U: Already in cache.
# Skipping ZyMa5BnZ59A: Already in cache.
# Skipping 17af-H0LDg8: Already in cache.
# Skipping jwxzpq-4E8I: Already in cache.
# Skipping azIOlzhuWSw: Already in cache.
# Skipping EGAG_aq5paU: Already in cache.
# Skipping _6Z-jve7mmo: Already in cache.
# Skipping lEGEHEDPlxQ: Already in cache.
# Skipping 2kQ9FwbXaok: Already in cache.
# Skipping TEHhqHDisl4: Already in cache.
# Skipping wqylfFNoFvE: Already in cache.
# Skipping i2sDu0-Najc: Already in cache.
# Skipping aqBFIgRO2kE: Already in cache.
# Skipping yqROj-KvlHM: Already in cache.
# Skipping 6T5fNZLs5j4: Already in cache.
# Skipping nrqCcQLANqA: Already in cache.
# Skipping X8n-3bXS77Q: Already in cache.
# Skipping gGLz4NFqs_s: Already in cache.
# Skipping DWjAVMJOzPo: Already in cache.
# Skipping LseN9pS3jtw: Already in cache.
# Skipping Orf4VgsieYU: Already in cache.
# Skipping Knej372vw_I: Already in cache.
# Skipping vhgriYhkPd4: Already in cache.
# Skipping mlie6EzomFc: Already in cache.
# Skipping _J0ZXMi918g: Already in cache.
# Skipping PSse_9n_Eho: Already in cache.
# Skipping q5Og-8Fe3To: Already in cache.
# Skipping v6TR6kcdE4k: Already in cache.
# Skipping rPlOmxbD04s: Already in cache.
# Skipping Rrm_rLO58ic: Already in cache.
# Skipping ajzRdisEuWM: Already in cache.
# Skipping jPFBML7o_eY: Already in cache.
# Skipping fjhf6jxwnMY: Already in cache.
# Skipping 2AXFP-T62Hc: Already in cache.
# Skipping MEg7IXc4DIg: Already in cache.
# Skipping BAtQEyoN0VE: Already in cache.
# Skipping bOPDJ-diit4: Already in cache.
# Skipping pqweHynJqv8: Already in cache.
# Skipping F5LnqsMAa1M: Already in cache.
# Skipping 2cH120AuP1A: Already in cache.
# Skipping 9r8VSkGbMt0: Already in cache.
# Skipping 063TXAthkIM: Already in cache.
# Skipping 35aZbnbIZSw: Already in cache.
# Skipping hIwtvaLKZ0g: Already in cache.
# Skipping RJi9Chtz6e4: Already in cache.
# Skipping MRfFkuMOpbE: Already in cache.
# Skipping 67vvkFrSB8Q: Already in cache.
# Skipping mqar83djiGE: Already in cache.
# Skipping GW1cnDeIf_A: Already in cache.
# Skipping g_CRsSiK5nI: Already in cache.
# Skipping 7d42mzNwZ7A: Already in cache.
# Skipping t3Ux99ZDqws: Already in cache.
# Skipping f9J8RhLKoBI: Already in cache.
# Skipping bpQ---65vGc: Already in cache.
# Skipping 8bfsSenZvfs: Already in cache.
# Skipping fZ9MwNkhTvA: Already in cache.
# Skipping e5M2SNPKe0o: Already in cache.
# Skipping tKMhQbd7q8M: Already in cache.
# Skipping J9HlLwL71qw: Already in cache.
# Skipping 0siakPWMqhs: Already in cache.
# Skipping 3_5aUXMIGHE: Already in cache.
# Skipping YLY7KAHwfmk: Already in cache.
# Skipping nLnKaPDZlzA: Already in cache.
# Skipping 9gvzG--b9mw: Already in cache.
# Skipping X9CXRzKnVu4: Already in cache.
# Skipping YehV43DG59M: Already in cache.
# Skipping d6d7YymywhQ: Already in cache.
# Skipping fVAjWnkIjos: Already in cache.
# Skipping SinQAHpPJ7k: Already in cache.
# Skipping GlvLaKlJvw0: Already in cache.
# Skipping W1LYKrukLzk: Already in cache.
# Skipping JdQzf30cJq4: Already in cache.
# Skipping I7MtgmsbQh4: Already in cache.
# Skipping MRJbs50fnyU: Already in cache.
# Skipping vafpNDM7TVE: Already in cache.
# Skipping 6OMQTU25hyw: Already in cache.
# Skipping f2u_WsRay8g: Already in cache.
# Skipping OHC00a5f-Y0: Already in cache.
# Skipping xUJHuE9QNAM: Already in cache.
# Skipping KPpkENSn8Qo: Already in cache.
# Skipping v3gEo028q5U: Already in cache.
# Skipping vNS3Uhoe_88: Already in cache.
# Skipping CFfWm3_FjeA: Already in cache.
# Skipping Xb51dXZ1Ce4: Already in cache.
# Skipping 7u9coA9qWAc: Already in cache.
# Skipping Qr55-hTaJDg: Already in cache.
# Skipping qrOLnMO7G24: Already in cache.
# Skipping ga2c_n6xfoM: Already in cache.
# Skipping -cps5zc8yUA: Already in cache.
# Skipping FNlw7XOvJ3k: Already in cache.
# Skipping _itnZmiFfKU: Already in cache.
# Skipping qpatFzo8sp0: Already in cache.
# Skipping R2ddMTxZ0Tc: Already in cache.
# Skipping xIhcTDllpFk: Already in cache.
# Skipping SXsUYrR9Q0s: Already in cache.
# Skipping 9ENxSNSbFyU: Already in cache.
# Skipping czSfOmKSUhw: Already in cache.
# Skipping vSZhh6lGaw4: Already in cache.
# Skipping TJOstaiccTU: Already in cache.
# Skipping zxKL6QRI76c: Already in cache.
# Skipping x-3Cj0Xekjo: Already in cache.
# Skipping PmqggVkWLhU: Already in cache.
# Skipping 3NMq6fR5lF0: Already in cache.
# Skipping akZbpPNGPLc: Already in cache.
# Skipping KQ2dp-QH5XY: Already in cache.
# Skipping zISymvb5jjw: Already in cache.
# Skipping uB6_BwdMrtI: Already in cache.
# Skipping FQtPv-S7jZQ: Already in cache.
# Skipping HIyc6xIu4EU: Already in cache.
# Skipping _EbgxPfReTo: Already in cache.
# Skipping W6vZnzHjeYY: Already in cache.
# Skipping IMmZxSzb-bA: Already in cache.
# Skipping o0ukrPRsW-o: Already in cache.
# Skipping K-AzxRLtACY: Already in cache.
# Skipping yVmfpq6QAdw: Already in cache.
# Skipping Rk4qTkFQ9Aw: Already in cache.
# Skipping W6m9INAKMeE: Already in cache.
# Skipping 10f6EH79C8o: Already in cache.
# Skipping tPx-jhAzAzk: Already in cache.
# Skipping -gW6hslobjE: Already in cache.
# Skipping p2CYygMOS4Q: Already in cache.
# Skipping QMa4Y3mBgDE: Already in cache.
# Skipping uBTpqJAexvU: Already in cache.
# Skipping kgxuDHbL44k: Already in cache.
# Skipping qgB2mntqpko: Already in cache.
# Skipping dC8jpChK1Sg: Already in cache.
# Skipping J1O_A19IVxo: Already in cache.
# Skipping gLcHghINQzI: Already in cache.
# Skipping J2Q38M2dAa8: Already in cache.
# Skipping rfgBTr_aJlE: Already in cache.
# Skipping dcWNqYZqIao: Already in cache.
# Skipping DxpfDfTPVGY: Already in cache.
# Skipping bbe513riTbA: Already in cache.
# Skipping 6XPFTA11W0c: Already in cache.
# Skipping BLYP0nzuldY: Already in cache.
# Skipping j0CbhwpBZeA: Already in cache.
# Skipping p3OxK65_YlQ: Already in cache.
# Skipping mGSboOnFsFQ: Already in cache.
# Skipping mxmBsuqA-2c: Already in cache.
# Skipping 6nHGE7JJBEg: Already in cache.
# Skipping ivNGyCg-0e8: Already in cache.
# Skipping vzKD9tcnc3Q: Already in cache.
# Skipping JdLLljZLrl8: Already in cache.
# Skipping SLvWNk_4Nng: Already in cache.
# Skipping LFjtWEwaMCk: Already in cache.
# Skipping BdHEm45DvmM: Already in cache.
# Skipping bZflQPbIeWs: Already in cache.
# Skipping TFAwkCL9OZc: Already in cache.
# Skipping StzE6SQegNk: Already in cache.
# Skipping fiKwySCvFBg: Already in cache.
# Skipping paRlzc3KXXw: Already in cache.
# Skipping Fp6YHMT4eoA: Already in cache.
# Skipping tU7lLM9eLmM: Already in cache.
# Skipping 63XW3_Dk64U: Already in cache.
# Skipping DLz-FaFIVMk: Already in cache.
# Skipping RnA9TmPtqDg: Already in cache.
# Skipping 6kKqcdrFinA: Already in cache.
# Skipping lF3-5cjKkeQ: Already in cache.
# Skipping 3FtDk1Uyye0: Already in cache.
# Skipping OMW4Ztlmw0E: Already in cache.
# Skipping FF_dpRuj-xM: Already in cache.
# Skipping Tuiug8TF7Rc: Already in cache.
# Skipping 2wqQ_YdgD9k: Already in cache.
# Skipping Snu4vV9eGcQ: Already in cache.
# Skipping pSFTIKcd-NI: Already in cache.
# Skipping xA4ZEi2tw80: Already in cache.
# Skipping OU2FVAw-BJ0: Already in cache.
# Skipping iXhiUSXjzq8: Already in cache.
# Skipping MRTNVQ6x6jg: Already in cache.
# Skipping 5RVVg-pNaLc: Already in cache.
# Skipping TSLPtSBegkI: Already in cache.
# Skipping ULWyrYv_H_Y: Already in cache.
# Skipping 1w_jY8MNvgM: Already in cache.
# Skipping fd4WXuNAIPU: Already in cache.
# Skipping YP-fFpj2Xyw: Already in cache.
# Skipping 0av0nkeTI08: Already in cache.
# Skipping 9N6MQmIfWKw: Already in cache.
# Skipping PgtQupqhbts: Already in cache.
# Skipping j8DARUyKXj8: Already in cache.
# Skipping Ove8hOG4i2A: Already in cache.
# Skipping 4zs878GmWkw: Already in cache.
# Skipping o5fBPBIqIXw: Already in cache.
# Skipping IiHaDAw9iI8: Already in cache.
# Skipping ErCaN1E6Ais: Already in cache.
# Skipping Vc2VkMCg2hI: Already in cache.
# Skipping xNsPBCkPnbw: Already in cache.
# Skipping GaFNXnE70dU: Already in cache.
# Skipping IKHPJ1KGs7A: Already in cache.
# Skipping DcKUUOwcrBg: Already in cache.
# Skipping 5oATfCjFg-o: Already in cache.
# Skipping DpPzzIYk7o8: Already in cache.
# Skipping uMqgy3Jdo9U: Already in cache.
# Skipping ltYH-LSBfQI: Already in cache.
# Skipping 8MPq13wEw7A: Already in cache.
# Skipping nyZVDSXI40M: Already in cache.
# Skipping 1qDMHW4H-DI: Already in cache.
# Skipping o3agZZ2Pxvc: Already in cache.
# Skipping hWqpMLsYxAQ: Already in cache.
# Skipping RyriVOXY6gI: Already in cache.
# Skipping nA91vCCzStU: Already in cache.
# Skipping 0Cx_lJY2B94: Already in cache.
# Skipping 2tstSlex9oA: Already in cache.
# Skipping dy3BZXjHEz0: Already in cache.
# Skipping Wz_RNoRighk: Already in cache.
# Skipping aEdpzqcjp-g: Already in cache.
# Skipping EtG45WuivvI: Already in cache.
# Skipping cDODVJoNOLo: Already in cache.
# Skipping T_sFYPmcGLA: Already in cache.
# Skipping hr-hreIrTxU: Already in cache.
# Skipping Zof96AAKl6g: Already in cache.
# Skipping Fsy6nEA910U: Already in cache.
# Skipping A0F3ie3saek: Already in cache.
# Skipping VK22wSAJ38I: Already in cache.
# Skipping D_cbVblbkuM: Already in cache.
# Skipping AwFQnHx8qSE: Already in cache.
# Skipping G2q5FNDKH6Q: Already in cache.
# Skipping xje0798Z4Mw: Already in cache.
# Skipping W2HLZv3A1VU: Already in cache.
# Skipping ZuzqxkXQo-Y: Already in cache.
# Skipping uPl_gy552oU: Already in cache.
# Skipping 4U8-_vnnrp0: Already in cache.
# Skipping 279ZOJfTS5g: Already in cache.
# Skipping g1FYc0_XihE: Already in cache.
# Skipping XcDLtBWsGRo: Already in cache.
# Skipping NWyERSc04N8: Already in cache.
# Skipping UpJfpTBSM88: Already in cache.
# Skipping tESW-hmvbhs: Already in cache.
# Skipping gz1MraytkX8: Already in cache.
# Skipping RXtTnD6C1ys: Already in cache.
# Skipping V1FU5V5T52o: Already in cache.
# Skipping Nv0q1X2ZNns: Already in cache.
# Skipping AvJneBT_9GU: Already in cache.
# Skipping SJm62Olt55o: Already in cache.
# Skipping Fzt_hXkJCOk: Already in cache.
# Skipping nKGegbJrcNM: Already in cache.
# Skipping LywMBosaqrA: Already in cache.
# Skipping A6gsHWkmLq8: Already in cache.
# Skipping _xdohDUZbuo: Already in cache.
# Skipping oxNmiIKXVg8: Already in cache.
# Skipping qO9ihPc5dOM: Already in cache.
# Skipping RPGTWLGqDyA: Already in cache.
# Skipping 5Q1TSLISO3U: Already in cache.
# Skipping CGp_ZM76El0: Already in cache.
# Skipping UG6Acb2cs_M: Already in cache.
# Skipping clrf9o0Ebyg: Already in cache.
# Skipping Z57Ja90xSdI: Already in cache.
# Skipping R2-TkC5FR5Y: Already in cache.
# Skipping oP3jhsLxIRE: Already in cache.
# Skipping hurK6Lv7QSs: Already in cache.
# Skipping Ui8kJMeWSuE: Already in cache.
# Skipping ZRERYwcNdqM: Already in cache.
# Skipping IokHkgnDfUY: Already in cache.
# Skipping iwqW1aLr--I: Already in cache.
# Skipping lrMwqUklrxc: Already in cache.
# Skipping oAIMUJYyZjM: Already in cache.
# Skipping rQNVzFbE3uM: Already in cache.
# Skipping Z-NNKUY-6_Q: Already in cache.
# Skipping x87AORW-mEY: Already in cache.
# Skipping VRbYude4nGE: Already in cache.
# Skipping UWZULVDYmTY: Already in cache.
# Skipping o2cDHI2f2f4: Already in cache.
# Skipping LPv6RtjMtI8: Already in cache.
# Skipping _eVSFQcqvXk: Already in cache.
# Skipping d-YdLxO99UE: Already in cache.
# Skipping RDEvvr998sk: Already in cache.
# Skipping 8ccr03-mD0I: Already in cache.
# Skipping SKq63SnBu8Y: Already in cache.
# Skipping dzbBjzDH-Aw: Already in cache.
# Skipping 7Vl4W42Tnw4: Already in cache.
# Skipping 2y0hMYTgLc0: Already in cache.
# Skipping 7hk1R5jxMKw: Already in cache.
# Skipping _CR1WRgNFsA: Already in cache.
# Skipping BtAxYMw0hw0: Already in cache.
# Skipping bZzm9nc7g8w: Already in cache.
# Skipping QbCGgMnthyk: Already in cache.
# Skipping 9Ilazsdxel4: Already in cache.
# Skipping D8yVKlY0vYc: Already in cache.
# Skipping xFfIouJQs1M: Already in cache.
# Skipping nvl3Jk4FV5Y: Already in cache.
# Skipping Sl5MXcVE8Tg: Already in cache.
# Skipping L7GH6fg8xm0: Already in cache.
# Skipping 6PVGnEXqVS4: Already in cache.
# Skipping fMMD17HxCKU: Already in cache.
# 2025-02-14 16:28:38,411 - INFO - Metadata fetching complete. Cache updated.
# Finished processing tesla_model_y videos. Total videos: 466

# %%
cache_dir="cache"
json_files = glob.glob(os.path.join(cache_dir, "video_info_cache_*.json"))
json_files
# Out:
# ['cache\\video_info_cache_apple_airtag.json',
#  'cache\\video_info_cache_cosrx_snail_mucin_serum.json',
#  'cache\\video_info_cache_liquid_death.json',
#  'cache\\video_info_cache_lululemon_align_pants.json',
#  'cache\\video_info_cache_macbook_pro_m4.json',
#  'cache\\video_info_cache_meta_quest_3.json',
#  'cache\\video_info_cache_samsung_galaxy_watch_7.json',
#  'cache\\video_info_cache_samsung_oled_tv.json',
#  'cache\\video_info_cache_stanley_tumbler.json',
#  'cache\\video_info_cache_tesla_model_y.json']

# %%
def process_video_metadata(df, cache_data):
    """
    Process video metadata from cached JSON files and merge with existing DataFrame
    
    Args:
        df (pd.DataFrame): Input DataFrame containing video_ids
        cache_dir (str): Directory containing cached JSON files
        
    Returns:
        pd.DataFrame: DataFrame with merged metadata
    """
    import json
    import os
    
    result_list = []
    
    # Load cached video info
    
    if not cache_data:
        print("No video info found in cache.")
        # return None
    
    # Process each video
    for video_id in df.video_id:
        video_data = cache_data.get(video_id, {})
        if not video_data:
            print(f"No video info found for video ID: {video_id}")
            continue
        append_dict = {"video_id": video_id}
        
        # Extract formats data
        # Extract formats data - Fixed this part
        for fmt in video_data.get("formats", []):  # Changed from cache_data to video_data
            if fmt.get("format_id") == "sb0":
                append_dict["merged_screenshot"] = fmt.get("fragments")
        
        # Extract other metadata
        append_dict.update({
            "video_chapters": video_data.get("chapters"),
            "heatmap": video_data.get("heatmap"),
            "automatic_captions": video_data.get("automatic_captions", {}).get("en", []),
            # "duration": video_data.get("duration"),
            # "view_count": video_data.get("view_count"),
            # "like_count": video_data.get("like_count"),
            # "comment_count": video_data.get("comment_count"),
            # "average_rating": video_data.get("average_rating")
        })
        # print(append_dict)
        
        result_list.append(append_dict)
    
    # Convert to DataFrame and merge
    result_df = pd.DataFrame(result_list)
    # left join on video_id
    final_df = pd.merge(df, result_df, how="left", on="video_id")
    
    # remove duplicates
    final_df = final_df.drop_duplicates(subset=['video_id'])
    
    return final_df

# Usage example:
cache_dir="cache"
json_files = glob.glob(os.path.join(cache_dir, "video_info_cache_*.json"))

for i, csv_file in enumerate(csv_matched):
    df = pd.read_csv(csv_file)
    print(f"Processing {csv_file}...")
    
    # Process video metadata
    print(f"Processing {json_files[i]}...")
    video_info = load_cache(json_files[i])
    print(len(video_info))
    df_with_metadata = process_video_metadata(df, video_info)

    # Create a binary column indicating if both transcript and screenshots are available
    df_with_metadata['transcript_screenshot_not_null'] = (
        df_with_metadata['merged_screenshot'].notna() & 
        df_with_metadata['transcript'].notna()
    ).astype(int)
    
    # sort by transcript_screenshot_not_null then viewCount
    df_with_metadata = df_with_metadata.sort_values(by=["transcript_screenshot_not_null", "viewCount"], ascending=[False, False])
    # Save processed DataFrame
    output_file = csv_file.replace('.csv', '_with_metadata.csv')
    df_with_metadata.to_csv(output_file, index=False)

    # save to excel
    df_with_metadata.to_excel(output_file.replace('.csv', '.xlsx'), index=False)
    
    print(f"\nProcessed {csv_file}:")
    print(f"Original columns: {len(df.columns)}")
    print(f"New columns: {len(df_with_metadata.columns)}")
    print(f"Rows processed: {len(df_with_metadata)}")
# Out:
# Processing cache\cleaned_ytb_search_combined_results_apple_airtag_matched_keywords.csv...
# Processing cache\video_info_cache_apple_airtag.json...
# 419
#
# Processed cache\cleaned_ytb_search_combined_results_apple_airtag_matched_keywords.csv:
# Original columns: 33
# New columns: 38
# Rows processed: 306
# Processing cache\cleaned_ytb_search_combined_results_cosrx_snail_mucin_serum_matched_keywords.csv...
# Processing cache\video_info_cache_cosrx_snail_mucin_serum.json...
# 419
#
# Processed cache\cleaned_ytb_search_combined_results_cosrx_snail_mucin_serum_matched_keywords.csv:
# Original columns: 33
# New columns: 38
# Rows processed: 288
# Processing cache\cleaned_ytb_search_combined_results_liquid_death_matched_keywords.csv...
# Processing cache\video_info_cache_liquid_death.json...
# 368
# No video info found for video ID: aMGs9HhjeWQ
# No video info found for video ID: hgiV-800TjU
# No video info found for video ID: UDxq0vnGNhg
# No video info found for video ID: htPlnC4Ket8
# No video info found for video ID: PI8CDi71fXQ
# No video info found for video ID: CJCW6nlIpos
#
# Processed cache\cleaned_ytb_search_combined_results_liquid_death_matched_keywords.csv:
# Original columns: 33
# New columns: 38
# Rows processed: 307
# Processing cache\cleaned_ytb_search_combined_results_lululemon_align_pants_matched_keywords.csv...
# Processing cache\video_info_cache_lululemon_align_pants.json...
# 408
#
# Processed cache\cleaned_ytb_search_combined_results_lululemon_align_pants_matched_keywords.csv:
# Original columns: 33
# New columns: 38
# Rows processed: 286
# Processing cache\cleaned_ytb_search_combined_results_macbook_pro_m4_matched_keywords.csv...
# Processing cache\video_info_cache_macbook_pro_m4.json...
# 422
#
# Processed cache\cleaned_ytb_search_combined_results_macbook_pro_m4_matched_keywords.csv:
# Original columns: 33
# New columns: 38
# Rows processed: 276
# Processing cache\cleaned_ytb_search_combined_results_meta_quest_3_matched_keywords.csv...
# Processing cache\video_info_cache_meta_quest_3.json...
# 468
#
# Processed cache\cleaned_ytb_search_combined_results_meta_quest_3_matched_keywords.csv:
# Original columns: 33
# New columns: 38
# Rows processed: 449
# Processing cache\cleaned_ytb_search_combined_results_samsung_galaxy_watch_7_matched_keywords.csv...
# Processing cache\video_info_cache_samsung_galaxy_watch_7.json...
# 391
#
# Processed cache\cleaned_ytb_search_combined_results_samsung_galaxy_watch_7_matched_keywords.csv:
# Original columns: 33
# New columns: 38
# Rows processed: 386
# Processing cache\cleaned_ytb_search_combined_results_samsung_oled_tv_matched_keywords.csv...
# Processing cache\video_info_cache_samsung_oled_tv.json...
# 395
#
# Processed cache\cleaned_ytb_search_combined_results_samsung_oled_tv_matched_keywords.csv:
# Original columns: 33
# New columns: 38
# Rows processed: 288
# Processing cache\cleaned_ytb_search_combined_results_stanley_tumbler_matched_keywords.csv...
# Processing cache\video_info_cache_stanley_tumbler.json...
# 420
#
# Processed cache\cleaned_ytb_search_combined_results_stanley_tumbler_matched_keywords.csv:
# Original columns: 33
# New columns: 38
# Rows processed: 353
# Processing cache\cleaned_ytb_search_combined_results_tesla_model_y_matched_keywords.csv...
# Processing cache\video_info_cache_tesla_model_y.json...
# 476
#
# Processed cache\cleaned_ytb_search_combined_results_tesla_model_y_matched_keywords.csv:
# Original columns: 33
# New columns: 38
# Rows processed: 466

# %%
cache_dir="cache"
final_csvs = glob.glob(os.path.join(cache_dir, "cleaned_ytb_search_combined_*_matched_keywords_with_metadata.csv"))
final_csvs
# Out:
# ['cache\\cleaned_ytb_search_combined_results_apple_airtag_matched_keywords_with_metadata.csv',
#  'cache\\cleaned_ytb_search_combined_results_cosrx_snail_mucin_serum_matched_keywords_with_metadata.csv',
#  'cache\\cleaned_ytb_search_combined_results_liquid_death_matched_keywords_with_metadata.csv',
#  'cache\\cleaned_ytb_search_combined_results_lululemon_align_pants_matched_keywords_with_metadata.csv',
#  'cache\\cleaned_ytb_search_combined_results_macbook_pro_m4_matched_keywords_with_metadata.csv',
#  'cache\\cleaned_ytb_search_combined_results_meta_quest_3_matched_keywords_with_metadata.csv',
#  'cache\\cleaned_ytb_search_combined_results_samsung_galaxy_watch_7_matched_keywords_with_metadata.csv',
#  'cache\\cleaned_ytb_search_combined_results_samsung_oled_tv_matched_keywords_with_metadata.csv',
#  'cache\\cleaned_ytb_search_combined_results_stanley_tumbler_matched_keywords_with_metadata.csv',
#  'cache\\cleaned_ytb_search_combined_results_tesla_model_y_matched_keywords_with_metadata.csv']

# %%
import json
import ast
import requests
import os
from io import BytesIO
from PIL import Image

def process_json(json_string):
    try:
        python_dict = ast.literal_eval(json_string) # Safely evaluates to Python dict
        json_string = json.dumps(python_dict) #Converts to proper JSON string
        data = json.loads(json_string)
        return data
    except (ValueError, SyntaxError, json.JSONDecodeError) as e:
        print(f"Error processing JSON: {e}")
        return None

def save_images_from_urls(image_dict, output_dir="images"):
    """
    Downloads images from a list of URLs and saves them locally.

    Args:
        image_urls: A list of image URLs.
        output_dir: The directory to save the images (created if it doesn't exist).
    """

    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    for video_id in image_dict:
        image_urls = [img['url'] for img in image_dict[video_id]]
        for i, url in enumerate(image_urls):
            try:
                response = requests.get(url, stream=True)
                response.raise_for_status()  # Raise an exception for bad status codes (4xx or 5xx)

                image = Image.open(BytesIO(response.content))
                filename = os.path.join(output_dir, f"{video_id}_{i+1}.jpg")  #Safe filename creation
                image.save(filename)
                print(f"Image {i+1} saved to: {filename}")

            except requests.exceptions.RequestException as e:
                print(f"Error downloading image {i+1} from {url}: {e}")
            except IOError as e:
                print(f"Error saving image {i+1} from {url}: {e}")
            except Exception as e: #Catch any other unexpected error
                print(f"An unexpected error occurred for image {i+1} from {url}: {e}")

# %%
# img_dict_tech = {}
# for idx, row in tech_df_100.iterrows():
#     if pd.notnull(row['merged_screenshot']):
#         img_dict_tech[row['video_id']] = process_json(row['merged_screenshot'])
# len(img_dict_tech), img_dict_tech.keys()

for csv in final_csvs:
    df = pd.read_csv(csv)
    print(f"Processing {csv}...")
    img_dict = {}
    for idx, row in df.iterrows():
        if pd.notnull(row['merged_screenshot']):
            img_dict[row['video_id']] = process_json(row['merged_screenshot'])
    print(len(img_dict), img_dict.keys())
    save_images_from_urls(img_dict, output_dir="cache/images")

# %% [markdown]
# House keeping

# %%
import os
import shutil

# Create the directories
os.makedirs('cache/csv_files', exist_ok=True)
os.makedirs('cache/json_files', exist_ok=True)
os.makedirs('cache/xlsx_files', exist_ok=True)

# Move files to their respective folders
for file in os.listdir('cache/'):
    if file.endswith('.csv'):
        shutil.move(f'cache/{file}', f'cache/csv_files/{file}')
    elif file.endswith('.json'):
        shutil.move(f'cache/{file}', f'cache/json_files/{file}')
    elif file.endswith('.xlsx'):
        shutil.move(f'cache/{file}', f'cache/xlsx_files/{file}')
